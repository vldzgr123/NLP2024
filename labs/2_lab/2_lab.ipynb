# %% [markdown]
# # Лабораторная работа 2. Классификация текстовых данных. Рекуррентные нейронные сети Many To One
#
#
# ## Задание
# - Осознать теоретические основы работы рекуррентных нейронных сетей;
#
# - изучить возможности и инструменты PyTorch для построения и использования рекуррентных блоков (RNN. LSTM, GRU);
#
# - решить задачу классификации текстовых документов с использованием рекуррентных нейронных сетей вида Many To One (многие к одному).
#
#
#
# ## Ход работы
# 1. Загрузите датасет из ЛР1. Датасет большой, рекомендуется для работы взять его часть (далее - корпус). Если вам не нравится этот набор данных, можете использовать другой, по своему вкусу.
#
# 2. Рассмотрите каждый объект корпуса как отдельный текстовый документ. Выполните предварительную обработку каждого объекта.
#
# 3. Выполните векторизацию каждого документа любым способом (можно с помощью своих моделей Word2Vec, при условии, что Word2Vec модели обучались на той же выборке документов; можно использовать другие библиотеки и модели).
#
# 4. Закодируйте значения целевого признака (категория обращения). Разделите данные на обучающую и тестирующую выборку.
#
# 5. С помощью PyTorch соберите и обучите три нейронных сети для решения задачи классификации (предсказания категории обращения); количество слоев и значения других параметров конфигурируете по вашему усмотрению:
#
# - сеть на базе блока RNN;
#
# - сеть на базе блока LSTM;
#
# - сеть на базе блока GRU.
#
# 6.  Используя известные вам метрики классификации и тестирующую выборку оцените качество каждой из обученных моделей. Сделайте вывод о том, какая из моделей на ваших данных отработала лучше других.

# %%
# !pip install pymorphy3
# Out:
# Requirement already satisfied: pymorphy3 in /usr/local/lib/python3.10/dist-packages (2.0.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy3) (0.7.2)
# Requirement already satisfied: pymorphy3-dicts-ru in /usr/local/lib/python3.10/dist-packages (from pymorphy3) (2.4.417150.4580142)

# %%
import pandas as pd
import torch
from torch import nn
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import re
from pymorphy3 import MorphAnalyzer
import string
from gensim.models import Word2Vec
import numpy as np
from sklearn.decomposition import PCA
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.__version__
# Out:
# '2.5.1+cu121'

# %% [markdown]
# ### 1. Загрузите датасет из ЛР1. Датасет большой, рекомендуется для работы взять его часть (далее - корпус). Если вам не нравится этот набор данных, можете использовать другой, по своему вкусу.

# %%
data = pd.read_csv("Petitions.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59889 entries, 0 to 59888
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    59889 non-null  int64
#  1   public_petition_text  59889 non-null  object
#  2   reason_category       59889 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %%
data.head(1000)
# Out:
#           id                               public_petition_text  \
# 0    3168490                                     снег на дороге
# 1    3219678                очистить кабельный киоск от рекламы
# 2    2963920  Просим убрать все деревья и кустарники, которы...
# 3    3374910  Неудовлетворительное состояние парадной - надп...
# 4    3336285                                           Граффити
# ..       ...                                                ...
# 995  3279475      Повреждения дорожного покрытия проезжей части
# 996  3356222  дворник убрал песок у подъезда и высыпал его н...
# 997  3276541                        Нужно заделать ямы во дворе
# 998  3032938                              демонтировать решетку
# 999  3034986                                     граффити на ТП
#
#                                    reason_category
# 0                                  Благоустройство
# 1                                  Благоустройство
# 2                                  Благоустройство
# 3                                   Содержание МКД
# 4                                  Благоустройство
# ..                                             ...
# 995                                Благоустройство
# 996                                Благоустройство
# 997                                Благоустройство
# 998  Нарушение правил пользования общим имуществом
# 999                                Благоустройство
#
# [1000 rows x 3 columns]

# %%
data = data.head(10000)

# %%
data.drop(["id"], axis=1, inplace=True)
# Out:
# <ipython-input-159-0544d42fdce7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(["id"], axis=1, inplace=True)

# %% [markdown]
# ### 2. Рассмотрите каждый объект корпуса как отдельный текстовый документ. Выполните предварительную обработку каждого объекта.

# %% [markdown]
# Удаление всех символов, которые не являются цифрами, буквами и пробелами, и токенизация

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
morph = MorphAnalyzer()
stopwords = stopwords.words("russian")


def preProccesingData(text):
    only_letters = re.sub("[^\s^\w]+", " ", text)
    tokenized = word_tokenize(only_letters)
    normalized = [morph.normal_forms(word)[0] for word in tokenized]
    no_stop_words = [
        word
        for word in normalized
        if ((word not in string.punctuation) and (word not in stopwords) and word.isalpha())
    ]
    return no_stop_words

# %%
data['public_petition_text'] = data['public_petition_text'].apply(preProccesingData).tolist()
data[:10]
# Out:
#                                 public_petition_text  \
# 0                                     [снег, дорога]
# 1              [очистить, кабельный, киоск, реклама]
# 2  [просить, убрать, всё, дерево, кустарник, кото...
# 3  [неудовлетворительный, состояние, парадный, на...
# 4                                         [граффити]
# 5  [необходимо, проверить, законность, установка,...
# 6  [уборка, производиться, лестница, очень, грязн...
# 7                                            [мусор]
# 8  [отсутствовать, освещение, лестничный, площадк...
# 9  [делать, благоустройство, никто, убирать, мусо...
#
#                                      reason_category
# 0                                    Благоустройство
# 1                                    Благоустройство
# 2                                    Благоустройство
# 3                                     Содержание МКД
# 4                                    Благоустройство
# 5  Незаконная информационная и (или) рекламная ко...
# 6                                     Содержание МКД
# 7                                    Благоустройство
# 8                                     Содержание МКД
# 9                                    Благоустройство

# %% [markdown]
# ### 3. Выполните векторизацию каждого документа любым способом (можно с помощью своих моделей Word2Vec, при условии, что Word2Vec модели обучались на той же выборке документов; можно использовать другие библиотеки и модели).

# %%
X = list(data['public_petition_text'])
y_str = list(data['reason_category'])
X
# Out:
# [['снег', 'дорога'],
#  ['очистить', 'кабельный', 'киоск', 'реклама'],
#  ['просить',
#   'убрать',
#   'всё',
#   'дерево',
#   'кустарник',
#   'который',
#   'выйти',
#   'предел',
#   'газон',
#   'пешеходный',
#   'зона',
#   'начинать',
#   'подъезд',
#   'подъезд',
#   'фасад',
#   'дом',
#   'сторона',
#   'ул',
#   'наличный'],
#  ['неудовлетворительный', 'состояние', 'парадный', 'надпись', 'дверь', 'этаж'],
#  ['граффити'],
#  ['необходимо',
#   'проверить',
#   'законность',
#   'установка',
#   'вывеска',
#   'фасад',
#   'мкд',
#   'адрес',
#   'проспект',
#   'непокорённый',
#   'случай',
#   'вывеска',
#   'установить',
#   'незаконно',
#   'её',
#   'необходимо',
#   'демонтировать'],
#  ['уборка',
#   'производиться',
#   'лестница',
#   'очень',
#   'грязно',
#   'весь',
#   'этаж',
#   'вплоть',
#   'го',
#   'звонок',
#   'жкс',
#   'дать',
#   'результат'],
#  ['мусор'],
#  ['отсутствовать', 'освещение', 'лестничный', 'площадка', 'этаж', 'парадный'],
#  ['делать', 'благоустройство', 'никто', 'убирать', 'мусор', 'ежедневно'],
#  ['просьба', 'закрасить'],
#  ['реклама', 'забор'],
#  ['снег', 'тротуар', 'убрать'],
#  ['проблема', 'регулярный', 'вывоз', 'мусор'],
#  ['рисунок'],
#  ['пожалуйста',
#   'удалить',
#   'бетонный',
#   'обрубка',
#   'ржавый',
#   'арматура',
#   'газон',
#   'дом',
#   'адрес',
#   'улица',
#   'тухачевский',
#   'далее'],
#  ['мусор', 'асфальт'],
#  ['ланский',
#   'шоссе',
#   'парадный',
#   'повредить',
#   'почтовый',
#   'ящик',
#   'просить',
#   'заменить'],
#  ['кривой', 'висеть', 'просьба', 'поправить', 'подьезд', 'этаж'],
#  ['плохой',
#   'уборка',
#   'улица',
#   'мусор',
#   'тротуар',
#   'газон',
#   'прямо',
#   'офис',
#   'муниципал'],
#  ['надпись', 'забор'],
#  ['убрать'],
#  ['частично', 'разрушить', 'ограждение', 'контейнерный', 'площадка'],
#  ['демонтаж',
#   'рекламный',
#   'вывеска',
#   'фасад',
#   'образоваться',
#   'повреждение',
#   'требоваться',
#   'произвести',
#   'работа',
#   'качественный',
#   'восстановление',
#   'штукатурный',
#   'окрасочный',
#   'слой',
#   'соответствовать',
#   'колерный',
#   'палитра',
#   'предварительно',
#   'подготовить',
#   'поверхность',
#   'оштукатурить',
#   'удалить',
#   'грязь',
#   'неровность',
#   'фотофиксация',
#   'прилагаться'],
#  ['надпись', 'стена'],
#  ['м',
#   'этаж',
#   'й',
#   'парадный',
#   'лифтовый',
#   'холл',
#   'скол',
#   'напольный',
#   'плитка'],
#  ['очистить'],
#  ['неудовлетворительный', 'состояние', 'покрытие'],
#  ['неудовлетворительный',
#   'состояние',
#   'парадный',
#   'потрескаться',
#   'штукатурка',
#   'облезлый',
#   'краска',
#   'входной',
#   'холл'],
#  ['дом',
#   'регулярно',
#   'отключать',
#   'горячий',
#   'вода',
#   'предупреждение',
#   'подчёркивать',
#   'протяжение',
#   'довольно',
#   'длительный',
#   'период',
#   'месяц',
#   'отключение',
#   'происходить',
#   'будний',
#   'день',
#   'период'],
#  ['листва', 'газон'],
#  ['реклама', 'опор', 'освещёние'],
#  ['мешок', 'собранный', 'мусор', 'школа'],
#  ['разбитый', 'машина', 'фара'],
#  ['требоваться', 'уборка', 'подъезд'],
#  ['санкт',
#   'петербург',
#   'ул',
#   'ярослав',
#   'гашек',
#   'далее',
#   'подъезд',
#   'несанкционированный',
#   'размещение',
#   'объявление',
#   'дверь',
#   'порча',
#   'общедомовый',
#   'имущество',
#   'мкд',
#   'всё',
#   'объявление',
#   'должный',
#   'размещиться',
#   'информационный',
#   'стенд'],
#  ['улица',
#   'халтурин',
#   'рядом',
#   'пешеходный',
#   'переход',
#   'напротив',
#   'дом',
#   'больший',
#   'яма'],
#  ['мусор', 'вне', 'контейнер'],
#  ['вывозить', 'мусор'],
#  ['очистить', 'столб', 'реклама', 'оставлять', 'след', 'бумага', 'клей'],
#  ['просьба', 'покрасить', 'почтовый', 'ящик'],
#  ['первый',
#   'центральный',
#   'парадный',
#   'жилой',
#   'дом',
#   'адрес',
#   'гражданский',
#   'проспект',
#   'дом',
#   'корпус',
#   'литера',
#   'центр',
#   'общеквартирный',
#   'коридор',
#   'шестой',
#   'этаж',
#   'парадный',
#   'район',
#   'лифтовый',
#   'площадка',
#   'незаконно',
#   'храниться',
#   'старый',
#   'грязный',
#   'выкинуть',
#   'деревянный',
#   'дверь',
#   'просить',
#   'убрать'],
#  ['первый',
#   'этаж',
#   'разбитый',
#   'стекло',
#   'дверь',
#   'сторона',
#   'двор',
#   'просить',
#   'заменить',
#   'спасибо'],
#  ['решётка'],
#  ['добрый',
#   'день',
#   'наш',
#   'дом',
#   'архивный',
#   'пара',
#   'систематически',
#   'работать',
#   'домофон',
#   'неоднократно',
#   'обращаться',
#   'ук',
#   'лично',
#   'ген',
#   'директор',
#   'ук',
#   'эталон',
#   'сервис',
#   'ремонтировать',
#   'привентивный',
#   'просьба',
#   'вмешаться',
#   'дом',
#   'человек',
#   'грудной',
#   'ребёнок',
#   'вынудить',
#   'подниматься',
#   'лесничестница',
#   'попасть',
#   'домой'],
#  ['детский',
#   'площадка',
#   'сломать',
#   'дуга',
#   'удерживать',
#   'верёвочный',
#   'сетка',
#   'который',
#   'ребёнок',
#   'залезать',
#   'горка',
#   'время',
#   'использование',
#   'верёвочный',
#   'сетка',
#   'весь',
#   'конструкция',
#   'сильно',
#   'качаться',
#   'любой',
#   'момент',
#   'мочь',
#   'упасть'],
#  ['придорожный',
#   'парадный',
#   'этаж',
#   'требовать',
#   'привести',
#   'кабель',
#   'канал',
#   'защитный',
#   'крышка',
#   'надлежащий',
#   'состояние'],
#  ['вывозиться', 'строительный', 'мусор', 'территория', 'двор'],
#  ['экскримент', 'лестница', 'необходимо', 'убрать', 'продизенфицировать'],
#  ['гореть', 'фонарь'],
#  ['открыть', 'люк'],
#  ['снег', 'убрать', 'проезжий', 'часть', 'тротуар'],
#  ['парадный',
#   'адрес',
#   'спб',
#   'улица',
#   'лиственный',
#   'дом',
#   'корпус',
#   'пол',
#   'год',
#   'общий',
#   'лестничный',
#   'клетка',
#   'этаж',
#   'лежать',
#   'строительный',
#   'мусор',
#   'который',
#   'никто',
#   'убирать'],
#  ['парадный',
#   'ужасный',
#   'состояние',
#   'внутренний',
#   'покраска',
#   'стена',
#   'краска',
#   'отваливаться',
#   'кусок',
#   'закрасить',
#   'отдельный',
#   'участник',
#   'стена',
#   'подтёк',
#   'стена',
#   'требоваться',
#   'провести',
#   'косметический',
#   'ремонт',
#   'полный',
#   'покраска',
#   'стена'],
#  ['яма', 'асфальт'],
#  ['санкционировать',
#   'размещение',
#   'наружный',
#   'блок',
#   'кондиционер',
#   'портить',
#   'фасад',
#   'дом',
#   'убрать'],
#  ['очистить', 'дорожный', 'знак', 'самоклей'],
#  ['мусор'],
#  ['надпись',
#   'киоск',
#   'напротив',
#   'дом',
#   'колпино',
#   'пр',
#   'ленин',
#   'напротив',
#   'аптека',
#   'лекоптторг'],
#  ['пожалуйста',
#   'восстановить',
#   'асфальт',
#   'второй',
#   'подъезд',
#   'адрес',
#   'улица',
#   'крюков',
#   'далее'],
#  ['граффити'],
#  ['самовольный',
#   'установка',
#   'конструкция',
#   'препятствовать',
#   'парковка',
#   'автотранспорт',
#   'дворовый',
#   'территория',
#   'фасад',
#   'сторона',
#   'щербаков',
#   'пер',
#   'оформить',
#   'общедолевой',
#   'собственность',
#   'земельный',
#   'участок',
#   'данный',
#   'факт',
#   'расценивать',
#   'самозахват',
#   'территория',
#   'просить',
#   'демонтировать',
#   'конструкция',
#   'обеспечить',
#   'исполнение',
#   'управлять',
#   'организация',
#   'дом',
#   'письмо',
#   'предписание',
#   'администрация',
#   'центральный',
#   'район',
#   'ряд',
#   'рамка',
#   'некоторый',
#   'данный',
#   'двор',
#   'дом',
#   'история',
#   'некоторый',
#   'рамка',
#   'обращение',
#   'снять',
#   'привычный',
#   'замок',
#   'однако',
#   'конструкция',
#   'продолжать',
#   'существовать',
#   'замок',
#   'скорее',
#   'весь',
#   'появиться',
#   'близкий',
#   'время',
#   'уровень',
#   'собственник',
#   'управлять',
#   'организация',
#   'данный',
#   'вопрос',
#   'решаться'],
#  ['сквер', 'внутридворовый', 'территория', 'завалить', 'мусор'],
#  ['лужа', 'пешеходный', 'переход'],
#  ['неудовлетворительный',
#   'состояние',
#   'фасад',
#   'дом',
#   'просить',
#   'произвести',
#   'капитальный',
#   'ремонт',
#   'фасад',
#   'жилой',
#   'дом'],
#  ['необходимо', 'покрасить', 'скамейка', 'возле', 'парадный'],
#  ['работать', 'лифт', 'день'],
#  ['сильно',
#   'загрязнить',
#   'территория',
#   'вокруг',
#   'дом',
#   'территория',
#   'газон',
#   'дом',
#   'убираться'],
#  ['яма', 'проезжий', 'часть', 'превышать', 'п', 'п', 'гост', 'р'],
#  ['очистить', 'снег', 'гололёд'],
#  ['парковка', 'машина', 'газон', 'просить', 'поставить', 'ограждение'],
#  ['графити', 'сторона', 'парадный'],
#  ['свет',
#   'подъезд',
#   'этаж',
#   'каждый',
#   'вкручивать',
#   'новый',
#   'лампа',
#   'хватать',
#   'месяц',
#   'необходимо',
#   'разобраться',
#   'причина',
#   'почему',
#   'часто',
#   'перегорать',
#   'лампа'],
#  ['фасад',
#   'отвалиться',
#   'облицовочный',
#   'панель',
#   'плитка',
#   'угрожать',
#   'безопасность',
#   'человек'],
#  ['просить', 'закрасить', 'фасад', 'гараж'],
#  ['парадный',
#   'гореть',
#   'освещение',
#   'обращение',
#   'председатель',
#   'жск',
#   'светлановец',
#   'помогать',
#   'спб',
#   'ул',
#   'гаврскай',
#   'далее',
#   'парадный',
#   'кв',
#   'этаж',
#   'просить',
#   'принять',
#   'мера',
#   'весь',
#   'прочее',
#   'использоваться',
#   'ртуть',
#   'содержать',
#   'лампа'],
#  ['мусор', 'газон', 'бутылка', 'бумага'],
#  ['отмыть', 'стекло', 'парадный', 'номер'],
#  ['просить', 'очистить', 'знак', 'реклама'],
#  ['гнить', 'фасад', 'нужно', 'штукатуривание', 'покраска'],
#  ['газонный', 'ограждение', 'необходимо', 'отремонтировать'],
#  ['перекосить', 'труба', 'установить', 'норматив'],
#  ['парадный', 'этаж', 'работать', 'освещение'],
#  ['оборудование', 'детский', 'площадка', 'требовать', 'ремонт'],
#  ['просадка', 'вокруг', 'колодец'],
#  ['трансформаторный', 'пожстанция', 'нанести', 'надпись'],
#  ['позорище', 'гора', 'мусор', 'свалка', 'придомовый', 'территория'],
#  ['граффити'],
#  ['ранее',
#   'работа',
#   'устранение',
#   'проблема',
#   'слабый',
#   'напор',
#   'холодный',
#   'вода',
#   'устранить',
#   'некачественно',
#   'эффект',
#   'временный',
#   'проблема',
#   'вернуться',
#   'замена',
#   'труба',
#   'хвс',
#   'произвести',
#   'весь',
#   'стояк',
#   'лишь',
#   'частично',
#   'невозможно',
#   'разбавить',
#   'горячий',
#   'вода',
#   'перепад',
#   'слабый',
#   'напор',
#   'приходиться',
#   'набирать',
#   'вода',
#   'ведро',
#   'помыться',
#   'обжечь',
#   'тело',
#   'вода',
#   'течь',
#   'тонкий',
#   'струя',
#   'посуда',
#   'проблемный',
#   'помыть'],
#  ['мусор', 'внутридворовый', 'территория', 'ул', 'крупский'],
#  ['ходить'],
#  ['здравствуйте', 'ужасный', 'состояние', 'парадный'],
#  ['ограждение', 'газон', 'сильно', 'заржавелый', 'необходимый', 'покраска'],
#  ['возможность',
#   'падение',
#   'опора',
#   'уличный',
#   'освещение',
#   'фонарный',
#   'столб'],
#  ['добрый',
#   'день',
#   'протечка',
#   'паркинг',
#   'улица',
#   'адмирал',
#   'трибуц',
#   'дом',
#   'нижний',
#   'уровень',
#   'около',
#   'вход',
#   'ую',
#   'парадный',
#   'фото',
#   'сделать',
#   'проблема',
#   'актуальный',
#   'каждый',
#   'год',
#   'весна',
#   'либо',
#   'время',
#   'сильный',
#   'осадки',
#   'обращение',
#   'офис',
#   'управлять',
#   'компания',
#   'сообщить',
#   'проблема',
#   'решаться',
#   'помощь',
#   'уборочный',
#   'машинка',
#   'который',
#   'ремонт',
#   'также',
#   'ук',
#   'сообщить',
#   'избавиться',
#   'протечка',
#   'проблема',
#   'актуальный',
#   'ук',
#   'ответить',
#   'вода',
#   'появиться',
#   'снова',
#   'уборка',
#   'просить',
#   'основательный',
#   'решение',
#   'проблема',
#   'спасибо'],
#  ['проезжать',
#   'часть',
#   'дорога',
#   'двор',
#   'очень',
#   'грязный',
#   'уборка',
#   'производиться',
#   'неудовлетворительно',
#   'сей',
#   'пора',
#   'асфальт',
#   'остаток',
#   'песчаный',
#   'смесь',
#   'который',
#   'рассыпать',
#   'зимой',
#   'середина',
#   'апрель',
#   'просить',
#   'провести',
#   'уборка',
#   'отмыть',
#   'дорога',
#   'двор',
#   'песок',
#   'грязь'],
#  ['ролгод'],
#  ['мусор', 'возле', 'контейнерный', 'площадка'],
#  ['спб',
#   'ул',
#   'кор',
#   'ая',
#   'парадный',
#   'отсутствовать',
#   'защитный',
#   'плафон',
#   'лампа',
#   'освещение',
#   'этаж'],
#  ['тсодда',
#   'длительный',
#   'время',
#   'разместить',
#   'несанкционированный',
#   'рекламный',
#   'объявление'],
#  ['рекламный', 'щит', 'весь', 'исписать'],
#  ['растрескивание', 'отделочный', 'материал', 'квартирный', 'холл', 'этаж'],
#  ['песок'],
#  ['добрый',
#   'день',
#   'недавно',
#   'двор',
#   'дом',
#   'адрес',
#   'гражданский',
#   'проспект',
#   'производиться',
#   'работа',
#   'ремонт',
#   'дорога',
#   'благоустройство',
#   'придомовый',
#   'территория',
#   'число',
#   'привести',
#   'восстановить',
#   'газон',
#   'территория',
#   'прилегать',
#   'детский',
#   'площадка',
#   'также',
#   'пустырь',
#   'находиться',
#   'электрический',
#   'подстанция',
#   'число',
#   'закрытый',
#   'дверной',
#   'оконный',
#   'проём',
#   'забросить',
#   'строение',
#   'который',
#   'попытка',
#   'организация',
#   'свалка',
#   'мусор',
#   'предотвращение',
#   'парковка',
#   'автотранспорт',
#   'восстановить',
#   'газон',
#   'установить',
#   'ограничитель',
#   'полусфера',
#   'данный',
#   'момент',
#   'сфера',
#   'отсутствовать',
#   'газон',
#   'осуществляться',
#   'парковка',
#   'автотранспорт',
#   'весь',
#   'газон',
#   'превратиться',
#   'разъездить',
#   'дорога',
#   'просить',
#   'дать',
#   'разъяснение',
#   'почему',
#   'благоустроенный',
#   'территория',
#   'превратиться',
#   'отстойник',
#   'автомобиль'],
#  ['неубранный', 'снег', 'тротуар'],
#  ['неубранный', 'снег', 'скользко', 'требоваться', 'посыпка'],
#  ['уборка', 'производиться', 'большой', 'месяц', 'проставляться', 'день'],
#  ['светить'],
#  ['надпись',
#   'похожий',
#   'свастика',
#   'фашистский',
#   'двор',
#   'напротив',
#   'детский',
#   'площадка'],
#  ['двор', 'снег', 'убрать', 'ещё', 'гололёд', 'лужа'],
#  ['незаконный', 'реклама', 'фасад', 'здание'],
#  ['надпись', 'будка'],
#  ['решётка'],
#  ['подъезд',
#   'мусоропровод',
#   'этаж',
#   'отсутствовать',
#   'освещение',
#   'фото',
#   'прилагаться'],
#  ['просьба', 'закрасить', 'смыть', 'граффити', 'парадный'],
#  ['подъезд',
#   'крайний',
#   'левый',
#   'лифт',
#   'неисправный',
#   'освещение',
#   'работать',
#   'светильник',
#   'второй',
#   'светить',
#   'еле',
#   'еле',
#   'председатель',
#   'тсж',
#   'ленинградский',
#   'вечер',
#   'отказываться',
#   'принимать',
#   'заявка',
#   'устранение',
#   'полгода',
#   'это',
#   'ежегодно',
#   'содержание',
#   'общий',
#   'имущество',
#   'дом',
#   'тратиться',
#   'млн',
#   'рубль',
#   'текущий',
#   'ремонт',
#   'общий',
#   'имущество',
#   'дом',
#   'тратиться',
#   'млн',
#   'рубль',
#   'содержание',
#   'председатель',
#   'окружение',
#   'млн',
#   'рубль'],
#  ['шланг',
#   'этаж',
#   'парадный',
#   'сотрудник',
#   'строитель',
#   'перекладывать',
#   'оборудование',
#   'ящик',
#   'каждый'],
#  ['граффити'],
#  ['убрать'],
#  ['неисправный',
#   'домофон',
#   'появиться',
#   'несанкционированный',
#   'надпись',
#   'подъездный',
#   'стена',
#   'этаж',
#   'доска',
#   'объявление',
#   'прикрутить',
#   'стена'],
#  ['реклама', 'пассажирский', 'лифт', 'подъезд'],
#  ['неудовлетворительный', 'состояние', 'покрытие'],
#  ['объявление'],
#  ['иметься', 'просадка', 'грунт'],
#  ['лестница',
#   'выше',
#   'первый',
#   'этаж',
#   'убирать',
#   'жилец',
#   'пытаться',
#   'подметать',
#   'график',
#   'висеть',
#   'соблюдаться'],
#  ['повредить', 'водосточный', 'труба', 'го', 'подъезд'],
#  ['незаконный',
#   'вывеска',
#   'рекламный',
#   'конструкция',
#   'адрес',
#   'санкт',
#   'петербург',
#   'митрофаньевский',
#   'широта',
#   'далее',
#   'установка',
#   'сверху'],
#  ['просаливаться', 'плитка', 'арка', 'многоквартирный', 'дом'],
#  ['проблема',
#   'находиться',
#   'адрес',
#   'спб',
#   'пушкин',
#   'ул',
#   'ленинградский',
#   'парадный',
#   'проблема',
#   'фиксатор',
#   'магнит',
#   'конец',
#   'закрываться',
#   'дверь',
#   'образоваться',
#   'конденсат',
#   'обратный',
#   'сторона',
#   'просить',
#   'устранить',
#   'спасибо'],
#  ['территория',
#   'двор',
#   'ужасный',
#   'состояние',
#   'проход',
#   'человек',
#   'двор',
#   'возможный',
#   'проезжий',
#   'часть',
#   'вдоль',
#   'весь',
#   'дом',
#   'данный',
#   'момент',
#   'время',
#   'конец',
#   'март',
#   'год',
#   'двор',
#   'огромный',
#   'лужа',
#   'ехать',
#   'машина',
#   'двор',
#   'человек',
#   'деться',
#   'некуда',
#   'асфальтовый',
#   'покрытие',
#   'двор',
#   'ремонтироваться',
#   'десяток',
#   'год'],
#  ['отсутствовать', 'крышка', 'технический', 'люк', 'опор', 'освещение'],
#  ['просить', 'удалить', 'граффити', 'стена'],
#  ['мешок', 'мусор', 'лежать', 'большой', 'год'],
#  ['пара',
#   'стеклопакет',
#   'закрепить',
#   'надлежащий',
#   'образ',
#   'требоваться',
#   'установить',
#   'крепёжный',
#   'планка',
#   'стекло'],
#  ['бытовой',
#   'мусор',
#   'куст',
#   'вдоль',
#   'забор',
#   'строительный',
#   'площадка',
#   'просьба',
#   'убрать'],
#  ['бумажный', 'объявление', 'опор'],
#  ['бетонный', 'кольцо', 'пандус'],
#  ['решётка', 'первый', 'этаж', 'помойка'],
#  ['надпись'],
#  ['секция',
#   'этаж',
#   'закрываться',
#   'конец',
#   'дверь',
#   'неисправность',
#   'доводчик',
#   'который',
#   'мочь',
#   'помочь',
#   'дверь',
#   'закрыться',
#   'сквозняк'],
#  ['тамбур',
#   'первый',
#   'этаж',
#   'пол',
#   'лежать',
#   'собачий',
#   'экскремент',
#   'просить',
#   'выполнить',
#   'уборка'],
#  ['объявление', 'знак'],
#  ['очистить',
#   'дорожный',
#   'знак',
#   'самоклеящийся',
#   'реклама',
#   'оставлять',
#   'след',
#   'бумага',
#   'клей'],
#  ['фото',
#   'указать',
#   'этаж',
#   'устранить',
#   'вложение',
#   'фото',
#   'сделать',
#   'минута',
#   'назад'],
#  ['мусор', 'убираться'],
#  ['добрый',
#   'день',
#   'просить',
#   'устранить',
#   'надпись',
#   'угол',
#   'дом',
#   'заранее',
#   'благодарный'],
#  ['мусор'],
#  ['отсутствовать',
#   'качели',
#   'детский',
#   'площадка',
#   'необходимо',
#   'восстановить'],
#  ['несанкционированный', 'надпись', 'сооружение'],
#  ['просьба', 'привести', 'павильон', 'надлежащий', 'вид'],
#  ['объявление'],
#  ['граффити', 'киоск'],
#  ['неудовлетворительный', 'уборка', 'параднойгрязь', 'лужа', 'первый', 'этаж'],
#  ['куча', 'мусор', 'газон', 'вокруг', 'трансформаторный', 'подстанция'],
#  ['требоваться',
#   'произвести',
#   'работа',
#   'качественный',
#   'очистка',
#   'остановочный',
#   'павильон',
#   'несанкционированный',
#   'рекламный',
#   'объявление',
#   'оставлять',
#   'след',
#   'фотофиксация',
#   'прилагаться'],
#  ['неудовлетворительный',
#   'состояние',
#   'лифт',
#   'пассажирский',
#   'грузовой',
#   'первый',
#   'парадный',
#   'всё',
#   'стена',
#   'обцарапать',
#   'разрисовать'],
#  ['плохо', 'убрать', 'снег', 'край', 'проезжий', 'часть'],
#  ['контейнер',
#   'расположить',
#   'предел',
#   'контейнерный',
#   'площадка',
#   'нарушение',
#   'распоряжение',
#   'комитет',
#   'благоустройство',
#   'санкт',
#   'петербург',
#   'ноябрь',
#   'год',
#   'n',
#   'р',
#   'утверждение',
#   'порядок',
#   'накопление',
#   'твёрдый',
#   'коммунальный',
#   'отход',
#   'число',
#   'раздельный',
#   'накопление',
#   'территория',
#   'санкт',
#   'петербург',
#   'п',
#   'цель',
#   'обеспечение',
#   'надлежащий',
#   'накопление',
#   'твёрдый',
#   'коммунальный',
#   'отход',
#   'запретить',
#   'выставлять',
#   'контейнер',
#   'предел',
#   'контейнерный',
#   'площадка',
#   'ранее',
#   'час',
#   'прибытие',
#   'мусоровоз',
#   'устанавливать',
#   'контейнер',
#   'бункер',
#   'предел',
#   'контейнерный',
#   'площадка'],
#  ['неубранный', 'снег', 'дорога'],
#  ['рисунок', 'стена'],
#  ['западный',
#   'часть',
#   'дом',
#   'деформировать',
#   'разрушить',
#   'водосточный',
#   'труба',
#   'украсть',
#   'нижний',
#   'секция',
#   'отлив'],
#  ['ям', 'аварийный', 'состояние'],
#  ['надпись', 'забор'],
#  ['первый',
#   'этаж',
#   'чёрный',
#   'лестница',
#   'входной',
#   'дверь',
#   'удовлетворительный',
#   'состояние',
#   'первый',
#   'парадный'],
#  ['необходимо',
#   'снять',
#   'дерево',
#   'мусор',
#   'рваный',
#   'одежда',
#   'тряпка',
#   'сбросить',
#   'жилец',
#   'балкон',
#   'дерево',
#   'вход',
#   'парадный',
#   'жилой',
#   'дом',
#   'адрес',
#   'пр',
#   'наука',
#   'калининский',
#   'район',
#   'санкт',
#   'петербург'],
#  ['просить', 'убрать', 'надпись'],
#  ['машина',
#   'привозить',
#   'продуктовый',
#   'магазин',
#   'товар',
#   'заезжать',
#   'тротуар',
#   'пешеходный',
#   'зона',
#   'блокировать',
#   'проход',
#   'шум',
#   'окно',
#   'жилой',
#   'дом',
#   'просить',
#   'поставить',
#   'преграда',
#   'сторона',
#   'двор',
#   'первый',
#   'подъезд',
#   'дом',
#   'ул',
#   'шостакович',
#   'магазин',
#   'шаг'],
#  ['пожалуйста',
#   'убрать',
#   'старый',
#   'шпала',
#   'щит',
#   'доска',
#   'который',
#   'валяться',
#   'канава',
#   'дорога',
#   'улица',
#   'овражный',
#   'напротив',
#   'дом',
#   'мешать',
#   'чистка',
#   'канава',
#   'сторона',
#   'улица',
#   'сосновый',
#   'шпала',
#   'валяться'],
#  ['здравствуйте',
#   'разрисовать',
#   'дверь',
#   'лифт',
#   'внутри',
#   'снаружи',
#   'подъезд',
#   'й'],
#  ['упавший', 'дерево'],
#  ['несанкционированный', 'объявление', 'опор', 'освещение'],
#  ['надпись', 'короб', 'электрощиток', 'фотофиксация'],
#  ['необходимо',
#   'удалить',
#   'несанкционированный',
#   'рисунок',
#   'второй',
#   'этаж',
#   'второй',
#   'подъезд'],
#  ['мусор'],
#  ['реклама', 'будка'],
#  ['утрата',
#   'жизнеспособность',
#   'декоративный',
#   'ценность',
#   'зелёный',
#   'насаждение'],
#  ['передача',
#   'общий',
#   'имущество',
#   'часть',
#   'лестничный',
#   'холл',
#   'весь',
#   'собственник',
#   'мкд',
#   'незаконный',
#   'пользование',
#   'собственник',
#   'кв',
#   'xxx',
#   'иметься',
#   'судебный',
#   'акт',
#   'отмена',
#   'весь',
#   'решение',
#   'осс',
#   'включая',
#   'передача',
#   'пользование',
#   'часть',
#   'общий',
#   'имущество'],
#  ['мусор'],
#  ['адрес',
#   'вознесенский',
#   'пр',
#   'далее',
#   'входной',
#   'дверь',
#   'лестничный',
#   'клетка',
#   'просьба',
#   'покрасить',
#   'дверной',
#   'ручка',
#   'цвет',
#   'дверь'],
#  ['провал',
#   'асфальтовый',
#   'покрытие',
#   'вследствие',
#   'образоваться',
#   'лужа',
#   'образоваться',
#   'трещина',
#   'покрытие',
#   'просьба',
#   'восстановить'],
#  ['маляр', 'попадать', 'цвет'],
#  ['мусор', 'грязь'],
#  ['яма', 'асфальт', 'сторона', 'парадный', 'садик'],
#  ['граффити', 'забор'],
#  ['вандальный', 'надпись', 'фасад', 'дом', 'ул', 'чебышевский'],
#  ['ремонт',
#   'парадный',
#   'адрес',
#   'московский',
#   'проспект',
#   'дом',
#   'лестница',
#   'проводиться',
#   'около',
#   'год',
#   'жилец',
#   'парадный',
#   'неоднократно',
#   'писать',
#   'обращение',
#   'необходимость',
#   'проведение',
#   'косметический',
#   'ремонт',
#   'ооо',
#   'жилкомсервис',
#   'московский',
#   'район',
#   'обещать',
#   'срок',
#   'ремонт',
#   'постоянно',
#   'переноситься',
#   'согласно',
#   'письмо',
#   'ооо',
#   'жкс',
#   'письмо',
#   'прилагаться',
#   'косметический',
#   'ремонт',
#   'парадный',
#   'включить',
#   'план',
#   'текущий',
#   'ремонт',
#   'год',
#   'состояние',
#   'ремонт',
#   'произвести',
#   'состояние',
#   'парадный',
#   'требовать',
#   'косметический',
#   'ремонт',
#   'ободрать',
#   'краска',
#   'скол',
#   'стена',
#   'потолок',
#   'свисать',
#   'штукатурка',
#   'весь',
#   'лестница',
#   'хаотичный',
#   'порядок',
#   'висеть',
#   'электропроводка',
#   'просить',
#   'обязать',
#   'ооо',
#   'жилкомсервис',
#   'московский',
#   'район',
#   'сделать',
#   'косметический',
#   'ремонт',
#   'парадный',
#   'спрятать',
#   'специальный',
#   'короб',
#   'электропроводка',
#   'закрыть',
#   'электрощиток',
#   'утеплить',
#   'входной',
#   'дверь',
#   'парадный'],
#  ['объявление', 'дом'],
#  ['стена',
#   'дом',
#   'литера',
#   'улица',
#   'курский',
#   'обнаружить',
#   'несанкционированый',
#   'надпись',
#   'просьба',
#   'устранить',
#   'проблема'],
#  ['убрать', 'снег', 'дорога'],
#  ['просить',
#   'проверить',
#   'восстановить',
#   'система',
#   'освещение',
#   'моп',
#   'парадный'],
#  ['осуществляться',
#   'уборка',
#   'подъезд',
#   'лифтовый',
#   'кабина',
#   'ук',
#   'последний',
#   'произвести',
#   'уборка',
#   'подъезд',
#   'уборка',
#   'влажный',
#   'сухой',
#   'выше',
#   'го',
#   'этаж',
#   'проводиться',
#   'март'],
#  ['требоваться',
#   'эвакуация',
#   'разукомплектовать',
#   'транспортный',
#   'средство',
#   'находиться',
#   'жилой',
#   'многоквартирный',
#   'дом',
#   'адрес',
#   'г',
#   'санкт',
#   'петербург',
#   'п',
#   'парголово',
#   'ул',
#   'фёдор',
#   'абрамов',
#   'напротив',
#   'магазин',
#   'магнит',
#   'косметика',
#   'который',
#   'препятствовать',
#   'осуществление',
#   'мероприятие',
#   'содержание',
#   'объект',
#   'благоустройство',
#   'также',
#   'создавать',
#   'помеха',
#   'подъезд',
#   'спецтранспорт',
#   'муровоз',
#   'одновременно',
#   'это',
#   'наличие',
#   'бросить',
#   'разукомплектовать',
#   'транспортный',
#   'средство',
#   'непосредственный',
#   'близость',
#   'мкд',
#   'создавать',
#   'повышенный',
#   'риск',
#   'умышленный',
#   'поджог',
#   'использование',
#   'противозаконный',
#   'действие',
#   'против',
#   'гражданин',
#   'транспортный',
#   'средство',
#   'отсутствовать',
#   'замок',
#   'дверь',
#   'кузов',
#   'кабина',
#   'пробка',
#   'топливный',
#   'бак',
#   'также',
#   'разбитый',
#   'внешний',
#   'световой',
#   'прибор',
#   'прогнить',
#   'насквозь',
#   'всё',
#   'элемент',
#   'кузов',
#   'весь',
#   'периметр'],
#  ['надпись', 'дом'],
#  ['неубранный', 'снег', 'требоваться', 'посыпка'],
#  ['добрый',
#   'день',
#   'просить',
#   'очистить',
#   'граффити',
#   'заранее',
#   'благодарить'],
#  ['гореть'],
#  ['объявление'],
#  ['необходимо',
#   'восстановить',
#   'окраска',
#   'фасад',
#   'единый',
#   'колерный',
#   'бланк'],
#  ['снег', 'дорога'],
#  ['вода', 'течь', 'холодный', 'месяц'],
#  ['восстановить',
#   'энергосберегающий',
#   'освещение',
#   'лестничный',
#   'марш',
#   'этаж',
#   'ответ',
#   'исполнитель',
#   'фото',
#   'сторона',
#   'энергосберегающий',
#   'лампа',
#   'этаж',
#   'конец',
#   'коридор',
#   'установить',
#   'запрос',
#   'первичный',
#   'сообщение',
#   'заявитель',
#   'выполнить',
#   'очень',
#   'темно',
#   'конец',
#   'коридор'],
#  ['мусор', 'дорога'],
#  ['необходимый', 'ремонт', 'гараж'],
#  ['нарушить',
#   'пожарный',
#   'безопасность',
#   'отсутствовать',
#   'пожарный',
#   'рукав',
#   'этаж',
#   'этаж',
#   'парадный'],
#  ['фасад',
#   'дом',
#   'гражданский',
#   'ул',
#   'торчать',
#   'провод',
#   'опасно',
#   'некрасиво'],
#  ['гореть', 'фонарь'],
#  ['грязный',
#   'лифт',
#   'регулярный',
#   'уборка',
#   'прежний',
#   'отсутствовать',
#   'просить',
#   'наладить',
#   'регулярность',
#   'уборка',
#   'обращение'],
#  ['незаконный', 'надпись', 'павильон', 'нужно', 'очистить'],
#  ['антенна'],
#  ['сломать',
#   'входной',
#   'металлический',
#   'дверь',
#   'сварочный',
#   'шов',
#   'расходиться',
#   'дверь',
#   'расслаиваться',
#   'нужно',
#   'восстановить',
#   'заварить',
#   'покрасить',
#   'парадный'],
#  ['поставить',
#   'второй',
#   'створка',
#   'тамбурный',
#   'дверь',
#   'смысл',
#   'дверь',
#   'теряться',
#   'очень',
#   'сильно',
#   'продувать'],
#  ['сдать',
#   'дом',
#   'горячий',
#   'вода',
#   'справляться',
#   'насос',
#   'жк',
#   'полис',
#   'комендантский',
#   'секция',
#   'адрес',
#   'ул',
#   'плесецкий',
#   'стр'],
#  ['надпись', 'стена'],
#  ['песок',
#   'вдоль',
#   'дом',
#   'придомовый',
#   'территория',
#   'требоваться',
#   'ручной',
#   'уборка',
#   'непосредственно',
#   'стена',
#   'дом',
#   'вазон'],
#  ['лист',
#   'проезжий',
#   'часть',
#   'требоваться',
#   'произвести',
#   'механизировать',
#   'ручной',
#   'уборка',
#   'фотофиксация',
#   'прилагаться'],
#  ['лужа',
#   'твёрдый',
#   'покрытие',
#   'дождь',
#   'таяние',
#   'снег',
#   'невозможно',
#   'пройти',
#   'коляска',
#   'просить',
#   'решить',
#   'проблема',
#   'просить',
#   'решить',
#   'проблема',
#   'проблема',
#   'решить',
#   'вода',
#   'скапливаться',
#   'постоянно',
#   'дождь',
#   'таяние',
#   'снег',
#   'давать',
#   'возможность',
#   'пройти',
#   'коляска',
#   'ребёнок',
#   'пожилой',
#   'человек',
#   'фотография',
#   'сделать',
#   'отсутсвовать',
#   'правильный',
#   'наклон',
#   'асфальтовый',
#   'покрытие',
#   'позволять',
#   'обеспечить',
#   'целевой',
#   'использование',
#   'данный',
#   'участок',
#   'пешеходный',
#   'дорога',
#   'подготовить',
#   'ответ',
#   'похожий',
#   'отписка',
#   'нежелание',
#   'решить',
#   'указанный',
#   'проблема'],
#  ['просить',
#   'провести',
#   'уборка',
#   'подъезд',
#   'уборка',
#   'проводиться',
#   'август',
#   'адрес',
#   'литейный',
#   'проспект',
#   'дом',
#   'квартира'],
#  ['просьба', 'проверить', 'кондиционер'],
#  ['просить',
#   'убрать',
#   'ствол',
#   'дерево',
#   'который',
#   'развернуться',
#   'сторона',
#   'окно',
#   'дом'],
#  ['надпись', 'дверь'],
#  ['отсутствовать',
#   'освещение',
#   'лестничный',
#   'клетка',
#   'номер',
#   'первый',
#   'второй',
#   'этаж'],
#  ['мусор', 'контейнерный', 'площадка'],
#  ['работать',
#   'фонарь',
#   'уличный',
#   'освещение',
#   'двор',
#   'ой',
#   'парадный',
#   'ул',
#   'полярник',
#   'далее'],
#  ['мусор'],
#  ['незаконный',
#   'размещение',
#   'рекламный',
#   'стойка',
#   'газон',
#   'территория',
#   'общий',
#   'имущество',
#   'собственник',
#   'дом',
#   'находиться',
#   'газон',
#   'возле',
#   'выезд',
#   'паркинг',
#   'улица',
#   'парфёновский',
#   'возле',
#   'цветочный',
#   'магазин'],
#  ['надпись', 'дорожный', 'знак'],
#  ['день',
#   'весь',
#   'лестница',
#   'этаж',
#   'кровь',
#   'никто',
#   'жилкомсервис',
#   'убирать',
#   'лестница',
#   'мыть',
#   'месяц',
#   'хотя',
#   'норматив',
#   'первый',
#   'этаж',
#   'ящик',
#   'должный',
#   'убирать',
#   'каждый',
#   'день',
#   'весь',
#   'лестница',
#   'неделя',
#   'парадный',
#   'жить',
#   'ребёнок',
#   'который',
#   'бояться',
#   'ходить',
#   'лестница',
#   'плач',
#   'уборка',
#   'лестница',
#   'исправно',
#   'хотеть',
#   'жить',
#   'чистый',
#   'парадный'],
#  ['незаконный',
#   'решётка',
#   'фасад',
#   'нарушение',
#   'противопожарный',
#   'тб',
#   'всё',
#   'решётка',
#   'однотипный',
#   'относиться',
#   'помещение'],
#  ['требоваться', 'уборка', 'территория'],
#  ['знак', 'зацепиться', 'провод', 'починить'],
#  ['повреждение',
#   'дорожный',
#   'покрытие',
#   'проезжий',
#   'часть',
#   'выбоина',
#   'неровность',
#   'выкрашивание',
#   'просадка',
#   'шурф',
#   'требоваться',
#   'произвести',
#   'работа',
#   'качественный',
#   'ремонт',
#   'асфальтовый',
#   'покрытие',
#   'устранить',
#   'аварийность',
#   'информация',
#   'кртеть',
#   'год',
#   'запланировать',
#   'ремонт',
#   'пр',
#   'обуховский',
#   'оборона',
#   'число',
#   'указанный',
#   'место',
#   'возможность',
#   'перенести',
#   'ответ',
#   'промежуточный',
#   'всесторонний',
#   'комплексный',
#   'устранение',
#   'дефект',
#   'аналогия',
#   'обращение',
#   'https',
#   'gorod',
#   'gov',
#   'spb',
#   'ru',
#   'problems',
#   'https',
#   'gorod',
#   'gov',
#   'spb',
#   'ru',
#   'problems',
#   'https',
#   'gorod',
#   'gov',
#   'spb',
#   'ru',
#   'problems',
#   'https',
#   'gorod',
#   'gov',
#   'spb',
#   'ru',
#   'problems',
#   'https',
#   'gorod',
#   'gov',
#   'spb',
#   'ru',
#   'problems',
#   'фотофиксация',
#   'прилагаться'],
#  ['добрый',
#   'день',
#   'парадный',
#   'находиться',
#   'неудовлетворительный',
#   'состояние',
#   'необходимый',
#   'уборка',
#   'весь',
#   'подъезд',
#   'особый',
#   'внимание',
#   'хотеться',
#   'обратить',
#   'мусор',
#   'входной',
#   'дверь',
#   'фото',
#   'мусор',
#   'лестничный',
#   'клетка',
#   'этаж',
#   'фото',
#   'также',
#   'этаж',
#   'лестничный',
#   'клетка',
#   'фото'],
#  ['баск',
#   'переулок',
#   'дом',
#   'неубранный',
#   'снег',
#   'посыпать',
#   'соль',
#   'наледь',
#   'двор',
#   'жилой',
#   'дом'],
#  ['незаконный', 'рольставень', 'фасад'],
#  ['трос',
#   'препятствовать',
#   'парковка',
#   'ждать',
#   'травма',
#   'ребёнок',
#   'неспособный',
#   'навести',
#   'порядок'],
#  ['надпись', 'будка'],
#  ['газон',
#   'вдоль',
#   'проезжий',
#   'часть',
#   'сей',
#   'пора',
#   'лежать',
#   'опасть',
#   'лист',
#   'очень',
#   'требоваться',
#   'произвести',
#   'работа',
#   'качественный',
#   'уборка',
#   'указанный',
#   'газон',
#   'мусор',
#   'хороший',
#   'эффект',
#   'рекомендовать',
#   'использовать',
#   'грабли',
#   'фотофиксация',
#   'прилагаться'],
#  ['двор',
#   'дом',
#   'корп',
#   'улица',
#   'пограничник',
#   'гарькавый',
#   'отсутствовать',
#   'ограждение',
#   'газон',
#   'машина',
#   'заезжать',
#   'газон',
#   'это',
#   'вид',
#   'очень',
#   'неприглядный',
#   'это',
#   'всё',
#   'рядом',
#   'районный',
#   'поликлиника'],
#  ['незаконный', 'решётка', 'фасад'],
#  ['отсутствовать',
#   'покрытие',
#   'рекламный',
#   'конструкция',
#   'ржавчина',
#   'выглядеть',
#   'неопрятно',
#   'требоваться',
#   'привести',
#   'конструкция',
#   'надлежащий',
#   'состояние',
#   'безопасно',
#   'крепление',
#   'конструкция',
#   'коррозия',
#   'фотофиксация',
#   'прилагаться'],
#  ['граффити',
#   'стена',
#   'дом',
#   'рядом',
#   'арка',
#   'напротив',
#   'детский',
#   'площадка'],
#  ['отсутствовать', 'адресный', 'вывеска', 'название', 'улица', 'номер', 'дом'],
#  ['дорога',
#   'покрыть',
#   'водорастворимый',
#   'асфальт',
#   'просить',
#   'восстановить',
#   'покрытие'],
#  ['неубранный', 'снег', 'проезд'],
#  ['весь',
#   'этаж',
#   'парадный',
#   'неудовлетворительный',
#   'состояние',
#   'окраска',
#   'потолок',
#   'окрасить',
#   'пятно',
#   'этаж',
#   'второе',
#   'остаться',
#   'всё',
#   'остальной',
#   'этаж',
#   'прежний',
#   'нуждаться',
#   'покраска'],
#  ['контейнерный',
#   'площадка',
#   'отсутствовать',
#   'кусок',
#   'стена',
#   'вид',
#   'неопрятный',
#   'грязно',
#   'рядом',
#   'находиться',
#   'школа',
#   'требоваться',
#   'привести',
#   'нормальный',
#   'состояние'],
#  ['несанкционированный', 'надпись'],
#  ['этаж',
#   'парадный',
#   'квартирный',
#   'холл',
#   'очень',
#   'грязно',
#   'предположительно',
#   'домыть',
#   'штукатурка',
#   'пол',
#   'ремонт',
#   'холл'],
#  ['снег', 'дорога'],
#  ['реклама'],
#  ['здравствуйте',
#   'год',
#   'парадный',
#   'ремонт',
#   'управлять',
#   'компания',
#   'реагировать',
#   'парадный',
#   'страшно',
#   'опасно',
#   'просить',
#   'обратить',
#   'внимание',
#   'перила'],
#  ['повреждение', 'дорожный', 'покрытие', 'проезжий', 'часть'],
#  ['просить', 'отремонтировать', 'асфальт'],
#  ['требоваться', 'произвести', 'уборка'],
#  ['незаконный', 'поперечный', 'реклама', 'фасад', 'памятник', 'архитектура'],
#  ['реклама',
#   'стоить',
#   'xxxx',
#   'xxxxxxx',
#   'x',
#   'xxxxxxxxxxx',
#   'xxxxxx',
#   'xxxx',
#   'xxxxxxxx',
#   'xxxxxxxx',
#   'xxxxxxxxxxxxxx'],
#  ['регулярный',
#   'поломка',
#   'лифтовый',
#   'оборудование',
#   'ой',
#   'парадный',
#   'систематически',
#   'отключаться',
#   'грузовой',
#   'лифт'],
#  ['разбитый', 'асфальт'],
#  ['добрый',
#   'день',
#   'просить',
#   'открыть',
#   'подвальный',
#   'окно',
#   'продух',
#   'подъезд',
#   'настоящий',
#   'время',
#   'оно',
#   'плотно',
#   'закрытый',
#   'щит',
#   'смотреть',
#   'фото'],
#  ['лестница',
#   'каждый',
#   'день',
#   'расклеивать',
#   'рекламный',
#   'объявление',
#   'парадный',
#   'стена',
#   'дом'],
#  ['работать', 'освещение', 'яхтенный', 'мост'],
#  ['убрать', 'мусор'],
#  ['краска', 'лестница', 'эт'],
#  ['реклама', 'ящик'],
#  ['газон', 'завалить', 'мусор'],
#  ['несанкционированный',
#   'реклама',
#   'парадный',
#   'информационный',
#   'доска',
#   'несколько',
#   'месяц',
#   'висеть',
#   'несогласованный',
#   'жилец',
#   'реклама',
#   'просить',
#   'удалить'],
#  ['лёд',
#   'невозможно',
#   'пройти',
#   'набережная',
#   'львиный',
#   'кокушкина',
#   'пер',
#   'весь',
#   'протяжение',
#   'указанный',
#   'участок',
#   'необходимо',
#   'отработать',
#   'песок',
#   'сломать',
#   'нарост',
#   'лёд'],
#  ['результат',
#   'подключение',
#   'домофонной',
#   'трубка',
#   'обслуживающий',
#   'компания',
#   'наш',
#   'домофон',
#   'повредить',
#   'общий',
#   'имущество',
#   'оборудование',
#   'этажный',
#   'электрический',
#   'щит',
#   'оставить',
#   'мусор',
#   'щит',
#   'закрытый',
#   'короб',
#   'трассировка',
#   'проводы',
#   'з',
#   'парадный',
#   'этаж'],
#  ['сломать',
#   'доводчик',
#   'тамбурный',
#   'дверь',
#   'парадный',
#   'номер',
#   'адрес',
#   'бухарестский',
#   'улица',
#   'дом',
#   'корпус'],
#  ['протечка',
#   'труба',
#   'подвал',
#   'засор',
#   'канализация',
#   'невыносимый',
#   'запах',
#   'весь',
#   'парадный',
#   'проникать',
#   'квартира',
#   'протечка',
#   'регулярный',
#   'месяц'],
#  ['просить',
#   'установить',
#   'ограждение',
#   'автобусный',
#   'остановка',
#   'препятствовать',
#   'подобный',
#   'ситуация'],
#  ['очистить'],
#  ['газон',
#   'железобетонный',
#   'мусор',
#   'вывести',
#   'второй',
#   'фото',
#   'выставить',
#   'мочь',
#   'хороший',
#   'рассмотреть',
#   'проблема'],
#  ['несанкционированный',
#   'реклама',
#   'облицовка',
#   'шахта',
#   'лифт',
#   'этаж',
#   'парадный'],
#  ['очень',
#   'мусор',
#   'газон',
#   'вдоль',
#   'дом',
#   'адрес',
#   'михаил',
#   'дудин',
#   'корпус',
#   'сторона',
#   'улица',
#   'михаил',
#   'дудин',
#   'двор',
#   'чувство',
#   'мусорный',
#   'бак',
#   'перевернуть',
#   'прямо',
#   'газон',
#   'лежать',
#   'суббота'],
#  ['очистить'],
#  ['незаконный', 'реклама', 'висеть'],
#  ['граффити'],
#  ['требоваться',
#   'произвести',
#   'работа',
#   'качественный',
#   'очистка',
#   'опора',
#   'наружное',
#   'освещение',
#   'несанкционированный',
#   'рекламный',
#   'объявление',
#   'оставлять',
#   'след',
#   'фотофиксация',
#   'прилагаться'],
#  ['развернуть', 'дорожный', 'знак', 'остановка'],
#  ['проржаветь', 'конструкция', 'шкаф'],
#  ['грязный', 'стена', 'парадный'],
#  ['законно', 'установить', 'шлагбаум'],
#  ['отсутствовать', 'адресный', 'вывеска', 'название', 'улица', 'номер', 'дом'],
#  ['краска', 'грязь', 'лестница', 'эт'],
#  ['мусор',
#   'вдоль',
#   'суздальский',
#   'пр',
#   'улица',
#   'есенин',
#   'пр',
#   'художник',
#   'мусор',
#   'газон',
#   'убираться',
#   'год'],
#  ['спить',
#   'дерево',
#   'ветка',
#   'убрать',
#   'территория',
#   'зелёный',
#   'насаждение',
#   'также',
#   'газон',
#   'убрать',
#   'прошлогодний',
#   'листва'],
#  ['мелкий', 'мусор', 'собачий', 'отход'],
#  ['реклама', 'щиток'],
#  ['грязь',
#   'весь',
#   'подъезд',
#   'соблюдение',
#   'графика',
#   'уборка',
#   'месяц',
#   'уборка'],
#  ['отсутствовать',
#   'подъёмник',
#   'коляска',
#   'очень',
#   'сложно',
#   'поднять',
#   'коляска',
#   'грудной',
#   'ребёнок'],
#  ['ям', 'внутриквартальный', 'проезд'],
#  ['надпись'],
#  ['лёд',
#   'тротуар',
#   'вблизи',
#   'автобусный',
#   'остановка',
#   'отдельный',
#   'участок',
#   'далёкий',
#   'направление',
#   'красногвардейский',
#   'пл'],
#  ['граффити', 'забор'],
#  ['тротуар',
#   'вдоль',
#   'улица',
#   'мариинский',
#   'проезд',
#   'дом',
#   'б',
#   'напротив',
#   'дом',
#   'покрытие',
#   'тротуар',
#   'ям',
#   'трещина',
#   'дождь',
#   'образоваться',
#   'непроходимый',
#   'лужа',
#   'просить',
#   'отремонтировать',
#   'покрытие',
#   'тротуар',
#   'частично',
#   'заплатка',
#   'весь',
#   'протяжение',
#   'повредить',
#   'участок',
#   'вход',
#   'игровой',
#   'площадка'],
#  ['убрать', 'мусор', 'газон', 'подъезд', 'весь', 'подъезд', 'убрать', 'мусор'],
#  ['повреждение', 'тротуар', 'просить', 'восстановить'],
#  ['отсутствовать',
#   'устройство',
#   'спуск',
#   'маломобильный',
#   'категория',
#   'гражданин',
#   'число',
#   'родитель',
#   'детский',
#   'коляска',
#   'невозможно',
#   'выйти',
#   'прогулка',
#   'жилец',
#   'использовать',
#   'технический',
#   'средство',
#   'передвижение',
#   'проспект',
#   'тореза',
#   'далее',
#   'кор',
#   'подъезд',
#   'несколько',
#   'месяц',
#   'назад',
#   'установить',
#   'пандус',
#   'вход',
#   'дойти',
#   'лифт',
#   'нужно',
#   'преодолеть',
#   'лестница',
#   'внутри',
#   'дом',
#   'соседний',
#   'парадный',
#   'адрес',
#   'складный',
#   'пандус',
#   'который',
#   'успешно',
#   'пользоваться'],
#  ['незаконный',
#   'решётка',
#   'фасад',
#   'всё',
#   'рещётка',
#   'однотипный',
#   'относиться',
#   'помещение'],
#  ['мусоропровод', 'забитый', 'большой', 'неделя', 'первый', 'парадный'],
#  ['мусор', 'проезжий', 'часть', 'прилегать', 'тротуар'],
#  ['неудовлетворительный', 'состояние', 'скамейка', 'площадка'],
#  ['плита'],
#  ['надпись', 'отваливаться', 'краска', 'чёрный', 'лестница', 'этаж'],
#  ['пройти', 'день', 'стоить', 'вода', 'щикододка'],
#  ['парадный',
#   'день',
#   'вонять',
#   'дохлятина',
#   'запах',
#   'проникать',
#   'квартира',
#   'просить',
#   'проверить',
#   'подвал',
#   'подъезд',
#   'предмет',
#   'мёртвый',
#   'животное'],
#  ['работать',
#   'светильник',
#   'перегореть',
#   'лампа',
#   'просьба',
#   'поставить',
#   'светодиодный',
#   'светильник',
#   'лампа'],
#  ['второй',
#   'третий',
#   'парадное',
#   'дом',
#   'корпус',
#   'северный',
#   'проспект',
#   'снова',
#   'лужа',
#   'каждый',
#   'пока',
#   'починить',
#   'ливневый',
#   'канализация',
#   'принять',
#   'мера',
#   'ждать',
#   'пока',
#   'высохнуть',
#   'написать',
#   'ответ',
#   'всё',
#   'сделать'],
#  ['мусор', 'возле', 'подьезда'],
#  ['надпись', 'дверь'],
#  ['убрать', 'листва', 'придомовый', 'территория'],
#  ['ободрать', 'стена', 'дом'],
#  ['просьба', 'стереть', 'надпись', 'спасибо'],
#  ['водосток',
#   'частично',
#   'повредить',
#   'сторона',
#   'линия',
#   'просьба',
#   'отремонтировать'],
#  ['гореть', 'фонарь', 'территория', 'деть', 'сад'],
#  ['крыльцо', 'парадный', 'ступенька', 'обваливаться', 'стенка', 'разрушить'],
#  ['объявление', 'опор'],
#  ['добрый',
#   'день',
#   'этаж',
#   'парадный',
#   'адрес',
#   'загородный',
#   'работать',
#   'лампа',
#   'освещение',
#   'справа',
#   'лифт',
#   'также',
#   'слабо',
#   'освещать',
#   'лампа',
#   'слева',
#   'лифт',
#   'работать',
#   'просить',
#   'устранить',
#   'данный',
#   'неисправность',
#   'xxxxxx',
#   'xx',
#   'xxxxxxx',
#   'xxxxxxxxx',
#   'xxx',
#   'xxx',
#   'xx',
#   'xxxxxxx',
#   'xxxxxxx',
#   'xxx',
#   'xxxxxxxxxx',
#   'xxxxxxxxx',
#   'xxxxxxxxx',
#   'x',
#   'xx',
#   'xxxxxxx',
#   'xxxxxx',
#   'xxxxx',
#   'xxxxxxxxx',
#   'xxxx',
#   'x',
#   'xxxx',
#   'xxxxxxx',
#   'xxxxxxxxxxxxx',
#   'xxx',
#   'xxx',
#   'xx',
#   'xxxxxxx',
#   'xxxxxxxxx',
#   'xxx',
#   'xxxx',
#   'xxxxxxxxxx',
#   'xxx',
#   'xxxxxxx',
#   'xxxxxx',
#   'x',
#   'xxxxxxxxx',
#   'x',
#   'xxxxx',
#   'xx',
#   'xxxxx',
#   'xxxxxx',
#   'x',
#   'xxxxxxxx',
#   'xx',
#   'xxxxx',
#   'x',
#   'xxxxxx',
#   'x',
#   'xx',
#   'xxxxxxx',
#   'xx',
#   'xxxxxxxxx',
#   'xx',
#   'x',
#   'xxxx',
#   'xxxxxxxxx',
#   'xx',
#   'xxxx',
#   'xxxxxxxxxxxxx',
#   'xxx',
#   'xxxxxxx',
#   'xxxxx',
#   'xxxxxx',
#   'xx',
#   'xxxxxxxxx',
#   'x',
#   'xx',
#   'xxxxxxx',
#   'xxxxx',
#   'xxxxxxx',
#   'xxxxxx',
#   'xxxxx',
#   'xxxxxxxxx'],
#  ['дверь',
#   'лифтовый',
#   'холл',
#   'этаж',
#   'ответный',
#   'часть',
#   'замок',
#   'дверь',
#   'травмоопасный',
#   'металичесый',
#   'накладка',
#   'торчать',
#   'рваться',
#   'куртка',
#   'срочно',
#   'принять',
#   'мера'],
#  ['надпись', 'киоск'],
#  ['незаконный', 'решётка', 'фасад'],
#  ['необходимый', 'уборка', 'лестница', 'этаж', 'парадный'],
#  ['секция', 'этаж', 'пробить', 'потолочный', 'плитка'],
#  ['весь', 'газон', 'разбросать', 'красный', 'труба', 'необходимо', 'убрать'],
#  ['доска', 'скамейка', 'сгнить'],
#  ['реклама', 'висеть'],
#  ['просить', 'очистить'],
#  ['проведение',
#   'ремонт',
#   'входной',
#   'группа',
#   'крыльцо',
#   'август',
#   'сентябрь',
#   'внутренний',
#   'часть',
#   'козырёк',
#   'преимущественно',
#   'стык',
#   'плита',
#   'иметься',
#   'трещина',
#   'спустя',
#   'месяц',
#   'говорить',
#   'качественный',
#   'выполнение',
#   'строительный',
#   'отделочный',
#   'работа',
#   'например',
#   'внутренний',
#   'часть',
#   'козырёк',
#   'парадный',
#   'номер'],
#  ['реклама', 'весь', 'парадный'],
#  ['ям', 'перекрёсток'],
#  ['этаж', 'висеть', 'провод', 'просьба', 'закрепить'],
#  ['осуществляться', 'уборка', 'снег', 'детский', 'площадка'],
#  ['очистить'],
#  ['открыть', 'коробка', 'проводы', 'просить', 'устранить'],
#  ['крышка', 'люк', 'приоткрыть'],
#  ['шестой',
#   'этаж',
#   'квартирный',
#   'холл',
#   'дверь',
#   'выход',
#   'квартирный',
#   'холл',
#   'общий',
#   'балкон',
#   'открываться'],
#  ['надпись', 'трансформаторный', 'подстанция'],
#  ['очистить'],
#  ['сломать', 'козырёк', 'вход', 'подвал'],
#  ['реклама', 'стена', 'дом'],
#  ['этаж',
#   'кв',
#   'xxx',
#   'стена',
#   'отсутствовать',
#   'штукатурка',
#   'плиточный',
#   'плинтус'],
#  ['заменить',
#   'вывеска',
#   'вывеска',
#   'указание',
#   'правильный',
#   'этажность',
#   'этаж',
#   'это',
#   'этаж',
#   'это',
#   'это',
#   'тд',
#   'врач',
#   'курьер',
#   'мочь',
#   'первый',
#   'попасть',
#   'нужный',
#   'этаж',
#   'подъезд'],
#  ['незаконный', 'решётка', 'фасад'],
#  ['очистить'],
#  ['крупногабаритный', 'мусор', 'газон'],
#  ['сломать', 'мёртвый', 'ветвь'],
#  ['доводчик',
#   'дверь',
#   'закрываться',
#   'заходить',
#   'посторонний',
#   'личность',
#   'кошка',
#   'подъезд',
#   'очень',
#   'холодно',
#   'лестница'],
#  ['граффити'],
#  ['подъезд', 'неделя', 'работать', 'пассажирский', 'лифт'],
#  ['граффити', 'дом'],
#  ['восстановить', 'секция', 'газонный', 'ограждение'],
#  ['убрать', 'пакет', 'мусор', 'газон'],
#  ['политехнический',
#   'ул',
#   'тротуар',
#   'вдоль',
#   'дом',
#   'пр',
#   'тореза',
#   'огромный',
#   'лужа',
#   'занимать',
#   'больший',
#   'часть',
#   'тротуар',
#   'сильный',
#   'дождь',
#   'заливать',
#   'тротуар',
#   'полностью',
#   'необходимо',
#   'прочистить',
#   'углубить',
#   'отводить',
#   'канавка',
#   'устроенный',
#   'вдоль',
#   'бордюр',
#   'газон',
#   'лужа',
#   'иметь',
#   'сток',
#   'забиться',
#   'канавка'],
#  ['течение',
#   'неделя',
#   'парить',
#   'лестничный',
#   'площадка',
#   'первый',
#   'этаж',
#   'который',
#   'находиться',
#   'помещение',
#   'теплоцентр',
#   'ступенька',
#   'лестница',
#   'проступать',
#   'влага',
#   'пара',
#   'лестница',
#   'влажно',
#   'предположительно',
#   'повреждение',
#   'запорный',
#   'арматура'],
#  ['проведение',
#   'ремонт',
#   'площадка',
#   'этаж',
#   'оставить',
#   'грязный',
#   'плинтус',
#   'необходимо',
#   'этаж',
#   'качественно',
#   'вымыть',
#   'плинтус',
#   'подкрасить'],
#  ['народный',
#   'улица',
#   'дом',
#   'литера',
#   'м',
#   'пара',
#   'просьба',
#   'восстановить',
#   'поручень',
#   'парадный',
#   'накладка'],
#  ['окно',
#   'заложить',
#   'кирпич',
#   'металл',
#   'просить',
#   'привести',
#   'проектный',
#   'состояние'],
#  ['мусор', 'газон', 'неделя', 'лежать', 'каждый', 'день', 'большой'],
#  ['столб', 'разместить', 'рекламный', 'конструкция'],
#  ['просадка', 'грунт'],
#  ['очень', 'грязно', 'подъезд'],
#  ['несанкционированный',
#   'торговля',
#   'несанкционированный',
#   'торговля',
#   'несанкционированный',
#   'торговля'],
#  ['мусор', 'придомовый', 'территория'],
#  ['обрушаться',
#   'фасад',
#   'голова',
#   'прохожий',
#   'год',
#   'назад',
#   'парадный',
#   'объявление',
#   'ремонт',
#   'воз',
#   'ныне'],
#  ['надпись', 'далее', 'мост'],
#  ['положение', 'знак', 'нарушить'],
#  ['утратить',
#   'стекло',
#   'крышка',
#   'уличный',
#   'фонарь',
#   'требоваться',
#   'произвести',
#   'ремонт',
#   'светильник',
#   'фотофиксация',
#   'прилагаться'],
#  ['лестница',
#   'фасад',
#   'дом',
#   'козырёк',
#   'входной',
#   'дверь',
#   'вода',
#   'попадать',
#   'площадка',
#   'лестница',
#   'первый',
#   'этаж',
#   'стекать',
#   'дверь',
#   'проводка',
#   'магнит',
#   'домофон',
#   'заливать',
#   'пола',
#   'вход',
#   'стена',
#   'слева',
#   'сверху',
#   'входной',
#   'дверь',
#   'внутри',
#   'лестница',
#   'весь',
#   'мокрый',
#   'просьба',
#   'устранить',
#   'протечка'],
#  ['наклейка', 'знак'],
#  ['подъезд',
#   'информационный',
#   'наклейка',
#   'лифт',
#   'дверь',
#   'лифт',
#   'присутствовать',
#   'надпись',
#   'несущий',
#   'смысл',
#   'необходимо',
#   'выполнить',
#   'замена',
#   'наклейка',
#   'очистка',
#   'покрытие'],
#  ['разрушить', 'стяжка', 'пол', 'парадный', 'лифтовый', 'хол', 'этаж', 'этаж'],
#  ['почтовый',
#   'ящик',
#   'сломать',
#   'находиться',
#   'удовлетворительно',
#   'состояние',
#   'просить',
#   'провести',
#   'ремонт',
#   'замена',
#   'парадный'],
#  ['чиститься', 'снег'],
#  ['неубранный', 'листва', 'мелкий', 'мусор', 'газон'],
#  ['убрать', 'мусор', 'внутридворовый', 'территория'],
#  ['надпись', 'сооружение'],
#  ['проверить',
#   'законность',
#   'установка',
#   'шлагбаум',
#   'наличие',
#   'согласование',
#   'установка',
#   'шлагбаум',
#   'комитет',
#   'градостроительство',
#   'архитектура',
#   'санкт',
#   'петербург',
#   'государственный',
#   'административно',
#   'технический',
#   'инспекция'],
#  ['состояние',
#   'часть',
#   'дорожный',
#   'покрытие',
#   'улица',
#   'проходить',
#   'гипермаркет',
#   'метро',
#   'окей',
#   'максидом',
#   'находиться',
#   'крайне',
#   'плохой',
#   'неудовлетворительный',
#   'состояние',
#   'отсутствовать',
#   'асфальтовый',
#   'покрытие',
#   'огромный',
#   'количество',
#   'глубокий',
#   'ям',
#   'просьба',
#   'принять',
#   'мера',
#   'отремонтировать',
#   'дорога'],
#  ['надпись', 'будка'],
#  ['фото',
#   'сделать',
#   'максимально',
#   'далёкий',
#   'обзорный',
#   'вывеска',
#   'читабельный',
#   'фотоматериал',
#   'хороший',
#   'качество'],
#  ['грязь', 'парадный', 'соблюдение', 'графика', 'уборка'],
#  ['реклама', 'xxxxxxxxxx', 'торговый', 'павильон', 'дом', 'пр', 'большевиков'],
#  ['тамбур',
#   'подъезд',
#   'дверь',
#   'храниться',
#   'мебель',
#   'дверь',
#   'лестница',
#   'полностью',
#   'открыть',
#   'мешать',
#   'проход',
#   'мебель',
#   'просто',
#   'переместить',
#   'часть',
#   'тамбур',
#   'закинуть',
#   'электрощит'],
#  ['грязь',
#   'парадный',
#   'убираться',
#   'течение',
#   'неделя',
#   'висеть',
#   'график',
#   'уборка',
#   'парадный',
#   'февраль'],
#  ['отвалиться', 'плитка', 'этаж'],
#  ['работать', 'фонарь'],
#  ['лужа', 'грязь', 'дорожка', 'ведущий', 'детский', 'сад'],
#  ['бетонный', 'блок', 'стойка', 'дорожный', 'знак', 'проезжий', 'часть'],
#  ['крупногабаритный', 'мусор', 'шпала', 'плита'],
#  ['нужно', 'убрать', 'старый', 'игрушка', 'дерево'],
#  ['повредить', 'ограждение', 'газон'],
#  ['снег', 'дорога'],
#  ['ям', 'дорога'],
#  ['течь', 'труба', 'образоваться', 'ржавчина'],
#  ['производиться', 'уборка', 'лестничный', 'площадка', 'парадный'],
#  ['очистить', 'дорога'],
#  ['просьба', 'стереть', 'надпись', 'спасибо'],
#  ['весь',
#   'фасад',
#   'дом',
#   'замазать',
#   'трещина',
#   'работа',
#   'фасад',
#   'привести',
#   'соответствие',
#   'паспорт',
#   'фасад',
#   'колерный',
#   'бланк'],
#  ['яма', 'асфальт', 'выезд', 'двор'],
#  ['мусор', 'канистра', 'необходимо', 'убрать'],
#  ['надпись', 'дом'],
#  ['работать', 'освещение'],
#  ['здание',
#   'бывший',
#   'котельная',
#   'отсутствовать',
#   'сегмент',
#   'водосточный',
#   'труба',
#   'часть',
#   'остаться',
#   'сегмент',
#   'повредить'],
#  ['граффити', 'знак'],
#  ['незаконный', 'рекламный', 'конструкция', 'вид', 'велосипед'],
#  ['добрый', 'день', 'просьба', 'закрасить', 'надпись', 'гараж'],
#  ['просьба', 'стереть', 'надпись', 'спасибо'],
#  ['мусор', 'территория'],
#  ['снег', 'дорога'],
#  ['отсутствовать', 'ручка', 'окно', 'парадный', 'этаж'],
#  ['плиточный',
#   'покрытие',
#   'тротуар',
#   'арка',
#   'неудовлетворительный',
#   'состояние',
#   'плитка',
#   'буквальный',
#   'смысл',
#   'слово',
#   'ходить',
#   'ходуном',
#   'запросто',
#   'запнуться',
#   'упасть',
#   'некоторый',
#   'плитка',
#   'потрескаться',
#   'также',
#   'выбоина',
#   'трещина',
#   'просьба',
#   'провести',
#   'работа',
#   'замена',
#   'покрытие',
#   'новый',
#   'качественный'],
#  ['пешеходный',
#   'дорожка',
#   'который',
#   'большинство',
#   'житель',
#   'вести',
#   'ребёнок',
#   'дошкольный',
#   'отделение',
#   'школа',
#   'школа',
#   'полностью',
#   'затопить',
#   'талый',
#   'вода',
#   'обойти',
#   'невозможно',
#   'всё',
#   'вокруг',
#   'лёд'],
#  ['отношение',
#   'размещение',
#   'инженерный',
#   'технический',
#   'оборудование',
#   'фасад',
#   'требоваться',
#   'разработка',
#   'лист',
#   'согласование',
#   'получить',
#   'основание',
#   'обращение',
#   'комитет',
#   'градостроительство',
#   'архитектура',
#   'закон',
#   'санкт',
#   'петербург',
#   'административный',
#   'правонарушение',
#   'санкт',
#   'петербург',
#   'статья',
#   'предусмотреть',
#   'административный',
# ...
#   'недействительный',
#   'копия',
#   'решение',
#   'приложить'],
#  ['гореть', 'свет'],
#  ['отсутствовать',
#   'информационный',
#   'щит',
#   'контейнерный',
#   'площадка',
#   'щит',
#   'должный',
#   'содержать',
#   'информация',
#   'согласно',
#   'п',
#   'постановление',
#   'комитет',
#   'благоустройство',
#   'санкт',
#   'петербург',
#   'ноябрь',
#   'год',
#   'n',
#   'р',
#   'утверждение',
#   'порядок',
#   'накопление',
#   'твёрдый',
#   'коммунальный',
#   'отход',
#   'число',
#   'раздельный',
#   'накопление',
#   'территория',
#   'санкт',
#   'петербург',
#   'число',
#   'наименование',
#   'адрес',
#   'контактный',
#   'телефон',
#   'организация',
#   'обеспечивать',
#   'содержание',
#   'контейнерный',
#   'площадка',
#   'график',
#   'вывоз',
#   'твёрдый',
#   'коммунальный',
#   'отход',
#   'место',
#   'установка',
#   'контейнер',
#   'накопление',
#   'отработать',
#   'ртутьсодержать',
#   'лампа',
#   'градусник',
#   'иной',
#   'ртутьсодержать',
#   'бытовой',
#   'прибор',
#   'термометр',
#   'тонометр',
#   'п',
#   'батарейка',
#   'малогабаритный',
#   'аккумулятор'],
#  ['улица', 'геологический', 'оба', 'сторона', 'дорога', 'газон', 'мусор'],
#  ['надпись', 'колонна'],
#  ['лестница', 'убирать', 'график', 'уборка', 'соблюдаться'],
#  ['законно', 'установленный', 'решётка', 'фасад', 'здание'],
#  ['очень', 'грязно'],
#  ['этаж', 'качественно', 'проводиться', 'уборка', 'грязь', 'возле', 'труба'],
#  ['дом',
#   'комендантский',
#   'пр',
#   'сторона',
#   'двор',
#   'дом',
#   'выломать',
#   'секция',
#   'забор',
#   'ограждать',
#   'газон',
#   'просьба',
#   'привести',
#   'ограждение',
#   'надлежащий',
#   'состояние'],
#  ['пакет', 'бутылка', 'газон', 'сквер', 'дом', 'ул', 'будапештский'],
#  ['здравствуйте',
#   'этаж',
#   'эвакуационный',
#   'лестница',
#   'подъезд',
#   'закрываться',
#   'дверь',
#   'подьезд',
#   'готовый',
#   'эксплуатация',
#   'зимний',
#   'условие',
#   'просить',
#   'обеспечить',
#   'закрывание',
#   'дверь',
#   'спасибо'],
#  ['третий',
#   'парадный',
#   'восьмой',
#   'этаж',
#   'чёрный',
#   'лестница',
#   'отсутствовать',
#   'декоративный',
#   'заглушка',
#   'поворотный',
#   'механизм',
#   'окно'],
#  ['мусор', 'двор'],
#  ['слабый', 'напор', 'вода', 'постоянно', 'проблема', 'решить'],
#  ['сломать', 'лавочка', 'детский', 'площадка'],
#  ['глубокий', 'ям', 'внутри', 'двор', 'проезжий', 'часть'],
#  ['реклама', 'поручень'],
#  ['объявление', 'остановка'],
#  ['северный',
#   'этаж',
#   'установить',
#   'дверь',
#   'препятствовать',
#   'доступ',
#   'электрический',
#   'щиток'],
#  ['отселиться',
#   'обшивка',
#   'стена',
#   'тамбур',
#   'дверь',
#   'парадный',
#   'адрес',
#   'юрий',
#   'гагарин',
#   'просьба',
#   'прикрепить',
#   'панель',
#   'обшивка'],
#  ['посторонний', 'предмет', 'ограда'],
#  ['непонятный',
#   'конструкция',
#   'травмоопасный',
#   'ограждение',
#   'установить',
#   'гост'],
#  ['пр',
#   'кузнецов',
#   'далее',
#   'подъезд',
#   'просьба',
#   'отмыть',
#   'синий',
#   'табличка',
#   'номер',
#   'квартира'],
#  ['полный', 'контейнер', 'мусор'],
#  ['провисать', 'труба', 'центральный', 'проход', 'подвал'],
#  ['просьба', 'убрать', 'реклама', 'лифт', 'пара'],
#  ['уборка',
#   'газон',
#   'трактор',
#   'сильно',
#   'загрязнить',
#   'тротуар',
#   'земля',
#   'мало',
#   'уборка',
#   'испортить',
#   'газон',
#   'пройти',
#   'испачкать',
#   'нога',
#   'требоваться',
#   'произвести',
#   'работа',
#   'качественный',
#   'механизировать',
#   'ручной',
#   'уборка',
#   'тротуар',
#   'загрязнение',
#   'дом',
#   'дом',
#   'ул',
#   'ольминский',
#   'фотофиксация',
#   'прилагаться'],
#  ['крыса',
#   'грызть',
#   'кабель',
#   'домофон',
#   'парадный',
#   'приводить',
#   'неисправность'],
#  ['куча', 'мусор', 'рядом', 'магазин', 'петрович'],
#  ['квартира',
#   'xxx',
#   'парадный',
#   'кухонный',
#   'стояк',
#   'холодный',
#   'вода',
#   'течение',
#   'неделя',
#   'оставлять',
#   'несколько',
#   'заявка',
#   'управлять',
#   'компания',
#   'первый',
#   'обращение',
#   'управлять',
#   'компания',
#   'октябрь'],
#  ['просить', 'поставить', 'крышка', 'колодец', 'пас'],
#  ['мусор', 'проезжий', 'часть', 'грязь', 'покрытие', 'разметка', 'видно'],
#  ['территория', 'убираться', 'снег'],
#  ['реклама', 'столб'],
#  ['бетонный', 'блок', 'песок', 'проезжий', 'часть'],
#  ['граффити', 'забор', 'больница'],
#  ['яма', 'асфальт'],
#  ['просьба',
#   'привести',
#   'порядок',
#   'территория',
#   'линия',
#   'среднее',
#   'проспект',
#   'зима',
#   'вычистить',
#   'песок',
#   'убрать',
#   'разъезд'],
#  ['очистить'],
#  ['вход', 'секция', 'повреждение', 'стена'],
#  ['просить', 'убрать', 'граффити', 'внутри', 'арка'],
#  ['граффити', 'рекламный', 'конструкция'],
#  ['просить', 'закрасить', 'граффити'],
#  ['декабрь',
#   'ремонт',
#   'парадный',
#   'остаться',
#   'лежать',
#   'материал',
#   'число',
#   'легковоспламеняющийся',
#   'краска'],
#  ['несанкционированный', 'торговля'],
#  ['администрация',
#   'район',
#   'замечать',
#   'незаконный',
#   'торговля',
#   'житель',
#   'каждый',
#   'день',
#   'видеть',
#   'ящик',
#   'выставить',
#   'запредел',
#   'нто',
#   'нто',
#   'установить',
#   'арендовать',
#   'земля',
#   'ящик',
#   'владелец',
#   'товар',
#   'незаконно',
#   'устанавливать',
#   'территория',
#   'санкт',
#   'петербург',
#   'предназначить',
#   'торговля'],
#  ['сторона',
#   'голубой',
#   'универсам',
#   'входной',
#   'дверь',
#   'второй',
#   'подъезд',
#   'разместить',
#   'реклама',
#   'металлический',
#   'пластина',
#   'просьба',
#   'убрать',
#   'незаконный',
#   'реклама'],
#  ['помещение',
#   'общий',
#   'пользование',
#   'полностью',
#   'холодный',
#   'радиатор',
#   'который',
#   'работать',
#   'моп',
#   'находиться',
#   'проход',
#   'лифтовый',
#   'холл',
#   'чёрный',
#   'лестница',
#   'адрес',
#   'дизельный',
#   'проезд',
#   'дом',
#   'парадный',
#   'этаж'],
#  ['очистить'],
#  ['входной',
#   'дверь',
#   'подъезд',
#   'двор',
#   'отсутствие',
#   'доводчик',
#   'останов',
#   'установленный',
#   'пружина',
#   'дверь',
#   'закрывать',
#   'открывание',
#   'постоянно',
#   'отламываться',
#   'крепление',
#   'который',
#   'сделать',
#   'тонкий',
#   'пластинка',
#   'держать',
#   'нагрузка',
#   'требоваться',
#   'восстановить',
#   'доводчик',
#   'остановой',
#   'входной',
#   'дверь',
#   'присылать',
#   'ответ',
#   'действовать',
#   'фото',
#   'старый',
#   'сообщение'],
#  ['перегореть',
#   'освещение',
#   'вход',
#   'подьезд',
#   'необходимо',
#   'восстановление',
#   'установка',
#   'свет',
#   'фотореле',
#   'датч',
#   'движение',
#   'двор',
#   'очень',
#   'темно',
#   'ребёнок',
#   'выпустить',
#   'смотреть',
#   'фото'],
#  ['улица',
#   'геологический',
#   'корпус',
#   'второй',
#   'парадный',
#   'лестница',
#   'везде',
#   'работать',
#   'освещение'],
#  ['грязь', 'песок', 'улица'],
#  ['грязный', 'стена', 'около', 'лифт'],
#  ['парадный',
#   'убирать',
#   'висеть',
#   'график',
#   'октябрь',
#   'банк',
#   'каки',
#   'стоять',
#   'стоить',
#   'хабарик',
#   'остаться',
#   'лежать',
#   'лифт',
#   'вывешить',
#   'график',
#   'уборка',
#   'отметить',
#   'адрес',
#   'графика',
#   'указать',
#   'новгородский',
#   'далее',
#   'убрать',
#   'сообщение',
#   'ежедневный',
#   'влажный',
#   'уборка',
#   'второй',
#   'этаж',
#   'каждый',
#   'день',
#   'делаться'],
#  ['яма', 'асфальт'],
#  ['мыться',
#   'парадный',
#   'номер',
#   'пятно',
#   'пол',
#   'первый',
#   'этаж',
#   'грязный',
#   'лифт'],
#  ['высокий', 'поребрик', 'невозможно', 'проехать', 'коляска', 'парадный'],
#  ['мусор', 'двор'],
#  ['надпись'],
#  ['незаконный',
#   'бумажный',
#   'реклама',
#   'театральный',
#   'афиша',
#   'недалеко',
#   'дом',
#   'адрес',
#   'гражданский',
#   'пр',
#   'калининский',
#   'район',
#   'санкт',
#   'петербург'],
#  ['работать', 'домофон', 'подъезд'],
#  ['неудовлетворительный', 'состояние', 'покрытие'],
#  ['неубранный', 'мусор', 'фото'],
#  ['лист', 'песок', 'тротуар'],
#  ['тихоокеанский',
#   'дверь',
#   'лифт',
#   'торчать',
#   'острый',
#   'самореза',
#   'ручка',
#   'портить',
#   'одежда',
#   'просить',
#   'привести',
#   'ручка',
#   'надлежащий',
#   'состояние',
#   'спасибо'],
#  ['несанкционированный', 'объявление', 'возле', 'метро', 'ломоносовский'],
#  ['просить', 'устранить', 'гололёд'],
#  ['лужа', 'минус', 'тротуар', 'вокруг', 'дом', 'улица', 'яхтенный'],
#  ['лужа',
#   'постоянно',
#   'долго',
#   'стоить',
#   'дождь',
#   'время',
#   'таяние',
#   'снег',
#   'порой',
#   'пройти',
#   'невозможно'],
#  ['вывезти', 'остаток', 'упануть', 'дерево'],
#  ['неочищенный', 'урна', 'детский', 'площадка'],
#  ['добрый',
#   'день',
#   'двор',
#   'дом',
#   'адрес',
#   'шлиссельбургский',
#   'пр',
#   'далее',
#   'корп',
#   'газон',
#   'около',
#   'контейнерный',
#   'площадка',
#   'находиться',
#   'люк',
#   'который',
#   'разбитый',
#   'бетонный',
#   'кольцо',
#   'люк',
#   'огромный',
#   'дыра',
#   'мочь',
#   'провалиться',
#   'ребёнок',
#   'животное',
#   'избежание',
#   'несчастный',
#   'случай',
#   'туда',
#   'поставить',
#   'стул',
#   'убедительный',
#   'просьба',
#   'найти',
#   'владелец',
#   'люк',
#   'устранить',
#   'данный',
#   'проблема',
#   'спасибо'],
#  ['ям', 'аварийный', 'состояние'],
#  ['ремонт',
#   'труба',
#   'участок',
#   'газон',
#   'нуждаться',
#   'восстановление',
#   'находиться',
#   'пересечение',
#   'караваевский',
#   'улица',
#   'ул',
#   'дмитрий',
#   'устинов',
#   'рядом',
#   'пешеходный',
#   'переход',
#   'дом',
#   'караваевский',
#   'ул'],
#  ['снег', 'тротуар', 'вдоль', 'дорога'],
#  ['выбоина', 'фотофиксация', 'прилагаться'],
#  ['убрать', 'газон', 'куча', 'грязь'],
#  ['незаконный', 'решётка', 'фасад'],
#  ['систематический',
#   'переполнение',
#   'мусорный',
#   'контейнер',
#   'ведущий',
#   'загрязнение',
#   'территория',
#   'двор',
#   'просить',
#   'пересмотреть',
#   'график',
#   'вывоз',
#   'мусор'],
#  ['требоваться', 'косметический', 'ремонт', 'парадный', 'этаж'],
#  ['очистить',
#   'дом',
#   'наклеёный',
#   'реклама',
#   'оставлять',
#   'след',
#   'бумага',
#   'клей'],
#  ['просить', 'убрать', 'бетонный', 'плита', 'газон'],
#  ['просить', 'привести', 'нормативный', 'состояние'],
#  ['парадный',
#   'график',
#   'уборка',
#   'соблюдаеться',
#   'видимо',
#   'график',
#   'висеть',
#   'просто',
#   'стенд',
#   'мытьё',
#   'лесть',
#   'площадка',
#   'выше',
#   'этаж',
#   'должный',
#   'ещё',
#   'го',
#   'число',
#   'подметание',
#   'нижний',
#   'этаж',
#   'мытьё',
#   'кабина',
#   'лифт',
#   'вообще',
#   'ежедневно',
#   'принять',
#   'мера'],
#  ['работать', 'фонарь', 'уличный', 'освещение', 'парадный', 'дом'],
#  ['порвать',
#   'отсутствовать',
#   'сетка',
#   'футбольный',
#   'ворота',
#   'месяц',
#   'назад',
#   'обращение',
#   'установить',
#   'сетка',
#   'ужасный',
#   'качество',
#   'долго',
#   'протянуть',
#   'просьба',
#   'решить',
#   'проблема',
#   'ребёнок',
#   'хотеть',
#   'играть',
#   'футбол'],
#  ['загородный',
#   'проспект',
#   'парадный',
#   'дверь',
#   'подвал',
#   'открыть',
#   'каждый',
#   'писать',
#   'принять',
#   'мера',
#   'загородный',
#   'проспект',
#   'парадный',
#   'дверь',
#   'подвал',
#   'открыть',
#   'каждый',
#   'писать',
#   'принять',
#   'мера',
#   'подвал',
#   'открыть'],
#  ['территория',
#   'вдоль',
#   'го',
#   'предпортовый',
#   'захламить',
#   'мусор',
#   'близкий',
#   'площадка',
#   'убираться'],
#  ['добрый',
#   'день',
#   'парадный',
#   'лиговский',
#   'проспект',
#   'убираться',
#   'должный',
#   'образ',
#   'сколько',
#   'писать',
#   'оставлять',
#   'заявка',
#   'парадный',
#   'мыть',
#   'весь',
#   'подрезать',
#   'первый',
#   'этаж',
#   'всё',
#   'остальной',
#   'этаж',
#   'грязный',
#   'лестничный',
#   'клетка',
#   'этаж',
#   'мыться',
#   'проводиться',
#   'мытьё',
#   'лестничный',
#   'клетка',
#   'судить',
#   'график',
#   'приложить',
#   'фото',
#   'это',
#   'видно',
#   'этаж',
#   'мытый'],
#  ['подъезд',
#   'третий',
#   'этаж',
#   'квартира',
#   'постоянно',
#   'моргать',
#   'лампочка',
#   'освещение'],
#  ['парадный',
#   'пассажирский',
#   'лифт',
#   'очень',
#   'тусклый',
#   'освещение',
#   'перегаресть',
#   'несколько',
#   'лампочка'],
#  ['работать', 'освещение', 'лифт', 'подъезд'],
#  ['необходимо', 'привести', 'ограждение', 'газон', 'надлежащий', 'вид'],
#  ['нужно', 'закрасить', 'надпись'],
#  ['объявление', 'светофор'],
#  ['разбитый',
#   'дверь',
#   'чёрный',
#   'лестница',
#   'просить',
#   'произвести',
#   'ремонт',
#   'парадный',
#   'этаж'],
#  ['требоваться', 'удалить', 'надпись'],
#  ['незаконный',
#   'размещение',
#   'рекламный',
#   'стойка',
#   'территория',
#   'общий',
#   'имущество',
#   'собственник',
#   'многоквартирный',
#   'дом',
#   'согласие',
#   'салон',
#   'красота',
#   'm',
#   'od'],
#  ['очистить',
#   'весь',
#   'дорожный',
#   'знак',
#   'весь',
#   'сторона',
#   'реклама',
#   'оставлять',
#   'след',
#   'бумага',
#   'клей'],
#  ['мусор'],
#  ['работать', 'указанный', 'светильник'],
#  ['решётка'],
#  ['необходимый', 'реставрация', 'ворота'],
#  ['закрасить', 'граффити', 'тон', 'здание', 'пожалуйста'],
#  ['несанкционированный', 'надпись', 'фасад', 'дом'],
#  ['сломать', 'дерево', 'лежать', 'газон', 'месяц'],
#  ['убрать', 'снег', 'вдоль', 'дорога', 'парковка'],
#  ['лужа',
#   'грязь',
#   'дорожка',
#   'школьный',
#   'футбольный',
#   'поле',
#   'школа',
#   'дом',
#   'ул',
#   'тамбасовый',
#   'лужа',
#   'образоваться',
#   'каждый',
#   'дождь',
#   'необходимо',
#   'поднять',
#   'покрытие',
#   'дорожка',
#   'уровень',
#   'газон'],
#  ['тамбурный',
#   'дверь',
#   'плохо',
#   'закрываться',
#   'необходимо',
#   'придать',
#   'верхний',
#   'петля',
#   'замена',
#   'саморез'],
#  ['мусор'],
#  ['мусор', 'вид', 'песок', 'дорога', 'двор', 'ул', 'шахматов'],
#  ['козырёк', 'крыльцо', 'парадный', 'неудовлетворительный', 'состояние'],
#  ['водослив',
#   'зелёный',
#   'кровля',
#   'паркинг',
#   'отсутствовать',
#   'крышка',
#   'ребёнок',
#   'мочь',
#   'нога',
#   'провалиться'],
#  ['требоваться',
#   'произвести',
#   'работа',
#   'качественный',
#   'очистка',
#   'дорожный',
#   'знак',
#   'несанкционированный',
#   'рекламный',
#   'объявление',
#   'оставлять',
#   'след',
#   'фотофиксация',
#   'прилагаться'],
#  ['газон', 'засыпать', 'мелкий', 'осколок', 'специальный', 'стекло'],
#  ['ролгод'],
#  ['недостаточный',
#   'уплотнение',
#   'дверь',
#   'выход',
#   'переходный',
#   'балкон',
#   'этаж',
#   'попадать',
#   'атмосферный',
#   'осадка',
#   'грязь',
#   'этаж'],
#  ['мыться',
#   'парадный',
#   'пол',
#   'грязный',
#   'липкий',
#   'лестница',
#   'этаж',
#   'окно',
#   'рассыпать',
#   'мусор'],
#  ['регулярный',
#   'соблюдение',
#   'графика',
#   'уборка',
#   'уборка',
#   'проводиться',
#   'обращение',
#   'жкс',
#   'грязь',
#   'подъезд',
#   'фото',
#   'прилагать'],
#  ['работать', 'фонарь', 'моп', 'этаж'],
#  ['огромный', 'незаконный', 'воздуховод', 'фасад'],
#  ['лифт',
#   'ужасный',
#   'состояние',
#   'лифт',
#   'трясти',
#   'постоянно',
#   'ломаться',
#   'кнопка',
#   'этаж',
#   'работать',
#   'год',
#   'приходить',
#   'комиссия',
#   'прикладывать',
#   'фото',
#   'результат',
#   'комиссия'],
#  ['неудовлетворительный', 'состояние', 'покрытие'],
#  ['вновь', 'неудовлетворительный', 'состояние', 'покрытие', 'возле', 'люк'],
#  ['парадный', 'этаж', 'отсутствие', 'решётка', 'радиатор'],
#  ['убрать', 'объявление', 'оставлять', 'след', 'бумага', 'клей'],
#  ['неубранный', 'снег', 'пешеходный', 'переход'],
#  ['неделя', 'проводиться', 'уборка', 'этаж', 'сухой', 'влажный'],
#  ['арка', 'дом', 'пакет', 'мусор'],
#  ['надпись', 'общий', 'балкон', 'этаж', 'подъезд'],
#  ['неисправный',
#   'домофон',
#   'квартира',
#   'ул',
#   'маршал',
#   'казаков',
#   'дом',
#   'корп',
#   'строение',
#   'кв'],
#  ['несанкционированный',
#   'надпись',
#   'объявление',
#   'дорожный',
#   'ограждение',
#   'остановочный',
#   'павильон',
#   'оборудовать',
#   'рекламный',
#   'конструкция'],
#  ['мусор', 'вид', 'покрышка', 'нужно', 'убрать'],
#  ['необходимо', 'закрыть', 'конец', 'крышка', 'люк'],
#  ['вдоль',
#   'дом',
#   'улица',
#   'шостакович',
#   'лужие',
#   'тротуар',
#   'дорога',
#   'вода',
#   'уходить',
#   'подойти'],
#  ['сильный',
#   'провисание',
#   'электропровод',
#   'здание',
#   'краснопутиловский',
#   'костюшко',
#   'провод',
#   'видимо',
#   'закрепить',
#   'сильный',
#   'порыв',
#   'ветер',
#   'опускаться',
#   'всё',
#   'ниже'],
#  ['повреждение', 'маф', 'скамейка', 'выкинуть', 'ручей'],
#  ['изгиб', 'дорога', 'яма', 'смотреть', 'глубина'],
#  ['погаснуть',
#   'несколько',
#   'фонарь',
#   'около',
#   'выход',
#   'метро',
#   'спортивный',
#   'рядом',
#   'остановка',
#   'транспорт',
#   'починить',
#   'пожалуйста'],
#  ['незаконный', 'решётка', 'фасад'],
#  ['мусор', 'газон'],
#  ['второй',
#   'этаж',
#   'рядом',
#   'почтовый',
#   'ящик',
#   'второй',
#   'месяц',
#   'вестись',
#   'влажный',
#   'уборка',
#   'тсж',
#   'бездействовать',
#   'хотя',
#   'график',
#   'уборка',
#   'последний',
#   'проводиться',
#   'ежедневно',
#   'проблема',
#   'касаться',
#   'часть',
#   'парадный',
#   'вход',
#   'второй',
#   'этаж',
#   'настоящий',
#   'проблема',
#   'речь',
#   'участок',
#   'парадный',
#   'этаж',
#   'установить',
#   'почтовый',
#   'ящик'],
#  ['повреждение', 'дорожный', 'покрытие', 'проезжий', 'часть'],
#  ['дворник', 'убрать', 'песок', 'подъезд', 'высыпать', 'газон'],
#  ['нужно', 'заделать', 'ям', 'двор'],
#  ['демонтировать', 'решётка'],
#  ['граффити', 'тп'],
#  ...]

# %%
all_words = [word for document in X for word in document]

# %%
all_words[:10]
# Out:
# ['снег',
#  'дорога',
#  'очистить',
#  'кабельный',
#  'киоск',
#  'реклама',
#  'просить',
#  'убрать',
#  'всё',
#  'дерево']

# %%
vocab = set(all_words)
vocab_len = len(vocab)
vocab_len
# Out:
# 7771

# %%
id_word = dict(enumerate(vocab))
id_word
# Out:
# {0: 'взудитие',
#  1: 'утверждение',
#  2: 'ношение',
#  3: 'стать',
#  4: 'зайцев',
#  5: 'гск',
#  6: 'инстанция',
#  7: 'новорождённый',
#  8: 'бездейстовать',
#  9: 'неудовлетворительно',
#  10: 'чебышевский',
#  11: 'частично',
#  12: 'достаточно',
#  13: 'параднойгрязь',
#  14: 'судебный',
#  15: 'пища',
#  16: 'снаружи',
#  17: 'петербург',
#  18: 'таракашка',
#  19: 'прохладный',
#  20: 'указываться',
#  21: 'тройка',
#  22: 'зацементировать',
#  23: 'облицевать',
#  24: 'неудолетворительный',
#  25: 'блюхер',
#  26: 'молодец',
#  27: 'заскорузлый',
#  28: 'сидение',
#  29: 'грязно',
#  30: 'оборванный',
#  31: 'здравствуйте',
#  32: 'нерасчистить',
#  33: 'инвалидный',
#  34: 'наружу',
#  35: 'вышеупомянутый',
#  36: 'навес',
#  37: 'конкретно',
#  38: 'колпак',
#  39: 'добавиться',
#  40: 'президент',
#  41: 'теплосеть',
#  42: 'перекидывание',
#  43: 'небо',
#  44: 'сомнительный',
#  45: 'зашпаклевать',
#  46: 'верно',
#  47: 'существенный',
#  48: 'щелчок',
#  49: 'статус',
#  50: 'вышеизложенный',
#  51: 'ежевика',
#  52: 'круглосуточно',
#  53: 'первозданный',
#  54: 'отсыпка',
#  55: 'прибрать',
#  56: 'приоткрываться',
#  57: 'исключительно',
#  58: 'толк',
#  59: 'неподключённый',
#  60: 'бутыль',
#  61: 'подотчётный',
#  62: 'пиво',
#  63: 'информировать',
#  64: 'эркер',
#  65: 'уполномочить',
#  66: 'разделять',
#  67: 'иметь',
#  68: 'кабинка',
#  69: 'облагородить',
#  70: 'гс',
#  71: 'ломаный',
#  72: 'вытяжка',
#  73: 'литр',
#  74: 'сыпаться',
#  75: 'зеленогорск',
#  76: 'водопроводчик',
#  77: 'производный',
#  78: 'хватать',
#  79: 'домоуправа',
#  80: 'производиться',
#  81: 'треснуть',
#  82: 'вырубать',
#  83: 'зсд',
#  84: 'порезаться',
#  85: 'незакрытый',
#  86: 'активно',
#  87: 'коллекторный',
#  88: 'вырубить',
#  89: 'мусоропремник',
#  90: 'отвернуться',
#  91: 'наличный',
#  92: 'старый',
#  93: 'наступать',
#  94: 'снег',
#  95: 'ужасающий',
#  96: 'специализировать',
#  97: 'энергоэффективность',
#  98: 'рыбка',
#  99: 'ухоженно',
#  100: 'разворот',
#  101: 'обрубка',
#  102: 'калининский',
#  103: 'курсант',
#  104: 'галицкий',
#  105: 'оставлять',
#  106: 'фактор',
#  107: 'недолговечный',
#  108: 'весна',
#  109: 'сз',
#  110: 'перемычка',
#  111: 'штендер',
#  112: 'гаврскай',
#  113: 'михаил',
#  114: 'разовый',
#  115: 'встроить',
#  116: 'поток',
#  117: 'ожидание',
#  118: 'перилла',
#  119: 'теплосбережение',
#  120: 'исчезновение',
#  121: 'шум',
#  122: 'xxxx',
#  123: 'безалаберный',
#  124: 'ежегодно',
#  125: 'округ',
#  126: 'тж',
#  127: 'кл',
#  128: 'приоткрыть',
#  129: 'чиститься',
#  130: 'овощной',
#  131: 'накатом',
#  132: 'пересылать',
#  133: 'выехать',
#  134: 'ботинок',
#  135: 'стиральный',
#  136: 'янтарный',
#  137: 'петроэлектросбыт',
#  138: 'блестеть',
#  139: 'спрессовать',
#  140: 'труп',
#  141: 'утеплительный',
#  142: 'прогнать',
#  143: 'встречный',
#  144: 'колейность',
#  145: 'коллега',
#  146: 'дырка',
#  147: 'приняться',
#  148: 'лад',
#  149: 'повалить',
#  150: 'фриз',
#  151: 'тверская',
#  152: 'строиться',
#  153: 'неуместный',
#  154: 'неправильно',
#  155: 'чёрный',
#  156: 'прекратиться',
#  157: 'огораживать',
#  158: 'выделять',
#  159: 'распредкоробка',
#  160: 'муфта',
#  161: 'рабфаковский',
#  162: 'светлый',
#  163: 'беркг',
#  164: 'вышеобозначить',
#  165: 'прибавляться',
#  166: 'ямочный',
#  167: 'голосование',
#  168: 'домовладение',
#  169: 'ставиться',
#  170: 'горсть',
#  171: 'представиться',
#  172: 'пионерстрой',
#  173: 'зависимость',
#  174: 'несчастный',
#  175: 'скрип',
#  176: 'приборка',
#  177: 'обшить',
#  178: 'комплектующие',
#  179: 'перетекание',
#  180: 'отсыревания',
#  181: 'космодемьянский',
#  182: 'успешный',
#  183: 'скидка',
#  184: 'прилотковый',
#  185: 'неработающий',
#  186: 'дыхание',
#  187: 'малолитражка',
#  188: 'закуска',
#  189: 'поклонногорский',
#  190: 'собичие',
#  191: 'подозрение',
#  192: 'однакратный',
#  193: 'чужой',
#  194: 'непрезентабельный',
#  195: 'интенсивный',
#  196: 'двойной',
#  197: 'осмотр',
#  198: 'вместо',
#  199: 'предназначить',
#  200: 'врезка',
#  201: 'фактори',
#  202: 'белечий',
#  203: 'коап',
#  204: 'цвет',
#  205: 'виновный',
#  206: 'серебристый',
#  207: 'стенв',
#  208: 'ливнесток',
#  209: 'продизенфицировать',
#  210: 'деформированый',
#  211: 'затапливать',
#  212: 'територий',
#  213: 'передаваться',
#  214: 'токопроводник',
#  215: 'неактуальный',
#  216: 'великолукский',
#  217: 'вымостить',
#  218: 'николай',
#  219: 'разровнять',
#  220: 'подделка',
#  221: 'болтаться',
#  222: 'азия',
#  223: 'воспитанный',
#  224: 'сдать',
#  225: 'сход',
#  226: 'мечта',
#  227: 'осветить',
#  228: 'сутки',
#  229: 'балконный',
#  230: 'провоцыровать',
#  231: 'общедолевой',
#  232: 'изображение',
#  233: 'оао',
#  234: 'доводчик',
#  235: 'внешний',
#  236: 'утиный',
#  237: 'рома',
#  238: 'гидроизоляционный',
#  239: 'вокзал',
#  240: 'турник',
#  241: 'морозко',
#  242: 'колледж',
#  243: 'диспетчер',
#  244: 'совет',
#  245: 'указаный',
#  246: 'неоднократно',
#  247: 'ямка',
#  248: 'сосед',
#  249: 'предупреждать',
#  250: 'успешно',
#  251: 'усложнять',
#  252: 'шар',
#  253: 'закрутить',
#  254: 'чайковский',
#  255: 'бесхозяйный',
#  256: 'источник',
#  257: 'востановить',
#  258: 'заморозка',
#  259: 'возможно',
#  260: 'снегоуборочный',
#  261: 'уделить',
#  262: 'чай',
#  263: 'пряжка',
#  264: 'скрипеть',
#  265: 'шесть',
#  266: 'течь',
#  267: 'рогод',
#  268: 'разъезд',
#  269: 'складывать',
#  270: 'дополнительно',
#  271: 'счистить',
#  272: 'удачно',
#  273: 'пластрон',
#  274: 'вынуть',
#  275: 'бампер',
#  276: 'пожарный',
#  277: 'буква',
#  278: 'пробираться',
#  279: 'дозвониться',
#  280: 'навалить',
#  281: 'система',
#  282: 'контролёр',
#  283: 'купить',
#  284: 'спать',
#  285: 'проставляться',
#  286: 'щэ',
#  287: 'август',
#  288: 'настоящий',
#  289: 'зазывала',
#  290: 'одеяло',
#  291: 'земельный',
#  292: 'забывать',
#  293: 'узнать',
#  294: 'воздухоотводчик',
#  295: 'сигнальный',
#  296: 'электросеть',
#  297: 'ведро',
#  298: 'продуктовый',
#  299: 'линолеумза',
#  300: 'маршал',
#  301: 'кронштадтский',
#  302: 'вмех',
#  303: 'гораздо',
#  304: 'устав',
#  305: 'каток',
#  306: 'протяжка',
#  307: 'полозов',
#  308: 'ив',
#  309: 'ширина',
#  310: 'асфальтовый',
#  311: 'элекрощитка',
#  312: 'превышать',
#  313: 'василеостровский',
#  314: 'псс',
#  315: 'недостаточный',
#  316: 'владимирский',
#  317: 'парнас',
#  318: 'обслкживание',
#  319: 'погибнуть',
#  320: 'каир',
#  321: 'отключение',
#  322: 'подвал',
#  323: 'вовсе',
#  324: 'экскримент',
#  325: 'страница',
#  326: 'указанный',
#  327: 'угорелый',
#  328: 'пластиковый',
#  329: 'контингент',
#  330: 'адресация',
#  331: 'изнутри',
#  332: 'угловой',
#  333: 'устрана',
#  334: 'немало',
#  335: 'проходить',
#  336: 'бутовый',
#  337: 'штука',
#  338: 'целостность',
#  339: 'болт',
#  340: 'капание',
#  341: 'желать',
#  342: 'вряд',
#  343: 'фонтанный',
#  344: 'предприятие',
#  345: 'мытый',
#  346: 'эты',
#  347: 'водоём',
#  348: 'санкционировать',
#  349: 'котельная',
#  350: 'нависнуть',
#  351: 'скб',
#  352: 'запуск',
#  353: 'левый',
#  354: 'пожаловаться',
#  355: 'крутиться',
#  356: 'хулиган',
#  357: 'достроить',
#  358: 'бфа',
#  359: 'шарик',
#  360: 'избежать',
#  361: 'разметить',
#  362: 'ограждать',
#  363: 'ке',
#  364: 'щепка',
#  365: 'признак',
#  366: 'чс',
#  367: 'раскидывать',
#  368: 'лестница',
#  369: 'отделочный',
#  370: 'аварийность',
#  371: 'сравнение',
#  372: 'исправлять',
#  373: 'обильный',
#  374: 'толщина',
#  375: 'закрашивать',
#  376: 'контейнер',
#  377: 'выдерживать',
#  378: 'случаться',
#  379: 'кантемировский',
#  380: 'член',
#  381: 'внешне',
#  382: 'нейтральный',
#  383: 'вечером',
#  384: 'таракан',
#  385: 'декор',
#  386: 'вид',
#  387: 'повышение',
#  388: 'прилагаться',
#  389: 'некуда',
#  390: 'потёртость',
#  391: 'известный',
#  392: 'лопата',
#  393: 'оставление',
#  394: 'канавка',
#  395: 'умыться',
#  396: 'прорвать',
#  397: 'оккервиль',
#  398: 'оказываться',
#  399: 'средство',
#  400: 'подрезка',
#  401: 'население',
#  402: 'цветовик',
#  403: 'лавочка',
#  404: 'вздуться',
#  405: 'армированный',
#  406: 'получать',
#  407: 'сбить',
#  408: 'пункт',
#  409: 'мошуваловый',
#  410: 'способ',
#  411: 'перекладывать',
#  412: 'домофонной',
#  413: 'моментальный',
#  414: 'дудергофский',
#  415: 'половой',
#  416: 'разместить',
#  417: 'почта',
#  418: 'мумифицироваться',
#  419: 'давно',
#  420: 'веник',
#  421: 'вывозиться',
#  422: 'начать',
#  423: 'автоматический',
#  424: 'заштукатурить',
#  425: 'океанариум',
#  426: 'прожечь',
#  427: 'львиный',
#  428: 'песок',
#  429: 'декабрист',
#  430: 'яркий',
#  431: 'околонулевой',
#  432: 'тср',
#  433: 'направляться',
#  434: 'повлечь',
#  435: 'искривить',
#  436: 'дольщик',
#  437: 'минус',
#  438: 'подлог',
#  439: 'рама',
#  440: 'замыкание',
#  441: 'лежак',
#  442: 'ракурс',
#  443: 'четыре',
#  444: 'называться',
#  445: 'газопровод',
#  446: 'легковой',
#  447: 'наш',
#  448: 'шагрень',
#  449: 'расписаться',
#  450: 'требукться',
#  451: 'сложный',
#  452: 'метро',
#  453: 'пятьдесят',
#  454: 'поколение',
#  455: 'объект',
#  456: 'шерсть',
#  457: 'прогулочный',
#  458: 'пожаронебезопасный',
#  459: 'заранее',
#  460: 'многократный',
#  461: 'оградить',
#  462: 'жикомсервис',
#  463: 'дочка',
#  464: 'полноразмерный',
#  465: 'перетащить',
#  466: 'колышек',
#  467: 'север',
#  468: 'промазывать',
#  469: 'неустранённый',
#  470: 'фонд',
#  471: 'свалить',
#  472: 'сдуваюать',
#  473: 'код',
#  474: 'проинструктировать',
#  475: 'защищать',
#  476: 'кардинальный',
#  477: 'очищать',
#  478: 'поликарбонат',
#  479: 'врыть',
#  480: 'маяковский',
#  481: 'переговорный',
#  482: 'отвратительный',
#  483: 'юго',
#  484: 'электрооборудование',
#  485: 'ограждение',
#  486: 'лестнечный',
#  487: 'беда',
#  488: 'гарь',
#  489: 'будить',
#  490: 'оборотный',
#  491: 'прожекторный',
#  492: 'нахимов',
#  493: 'зноп',
#  494: 'электроника',
#  495: 'рабочий',
#  496: 'прекратить',
#  497: 'необходимо',
#  498: 'острый',
#  499: 'скапливаться',
#  500: 'безопасность',
#  501: 'опасность',
#  502: 'фекалия',
#  503: 'собственность',
#  504: 'основа',
#  505: 'исключить',
#  506: 'просачиваться',
#  507: 'последнеднём',
#  508: 'подьеза',
#  509: 'автотранспорт',
#  510: 'зарастать',
#  511: 'усиливаться',
#  512: 'возвращаться',
#  513: 'утащить',
#  514: 'каша',
#  515: 'деятельность',
#  516: 'мехуборка',
#  517: 'вандал',
#  518: 'удовлетворение',
#  519: 'организация',
#  520: 'наружный',
#  521: 'посадить',
#  522: 'владение',
#  523: 'вынести',
#  524: 'фёдор',
#  525: 'прекрасный',
#  526: 'гранитный',
#  527: 'собранный',
#  528: 'солевой',
#  529: 'мёрзнуть',
#  530: 'частность',
#  531: 'замерзание',
#  532: 'долгоозёрный',
#  533: 'пень',
#  534: 'неоднородность',
#  535: 'пружина',
#  536: 'просъб',
#  537: 'ильюшин',
#  538: 'добавить',
#  539: 'кронация',
#  540: 'характер',
#  541: 'ую',
#  542: 'ода',
#  543: 'многие',
#  544: 'комар',
#  545: 'обосновать',
#  546: 'разгоняться',
#  547: 'доказательство',
#  548: 'дефектный',
#  549: 'печальный',
#  550: 'несмотря',
#  551: 'столб',
#  552: 'бортик',
#  553: 'плановый',
#  554: 'лоток',
#  555: 'кабина',
#  556: 'несоблюдаеться',
#  557: 'прицеп',
#  558: 'освещерия',
#  559: 'почтамтский',
#  560: 'обходить',
#  561: 'зиять',
#  562: 'тугой',
#  563: 'благодаря',
#  564: 'местный',
#  565: 'придеться',
#  566: 'кролик',
#  567: 'исполнитель',
#  568: 'кампания',
#  569: 'жвачка',
#  570: 'скользко',
#  571: 'ветхость',
#  572: 'лицезреть',
#  573: 'мысль',
#  574: 'касающиийся',
#  575: 'gov',
#  576: 'участие',
#  577: 'шаг',
#  578: 'обильно',
#  579: 'коллективный',
#  580: 'легендарный',
#  581: 'створка',
#  582: 'заполнение',
#  583: 'сегодня',
#  584: 'просохнуть',
#  585: 'рубцов',
#  586: 'подровнять',
#  587: 'вандальский',
#  588: 'кольцо',
#  589: 'нагреться',
#  590: 'труднодоступный',
#  591: 'собирать',
#  592: 'карниз',
#  593: 'тож',
#  594: 'финальный',
#  595: 'следовательно',
#  596: 'моча',
#  597: 'нашествие',
#  598: 'смеситель',
#  599: 'грубо',
#  600: 'совесть',
#  601: 'снизу',
#  602: 'почтовый',
#  603: 'произвольно',
#  604: 'посторонний',
#  605: 'рядом',
#  606: 'уклон',
#  607: 'неполадка',
#  608: 'ковш',
#  609: 'вычистить',
#  610: 'разукрасить',
#  611: 'расходиться',
#  612: 'км',
#  613: 'бабуля',
#  614: 'афишный',
#  615: 'линейный',
#  616: 'глубокий',
#  617: 'лестничноц',
#  618: 'доступ',
#  619: 'начаться',
#  620: 'процент',
#  621: 'окрасочный',
#  622: 'арматура',
#  623: 'пражский',
#  624: 'голубятня',
#  625: 'гнить',
#  626: 'чичеринский',
#  627: 'надлежащий',
#  628: 'хэу',
#  629: 'полгода',
#  630: 'зазывать',
#  631: 'проржаветь',
#  632: 'посещать',
#  633: 'столь',
#  634: 'реставрационный',
#  635: 'велосипедный',
#  636: 'выцвелый',
#  637: 'взыскание',
#  638: 'уважение',
#  639: 'правильно',
#  640: 'ленсоветовский',
#  641: 'проконтролировать',
#  642: 'дерптский',
#  643: 'устрашать',
#  644: 'удар',
#  645: 'вверх',
#  646: 'доказать',
#  647: 'пандус',
#  648: 'картонка',
#  649: 'люблинский',
#  650: 'аэродромный',
#  651: 'вскрыть',
#  652: 'качественно',
#  653: 'атмосферный',
#  654: 'основной',
#  655: 'агентство',
#  656: 'качестая',
#  657: 'котофей',
#  658: 'год',
#  659: 'применить',
#  660: 'знание',
#  661: 'возмещение',
#  662: 'разрушать',
#  663: 'банер',
#  664: 'ежедневно',
#  665: 'принудительный',
#  666: 'параодный',
#  667: 'давать',
#  668: 'загрязнить',
#  669: 'революция',
#  670: 'выкачивать',
#  671: 'пто',
#  672: 'памятный',
#  673: 'тажа',
#  674: 'окрашивание',
#  675: 'тон',
#  676: 'санкция',
#  677: 'простой',
#  678: 'осущест',
#  679: 'наркотический',
#  680: 'некрасов',
#  681: 'падение',
#  682: 'опознавательный',
#  683: 'лесничный',
#  684: 'молодой',
#  685: 'воспользоваться',
#  686: 'приглушить',
#  687: 'капремонт',
#  688: 'ржаветь',
#  689: 'заменяться',
#  690: 'дойников',
#  691: 'балерина',
#  692: 'пролетарский',
#  693: 'прежний',
#  694: 'выправка',
#  695: 'алкогольный',
#  696: 'светложелтый',
#  697: 'прекращать',
#  698: 'подчинить',
#  699: 'читаемый',
#  700: 'время',
#  701: 'рольставень',
#  702: 'глухой',
#  703: 'устанить',
#  704: 'заделывать',
#  705: 'перила',
#  706: 'пахнуть',
#  707: 'мм',
#  708: 'вниз',
#  709: 'негорт',
#  710: 'обязать',
#  711: 'скрежет',
#  712: 'недопускать',
#  713: 'заплатка',
#  714: 'напоминать',
#  715: 'перебой',
#  716: 'глубокоуважаемый',
#  717: 'универсам',
#  718: 'кнопочный',
#  719: 'нарушеннго',
#  720: 'тонема',
#  721: 'написание',
#  722: 'колористический',
#  723: 'поддерживать',
#  724: 'жизнедеятельность',
#  725: 'обращать',
#  726: 'петергоф',
#  727: 'стоить',
#  728: 'дизайн',
#  729: 'придерживаться',
#  730: 'экстремистский',
#  731: 'жэк',
#  732: 'безобразный',
#  733: 'скуда',
#  734: 'люминесценция',
#  735: 'страшный',
#  736: 'минь',
#  737: 'почернеть',
#  738: 'оклейка',
#  739: 'бучить',
#  740: 'сентябрь',
#  741: 'грп',
#  742: 'возмездный',
#  743: 'новочеркасский',
#  744: 'правообладатель',
#  745: 'выброс',
#  746: 'смывание',
#  747: 'оснастить',
#  748: 'рельеф',
#  749: 'износиться',
#  750: 'щель',
#  751: 'помещение',
#  752: 'доу',
#  753: 'жалкий',
#  754: 'трэш',
#  755: 'мчаться',
#  756: 'негде',
#  757: 'смоленский',
#  758: 'окно',
#  759: 'неровно',
#  760: 'рубинштейн',
#  761: 'бюджетный',
#  762: 'поинтересоваться',
#  763: 'перемешать',
#  764: 'вселяться',
#  765: 'заморозок',
#  766: 'фрукт',
#  767: 'возраст',
#  768: 'вышесказанный',
#  769: 'отражаться',
#  770: 'отписаться',
#  771: 'последствие',
#  772: 'оказание',
#  773: 'разбить',
#  774: 'навести',
#  775: 'новосмоленский',
#  776: 'хазов',
#  777: 'незакреплённый',
#  778: 'полдень',
#  779: 'модуль',
#  780: 'рыбацкий',
#  781: 'переполнить',
#  782: 'трус',
#  783: 'пешеходный',
#  784: 'кварплат',
#  785: 'роллер',
#  786: 'вонять',
#  787: 'слуга',
#  788: 'эстетический',
#  789: 'дудин',
#  790: 'будни',
#  791: 'эксплутации',
#  792: 'здать',
#  793: 'солдат',
#  794: 'ым',
#  795: 'курьер',
#  796: 'завестись',
#  797: 'планк',
#  798: 'укомплектовать',
#  799: 'второй',
#  800: 'фактический',
#  801: 'промоина',
#  802: 'разлетаться',
#  803: 'наука',
#  804: 'восстанавливать',
#  805: 'окружающий',
#  806: 'катастрофа',
#  807: 'содержимое',
#  808: 'курение',
#  809: 'убедительный',
#  810: 'отслаивание',
#  811: 'закрытый',
#  812: 'городок',
#  813: 'дорожный',
#  814: 'главстроить',
#  815: 'инфекция',
#  816: 'сдуть',
#  817: 'хулиганский',
#  818: 'тк',
#  819: 'срочный',
#  820: 'благустройство',
#  821: 'мысленно',
#  822: 'замерзать',
#  823: 'выгодно',
#  824: 'расстояние',
#  825: 'очевидный',
#  826: 'требовать',
#  827: 'бак',
#  828: 'магнититься',
#  829: 'цифра',
#  830: 'шуметь',
#  831: 'убиться',
#  832: 'петроградский',
#  833: 'рассматриваться',
#  834: 'непригодный',
#  835: 'поляна',
#  836: 'село',
#  837: 'наконечник',
#  838: 'оружейник',
#  839: 'раздвинуться',
#  840: 'ликвидация',
#  841: 'ход',
#  842: 'оштрафовать',
#  843: 'примагнитить',
#  844: 'средний',
#  845: 'наметать',
#  846: 'простить',
#  847: 'дезинсекция',
#  848: 'наполовину',
#  849: 'проступать',
#  850: 'административка',
#  851: 'идеальный',
#  852: 'тополь',
#  853: 'баннер',
#  854: 'усть',
#  855: 'многий',
#  856: 'звуковой',
#  857: 'разбросать',
#  858: 'проч',
#  859: 'зайти',
#  860: 'достоверность',
#  861: 'доводиться',
#  862: 'складироваться',
#  863: 'заклинивать',
#  864: 'запорный',
#  865: 'выцвеить',
#  866: 'запустить',
#  867: 'немой',
#  868: 'прохождение',
#  869: 'обьект',
#  870: 'бачок',
#  871: 'растяжка',
#  872: 'потолочный',
#  873: 'закрывать',
#  874: 'безумно',
#  875: 'недочёт',
#  876: 'полис',
#  877: 'неприличный',
#  878: 'рувд',
#  879: 'эвакуация',
#  880: 'коломяжский',
#  881: 'уборщица',
#  882: 'обметаться',
#  883: 'казарма',
#  884: 'размыть',
#  885: 'писк',
#  886: 'посадка',
#  887: 'громкий',
#  888: 'посередине',
#  889: 'пройти',
#  890: 'растрескивание',
#  891: 'понять',
#  892: 'сказать',
#  893: 'отказываться',
#  894: 'переносный',
#  895: 'неудобство',
#  896: 'магнитный',
#  897: 's',
#  898: 'похожий',
#  899: 'польза',
#  900: 'зина',
#  901: 'отрегулировать',
#  902: 'предел',
#  903: 'бурцев',
#  904: 'перекрыть',
#  905: 'кафель',
#  906: 'расклеивать',
#  907: 'сообщение',
#  908: 'н',
#  909: 'дворовый',
#  910: 'комиссия',
#  911: 'таить',
#  912: 'филя',
#  913: 'сохранение',
#  914: 'муравейник',
#  915: 'садовый',
#  916: 'председатель',
#  917: 'свод',
#  918: 'выборочный',
#  919: 'хламовникнуть',
#  920: 'кошка',
#  921: 'уплотнение',
#  922: 'трещина',
#  923: 'просидеть',
#  924: 'роллета',
#  925: 'больной',
#  926: 'количество',
#  927: 'загребский',
#  928: 'дружба',
#  929: 'засунуть',
#  930: 'становиться',
#  931: 'провезти',
#  932: 'желательно',
#  933: 'цепочный',
#  934: 'отсесть',
#  935: 'продажа',
#  936: 'капитан',
#  937: 'авиатор',
#  938: 'столбик',
#  939: 'мыть',
#  940: 'ходовой',
#  941: 'девятый',
#  942: 'щитовой',
#  943: 'маслянистый',
#  944: 'вытаскивать',
#  945: 'скоро',
#  946: 'водосток',
#  947: 'росреестр',
#  948: 'метать',
#  949: 'проезжейчасть',
#  950: 'бц',
#  951: 'отогнуть',
#  952: 'мятый',
#  953: 'депо',
#  954: 'металлопластиковый',
#  955: 'сочиться',
#  956: 'телега',
#  957: 'пушистый',
#  958: 'велдберс',
#  959: 'подметать',
#  960: 'xxxxxxxxxxxxxxxxx',
#  961: 'мочалка',
#  962: 'грохот',
#  963: 'доска',
#  964: 'снаряд',
#  965: 'двигать',
#  966: 'лечиться',
#  967: 'гидрант',
#  968: 'всеволод',
#  969: 'птк',
#  970: 'закопать',
#  971: 'россеть',
#  972: 'чреватый',
#  973: 'осуществить',
#  974: 'вазон',
#  975: 'митрополикать',
#  976: 'наверно',
#  977: 'дольшея',
#  978: 'растянутый',
#  979: 'бесполезно',
#  980: 'думать',
#  981: 'чистить',
#  982: 'наладочный',
#  983: 'тротуарный',
#  984: 'хомут',
#  985: 'протирать',
#  986: 'подумать',
#  987: 'сквозной',
#  988: 'отваливаться',
#  989: 'сконструировать',
#  990: 'перекособочить',
#  991: 'кун',
#  992: 'зависать',
#  993: 'отодрать',
#  994: 'обслуживаться',
#  995: 'морозов',
#  996: 'дезинфицироваться',
#  997: 'видимо',
#  998: 'намазать',
#  999: 'отчёт',
#  ...}

# %%
word_id = {v: k for k, v in id_word.items()}
word_id
# Out:
# {'взудитие': 0,
#  'утверждение': 1,
#  'ношение': 2,
#  'стать': 3,
#  'зайцев': 4,
#  'гск': 5,
#  'инстанция': 6,
#  'новорождённый': 7,
#  'бездейстовать': 8,
#  'неудовлетворительно': 9,
#  'чебышевский': 10,
#  'частично': 11,
#  'достаточно': 12,
#  'параднойгрязь': 13,
#  'судебный': 14,
#  'пища': 15,
#  'снаружи': 16,
#  'петербург': 17,
#  'таракашка': 18,
#  'прохладный': 19,
#  'указываться': 20,
#  'тройка': 21,
#  'зацементировать': 22,
#  'облицевать': 23,
#  'неудолетворительный': 24,
#  'блюхер': 25,
#  'молодец': 26,
#  'заскорузлый': 27,
#  'сидение': 28,
#  'грязно': 29,
#  'оборванный': 30,
#  'здравствуйте': 31,
#  'нерасчистить': 32,
#  'инвалидный': 33,
#  'наружу': 34,
#  'вышеупомянутый': 35,
#  'навес': 36,
#  'конкретно': 37,
#  'колпак': 38,
#  'добавиться': 39,
#  'президент': 40,
#  'теплосеть': 41,
#  'перекидывание': 42,
#  'небо': 43,
#  'сомнительный': 44,
#  'зашпаклевать': 45,
#  'верно': 46,
#  'существенный': 47,
#  'щелчок': 48,
#  'статус': 49,
#  'вышеизложенный': 50,
#  'ежевика': 51,
#  'круглосуточно': 52,
#  'первозданный': 53,
#  'отсыпка': 54,
#  'прибрать': 55,
#  'приоткрываться': 56,
#  'исключительно': 57,
#  'толк': 58,
#  'неподключённый': 59,
#  'бутыль': 60,
#  'подотчётный': 61,
#  'пиво': 62,
#  'информировать': 63,
#  'эркер': 64,
#  'уполномочить': 65,
#  'разделять': 66,
#  'иметь': 67,
#  'кабинка': 68,
#  'облагородить': 69,
#  'гс': 70,
#  'ломаный': 71,
#  'вытяжка': 72,
#  'литр': 73,
#  'сыпаться': 74,
#  'зеленогорск': 75,
#  'водопроводчик': 76,
#  'производный': 77,
#  'хватать': 78,
#  'домоуправа': 79,
#  'производиться': 80,
#  'треснуть': 81,
#  'вырубать': 82,
#  'зсд': 83,
#  'порезаться': 84,
#  'незакрытый': 85,
#  'активно': 86,
#  'коллекторный': 87,
#  'вырубить': 88,
#  'мусоропремник': 89,
#  'отвернуться': 90,
#  'наличный': 91,
#  'старый': 92,
#  'наступать': 93,
#  'снег': 94,
#  'ужасающий': 95,
#  'специализировать': 96,
#  'энергоэффективность': 97,
#  'рыбка': 98,
#  'ухоженно': 99,
#  'разворот': 100,
#  'обрубка': 101,
#  'калининский': 102,
#  'курсант': 103,
#  'галицкий': 104,
#  'оставлять': 105,
#  'фактор': 106,
#  'недолговечный': 107,
#  'весна': 108,
#  'сз': 109,
#  'перемычка': 110,
#  'штендер': 111,
#  'гаврскай': 112,
#  'михаил': 113,
#  'разовый': 114,
#  'встроить': 115,
#  'поток': 116,
#  'ожидание': 117,
#  'перилла': 118,
#  'теплосбережение': 119,
#  'исчезновение': 120,
#  'шум': 121,
#  'xxxx': 122,
#  'безалаберный': 123,
#  'ежегодно': 124,
#  'округ': 125,
#  'тж': 126,
#  'кл': 127,
#  'приоткрыть': 128,
#  'чиститься': 129,
#  'овощной': 130,
#  'накатом': 131,
#  'пересылать': 132,
#  'выехать': 133,
#  'ботинок': 134,
#  'стиральный': 135,
#  'янтарный': 136,
#  'петроэлектросбыт': 137,
#  'блестеть': 138,
#  'спрессовать': 139,
#  'труп': 140,
#  'утеплительный': 141,
#  'прогнать': 142,
#  'встречный': 143,
#  'колейность': 144,
#  'коллега': 145,
#  'дырка': 146,
#  'приняться': 147,
#  'лад': 148,
#  'повалить': 149,
#  'фриз': 150,
#  'тверская': 151,
#  'строиться': 152,
#  'неуместный': 153,
#  'неправильно': 154,
#  'чёрный': 155,
#  'прекратиться': 156,
#  'огораживать': 157,
#  'выделять': 158,
#  'распредкоробка': 159,
#  'муфта': 160,
#  'рабфаковский': 161,
#  'светлый': 162,
#  'беркг': 163,
#  'вышеобозначить': 164,
#  'прибавляться': 165,
#  'ямочный': 166,
#  'голосование': 167,
#  'домовладение': 168,
#  'ставиться': 169,
#  'горсть': 170,
#  'представиться': 171,
#  'пионерстрой': 172,
#  'зависимость': 173,
#  'несчастный': 174,
#  'скрип': 175,
#  'приборка': 176,
#  'обшить': 177,
#  'комплектующие': 178,
#  'перетекание': 179,
#  'отсыревания': 180,
#  'космодемьянский': 181,
#  'успешный': 182,
#  'скидка': 183,
#  'прилотковый': 184,
#  'неработающий': 185,
#  'дыхание': 186,
#  'малолитражка': 187,
#  'закуска': 188,
#  'поклонногорский': 189,
#  'собичие': 190,
#  'подозрение': 191,
#  'однакратный': 192,
#  'чужой': 193,
#  'непрезентабельный': 194,
#  'интенсивный': 195,
#  'двойной': 196,
#  'осмотр': 197,
#  'вместо': 198,
#  'предназначить': 199,
#  'врезка': 200,
#  'фактори': 201,
#  'белечий': 202,
#  'коап': 203,
#  'цвет': 204,
#  'виновный': 205,
#  'серебристый': 206,
#  'стенв': 207,
#  'ливнесток': 208,
#  'продизенфицировать': 209,
#  'деформированый': 210,
#  'затапливать': 211,
#  'територий': 212,
#  'передаваться': 213,
#  'токопроводник': 214,
#  'неактуальный': 215,
#  'великолукский': 216,
#  'вымостить': 217,
#  'николай': 218,
#  'разровнять': 219,
#  'подделка': 220,
#  'болтаться': 221,
#  'азия': 222,
#  'воспитанный': 223,
#  'сдать': 224,
#  'сход': 225,
#  'мечта': 226,
#  'осветить': 227,
#  'сутки': 228,
#  'балконный': 229,
#  'провоцыровать': 230,
#  'общедолевой': 231,
#  'изображение': 232,
#  'оао': 233,
#  'доводчик': 234,
#  'внешний': 235,
#  'утиный': 236,
#  'рома': 237,
#  'гидроизоляционный': 238,
#  'вокзал': 239,
#  'турник': 240,
#  'морозко': 241,
#  'колледж': 242,
#  'диспетчер': 243,
#  'совет': 244,
#  'указаный': 245,
#  'неоднократно': 246,
#  'ямка': 247,
#  'сосед': 248,
#  'предупреждать': 249,
#  'успешно': 250,
#  'усложнять': 251,
#  'шар': 252,
#  'закрутить': 253,
#  'чайковский': 254,
#  'бесхозяйный': 255,
#  'источник': 256,
#  'востановить': 257,
#  'заморозка': 258,
#  'возможно': 259,
#  'снегоуборочный': 260,
#  'уделить': 261,
#  'чай': 262,
#  'пряжка': 263,
#  'скрипеть': 264,
#  'шесть': 265,
#  'течь': 266,
#  'рогод': 267,
#  'разъезд': 268,
#  'складывать': 269,
#  'дополнительно': 270,
#  'счистить': 271,
#  'удачно': 272,
#  'пластрон': 273,
#  'вынуть': 274,
#  'бампер': 275,
#  'пожарный': 276,
#  'буква': 277,
#  'пробираться': 278,
#  'дозвониться': 279,
#  'навалить': 280,
#  'система': 281,
#  'контролёр': 282,
#  'купить': 283,
#  'спать': 284,
#  'проставляться': 285,
#  'щэ': 286,
#  'август': 287,
#  'настоящий': 288,
#  'зазывала': 289,
#  'одеяло': 290,
#  'земельный': 291,
#  'забывать': 292,
#  'узнать': 293,
#  'воздухоотводчик': 294,
#  'сигнальный': 295,
#  'электросеть': 296,
#  'ведро': 297,
#  'продуктовый': 298,
#  'линолеумза': 299,
#  'маршал': 300,
#  'кронштадтский': 301,
#  'вмех': 302,
#  'гораздо': 303,
#  'устав': 304,
#  'каток': 305,
#  'протяжка': 306,
#  'полозов': 307,
#  'ив': 308,
#  'ширина': 309,
#  'асфальтовый': 310,
#  'элекрощитка': 311,
#  'превышать': 312,
#  'василеостровский': 313,
#  'псс': 314,
#  'недостаточный': 315,
#  'владимирский': 316,
#  'парнас': 317,
#  'обслкживание': 318,
#  'погибнуть': 319,
#  'каир': 320,
#  'отключение': 321,
#  'подвал': 322,
#  'вовсе': 323,
#  'экскримент': 324,
#  'страница': 325,
#  'указанный': 326,
#  'угорелый': 327,
#  'пластиковый': 328,
#  'контингент': 329,
#  'адресация': 330,
#  'изнутри': 331,
#  'угловой': 332,
#  'устрана': 333,
#  'немало': 334,
#  'проходить': 335,
#  'бутовый': 336,
#  'штука': 337,
#  'целостность': 338,
#  'болт': 339,
#  'капание': 340,
#  'желать': 341,
#  'вряд': 342,
#  'фонтанный': 343,
#  'предприятие': 344,
#  'мытый': 345,
#  'эты': 346,
#  'водоём': 347,
#  'санкционировать': 348,
#  'котельная': 349,
#  'нависнуть': 350,
#  'скб': 351,
#  'запуск': 352,
#  'левый': 353,
#  'пожаловаться': 354,
#  'крутиться': 355,
#  'хулиган': 356,
#  'достроить': 357,
#  'бфа': 358,
#  'шарик': 359,
#  'избежать': 360,
#  'разметить': 361,
#  'ограждать': 362,
#  'ке': 363,
#  'щепка': 364,
#  'признак': 365,
#  'чс': 366,
#  'раскидывать': 367,
#  'лестница': 368,
#  'отделочный': 369,
#  'аварийность': 370,
#  'сравнение': 371,
#  'исправлять': 372,
#  'обильный': 373,
#  'толщина': 374,
#  'закрашивать': 375,
#  'контейнер': 376,
#  'выдерживать': 377,
#  'случаться': 378,
#  'кантемировский': 379,
#  'член': 380,
#  'внешне': 381,
#  'нейтральный': 382,
#  'вечером': 383,
#  'таракан': 384,
#  'декор': 385,
#  'вид': 386,
#  'повышение': 387,
#  'прилагаться': 388,
#  'некуда': 389,
#  'потёртость': 390,
#  'известный': 391,
#  'лопата': 392,
#  'оставление': 393,
#  'канавка': 394,
#  'умыться': 395,
#  'прорвать': 396,
#  'оккервиль': 397,
#  'оказываться': 398,
#  'средство': 399,
#  'подрезка': 400,
#  'население': 401,
#  'цветовик': 402,
#  'лавочка': 403,
#  'вздуться': 404,
#  'армированный': 405,
#  'получать': 406,
#  'сбить': 407,
#  'пункт': 408,
#  'мошуваловый': 409,
#  'способ': 410,
#  'перекладывать': 411,
#  'домофонной': 412,
#  'моментальный': 413,
#  'дудергофский': 414,
#  'половой': 415,
#  'разместить': 416,
#  'почта': 417,
#  'мумифицироваться': 418,
#  'давно': 419,
#  'веник': 420,
#  'вывозиться': 421,
#  'начать': 422,
#  'автоматический': 423,
#  'заштукатурить': 424,
#  'океанариум': 425,
#  'прожечь': 426,
#  'львиный': 427,
#  'песок': 428,
#  'декабрист': 429,
#  'яркий': 430,
#  'околонулевой': 431,
#  'тср': 432,
#  'направляться': 433,
#  'повлечь': 434,
#  'искривить': 435,
#  'дольщик': 436,
#  'минус': 437,
#  'подлог': 438,
#  'рама': 439,
#  'замыкание': 440,
#  'лежак': 441,
#  'ракурс': 442,
#  'четыре': 443,
#  'называться': 444,
#  'газопровод': 445,
#  'легковой': 446,
#  'наш': 447,
#  'шагрень': 448,
#  'расписаться': 449,
#  'требукться': 450,
#  'сложный': 451,
#  'метро': 452,
#  'пятьдесят': 453,
#  'поколение': 454,
#  'объект': 455,
#  'шерсть': 456,
#  'прогулочный': 457,
#  'пожаронебезопасный': 458,
#  'заранее': 459,
#  'многократный': 460,
#  'оградить': 461,
#  'жикомсервис': 462,
#  'дочка': 463,
#  'полноразмерный': 464,
#  'перетащить': 465,
#  'колышек': 466,
#  'север': 467,
#  'промазывать': 468,
#  'неустранённый': 469,
#  'фонд': 470,
#  'свалить': 471,
#  'сдуваюать': 472,
#  'код': 473,
#  'проинструктировать': 474,
#  'защищать': 475,
#  'кардинальный': 476,
#  'очищать': 477,
#  'поликарбонат': 478,
#  'врыть': 479,
#  'маяковский': 480,
#  'переговорный': 481,
#  'отвратительный': 482,
#  'юго': 483,
#  'электрооборудование': 484,
#  'ограждение': 485,
#  'лестнечный': 486,
#  'беда': 487,
#  'гарь': 488,
#  'будить': 489,
#  'оборотный': 490,
#  'прожекторный': 491,
#  'нахимов': 492,
#  'зноп': 493,
#  'электроника': 494,
#  'рабочий': 495,
#  'прекратить': 496,
#  'необходимо': 497,
#  'острый': 498,
#  'скапливаться': 499,
#  'безопасность': 500,
#  'опасность': 501,
#  'фекалия': 502,
#  'собственность': 503,
#  'основа': 504,
#  'исключить': 505,
#  'просачиваться': 506,
#  'последнеднём': 507,
#  'подьеза': 508,
#  'автотранспорт': 509,
#  'зарастать': 510,
#  'усиливаться': 511,
#  'возвращаться': 512,
#  'утащить': 513,
#  'каша': 514,
#  'деятельность': 515,
#  'мехуборка': 516,
#  'вандал': 517,
#  'удовлетворение': 518,
#  'организация': 519,
#  'наружный': 520,
#  'посадить': 521,
#  'владение': 522,
#  'вынести': 523,
#  'фёдор': 524,
#  'прекрасный': 525,
#  'гранитный': 526,
#  'собранный': 527,
#  'солевой': 528,
#  'мёрзнуть': 529,
#  'частность': 530,
#  'замерзание': 531,
#  'долгоозёрный': 532,
#  'пень': 533,
#  'неоднородность': 534,
#  'пружина': 535,
#  'просъб': 536,
#  'ильюшин': 537,
#  'добавить': 538,
#  'кронация': 539,
#  'характер': 540,
#  'ую': 541,
#  'ода': 542,
#  'многие': 543,
#  'комар': 544,
#  'обосновать': 545,
#  'разгоняться': 546,
#  'доказательство': 547,
#  'дефектный': 548,
#  'печальный': 549,
#  'несмотря': 550,
#  'столб': 551,
#  'бортик': 552,
#  'плановый': 553,
#  'лоток': 554,
#  'кабина': 555,
#  'несоблюдаеться': 556,
#  'прицеп': 557,
#  'освещерия': 558,
#  'почтамтский': 559,
#  'обходить': 560,
#  'зиять': 561,
#  'тугой': 562,
#  'благодаря': 563,
#  'местный': 564,
#  'придеться': 565,
#  'кролик': 566,
#  'исполнитель': 567,
#  'кампания': 568,
#  'жвачка': 569,
#  'скользко': 570,
#  'ветхость': 571,
#  'лицезреть': 572,
#  'мысль': 573,
#  'касающиийся': 574,
#  'gov': 575,
#  'участие': 576,
#  'шаг': 577,
#  'обильно': 578,
#  'коллективный': 579,
#  'легендарный': 580,
#  'створка': 581,
#  'заполнение': 582,
#  'сегодня': 583,
#  'просохнуть': 584,
#  'рубцов': 585,
#  'подровнять': 586,
#  'вандальский': 587,
#  'кольцо': 588,
#  'нагреться': 589,
#  'труднодоступный': 590,
#  'собирать': 591,
#  'карниз': 592,
#  'тож': 593,
#  'финальный': 594,
#  'следовательно': 595,
#  'моча': 596,
#  'нашествие': 597,
#  'смеситель': 598,
#  'грубо': 599,
#  'совесть': 600,
#  'снизу': 601,
#  'почтовый': 602,
#  'произвольно': 603,
#  'посторонний': 604,
#  'рядом': 605,
#  'уклон': 606,
#  'неполадка': 607,
#  'ковш': 608,
#  'вычистить': 609,
#  'разукрасить': 610,
#  'расходиться': 611,
#  'км': 612,
#  'бабуля': 613,
#  'афишный': 614,
#  'линейный': 615,
#  'глубокий': 616,
#  'лестничноц': 617,
#  'доступ': 618,
#  'начаться': 619,
#  'процент': 620,
#  'окрасочный': 621,
#  'арматура': 622,
#  'пражский': 623,
#  'голубятня': 624,
#  'гнить': 625,
#  'чичеринский': 626,
#  'надлежащий': 627,
#  'хэу': 628,
#  'полгода': 629,
#  'зазывать': 630,
#  'проржаветь': 631,
#  'посещать': 632,
#  'столь': 633,
#  'реставрационный': 634,
#  'велосипедный': 635,
#  'выцвелый': 636,
#  'взыскание': 637,
#  'уважение': 638,
#  'правильно': 639,
#  'ленсоветовский': 640,
#  'проконтролировать': 641,
#  'дерптский': 642,
#  'устрашать': 643,
#  'удар': 644,
#  'вверх': 645,
#  'доказать': 646,
#  'пандус': 647,
#  'картонка': 648,
#  'люблинский': 649,
#  'аэродромный': 650,
#  'вскрыть': 651,
#  'качественно': 652,
#  'атмосферный': 653,
#  'основной': 654,
#  'агентство': 655,
#  'качестая': 656,
#  'котофей': 657,
#  'год': 658,
#  'применить': 659,
#  'знание': 660,
#  'возмещение': 661,
#  'разрушать': 662,
#  'банер': 663,
#  'ежедневно': 664,
#  'принудительный': 665,
#  'параодный': 666,
#  'давать': 667,
#  'загрязнить': 668,
#  'революция': 669,
#  'выкачивать': 670,
#  'пто': 671,
#  'памятный': 672,
#  'тажа': 673,
#  'окрашивание': 674,
#  'тон': 675,
#  'санкция': 676,
#  'простой': 677,
#  'осущест': 678,
#  'наркотический': 679,
#  'некрасов': 680,
#  'падение': 681,
#  'опознавательный': 682,
#  'лесничный': 683,
#  'молодой': 684,
#  'воспользоваться': 685,
#  'приглушить': 686,
#  'капремонт': 687,
#  'ржаветь': 688,
#  'заменяться': 689,
#  'дойников': 690,
#  'балерина': 691,
#  'пролетарский': 692,
#  'прежний': 693,
#  'выправка': 694,
#  'алкогольный': 695,
#  'светложелтый': 696,
#  'прекращать': 697,
#  'подчинить': 698,
#  'читаемый': 699,
#  'время': 700,
#  'рольставень': 701,
#  'глухой': 702,
#  'устанить': 703,
#  'заделывать': 704,
#  'перила': 705,
#  'пахнуть': 706,
#  'мм': 707,
#  'вниз': 708,
#  'негорт': 709,
#  'обязать': 710,
#  'скрежет': 711,
#  'недопускать': 712,
#  'заплатка': 713,
#  'напоминать': 714,
#  'перебой': 715,
#  'глубокоуважаемый': 716,
#  'универсам': 717,
#  'кнопочный': 718,
#  'нарушеннго': 719,
#  'тонема': 720,
#  'написание': 721,
#  'колористический': 722,
#  'поддерживать': 723,
#  'жизнедеятельность': 724,
#  'обращать': 725,
#  'петергоф': 726,
#  'стоить': 727,
#  'дизайн': 728,
#  'придерживаться': 729,
#  'экстремистский': 730,
#  'жэк': 731,
#  'безобразный': 732,
#  'скуда': 733,
#  'люминесценция': 734,
#  'страшный': 735,
#  'минь': 736,
#  'почернеть': 737,
#  'оклейка': 738,
#  'бучить': 739,
#  'сентябрь': 740,
#  'грп': 741,
#  'возмездный': 742,
#  'новочеркасский': 743,
#  'правообладатель': 744,
#  'выброс': 745,
#  'смывание': 746,
#  'оснастить': 747,
#  'рельеф': 748,
#  'износиться': 749,
#  'щель': 750,
#  'помещение': 751,
#  'доу': 752,
#  'жалкий': 753,
#  'трэш': 754,
#  'мчаться': 755,
#  'негде': 756,
#  'смоленский': 757,
#  'окно': 758,
#  'неровно': 759,
#  'рубинштейн': 760,
#  'бюджетный': 761,
#  'поинтересоваться': 762,
#  'перемешать': 763,
#  'вселяться': 764,
#  'заморозок': 765,
#  'фрукт': 766,
#  'возраст': 767,
#  'вышесказанный': 768,
#  'отражаться': 769,
#  'отписаться': 770,
#  'последствие': 771,
#  'оказание': 772,
#  'разбить': 773,
#  'навести': 774,
#  'новосмоленский': 775,
#  'хазов': 776,
#  'незакреплённый': 777,
#  'полдень': 778,
#  'модуль': 779,
#  'рыбацкий': 780,
#  'переполнить': 781,
#  'трус': 782,
#  'пешеходный': 783,
#  'кварплат': 784,
#  'роллер': 785,
#  'вонять': 786,
#  'слуга': 787,
#  'эстетический': 788,
#  'дудин': 789,
#  'будни': 790,
#  'эксплутации': 791,
#  'здать': 792,
#  'солдат': 793,
#  'ым': 794,
#  'курьер': 795,
#  'завестись': 796,
#  'планк': 797,
#  'укомплектовать': 798,
#  'второй': 799,
#  'фактический': 800,
#  'промоина': 801,
#  'разлетаться': 802,
#  'наука': 803,
#  'восстанавливать': 804,
#  'окружающий': 805,
#  'катастрофа': 806,
#  'содержимое': 807,
#  'курение': 808,
#  'убедительный': 809,
#  'отслаивание': 810,
#  'закрытый': 811,
#  'городок': 812,
#  'дорожный': 813,
#  'главстроить': 814,
#  'инфекция': 815,
#  'сдуть': 816,
#  'хулиганский': 817,
#  'тк': 818,
#  'срочный': 819,
#  'благустройство': 820,
#  'мысленно': 821,
#  'замерзать': 822,
#  'выгодно': 823,
#  'расстояние': 824,
#  'очевидный': 825,
#  'требовать': 826,
#  'бак': 827,
#  'магнититься': 828,
#  'цифра': 829,
#  'шуметь': 830,
#  'убиться': 831,
#  'петроградский': 832,
#  'рассматриваться': 833,
#  'непригодный': 834,
#  'поляна': 835,
#  'село': 836,
#  'наконечник': 837,
#  'оружейник': 838,
#  'раздвинуться': 839,
#  'ликвидация': 840,
#  'ход': 841,
#  'оштрафовать': 842,
#  'примагнитить': 843,
#  'средний': 844,
#  'наметать': 845,
#  'простить': 846,
#  'дезинсекция': 847,
#  'наполовину': 848,
#  'проступать': 849,
#  'административка': 850,
#  'идеальный': 851,
#  'тополь': 852,
#  'баннер': 853,
#  'усть': 854,
#  'многий': 855,
#  'звуковой': 856,
#  'разбросать': 857,
#  'проч': 858,
#  'зайти': 859,
#  'достоверность': 860,
#  'доводиться': 861,
#  'складироваться': 862,
#  'заклинивать': 863,
#  'запорный': 864,
#  'выцвеить': 865,
#  'запустить': 866,
#  'немой': 867,
#  'прохождение': 868,
#  'обьект': 869,
#  'бачок': 870,
#  'растяжка': 871,
#  'потолочный': 872,
#  'закрывать': 873,
#  'безумно': 874,
#  'недочёт': 875,
#  'полис': 876,
#  'неприличный': 877,
#  'рувд': 878,
#  'эвакуация': 879,
#  'коломяжский': 880,
#  'уборщица': 881,
#  'обметаться': 882,
#  'казарма': 883,
#  'размыть': 884,
#  'писк': 885,
#  'посадка': 886,
#  'громкий': 887,
#  'посередине': 888,
#  'пройти': 889,
#  'растрескивание': 890,
#  'понять': 891,
#  'сказать': 892,
#  'отказываться': 893,
#  'переносный': 894,
#  'неудобство': 895,
#  'магнитный': 896,
#  's': 897,
#  'похожий': 898,
#  'польза': 899,
#  'зина': 900,
#  'отрегулировать': 901,
#  'предел': 902,
#  'бурцев': 903,
#  'перекрыть': 904,
#  'кафель': 905,
#  'расклеивать': 906,
#  'сообщение': 907,
#  'н': 908,
#  'дворовый': 909,
#  'комиссия': 910,
#  'таить': 911,
#  'филя': 912,
#  'сохранение': 913,
#  'муравейник': 914,
#  'садовый': 915,
#  'председатель': 916,
#  'свод': 917,
#  'выборочный': 918,
#  'хламовникнуть': 919,
#  'кошка': 920,
#  'уплотнение': 921,
#  'трещина': 922,
#  'просидеть': 923,
#  'роллета': 924,
#  'больной': 925,
#  'количество': 926,
#  'загребский': 927,
#  'дружба': 928,
#  'засунуть': 929,
#  'становиться': 930,
#  'провезти': 931,
#  'желательно': 932,
#  'цепочный': 933,
#  'отсесть': 934,
#  'продажа': 935,
#  'капитан': 936,
#  'авиатор': 937,
#  'столбик': 938,
#  'мыть': 939,
#  'ходовой': 940,
#  'девятый': 941,
#  'щитовой': 942,
#  'маслянистый': 943,
#  'вытаскивать': 944,
#  'скоро': 945,
#  'водосток': 946,
#  'росреестр': 947,
#  'метать': 948,
#  'проезжейчасть': 949,
#  'бц': 950,
#  'отогнуть': 951,
#  'мятый': 952,
#  'депо': 953,
#  'металлопластиковый': 954,
#  'сочиться': 955,
#  'телега': 956,
#  'пушистый': 957,
#  'велдберс': 958,
#  'подметать': 959,
#  'xxxxxxxxxxxxxxxxx': 960,
#  'мочалка': 961,
#  'грохот': 962,
#  'доска': 963,
#  'снаряд': 964,
#  'двигать': 965,
#  'лечиться': 966,
#  'гидрант': 967,
#  'всеволод': 968,
#  'птк': 969,
#  'закопать': 970,
#  'россеть': 971,
#  'чреватый': 972,
#  'осуществить': 973,
#  'вазон': 974,
#  'митрополикать': 975,
#  'наверно': 976,
#  'дольшея': 977,
#  'растянутый': 978,
#  'бесполезно': 979,
#  'думать': 980,
#  'чистить': 981,
#  'наладочный': 982,
#  'тротуарный': 983,
#  'хомут': 984,
#  'протирать': 985,
#  'подумать': 986,
#  'сквозной': 987,
#  'отваливаться': 988,
#  'сконструировать': 989,
#  'перекособочить': 990,
#  'кун': 991,
#  'зависать': 992,
#  'отодрать': 993,
#  'обслуживаться': 994,
#  'морозов': 995,
#  'дезинфицироваться': 996,
#  'видимо': 997,
#  'намазать': 998,
#  'отчёт': 999,
#  ...}

# %%
w2v = Word2Vec(sentences=X, min_count=1, vector_size=32, epochs=50)

# %%
word_vectors = {word: w2v.wv[word] for word in vocab}

# %%
word_vectors
# Out:
# {'взудитие': array([-0.12857096, -0.1821478 , -0.08437478,  0.15940414,  0.1322826 ,
#         -0.05456191,  0.20577869,  0.05710222, -0.27503088, -0.06156126,
#          0.08349769, -0.17244886,  0.08279859, -0.03958371,  0.00427412,
#          0.01308259,  0.0626841 , -0.02038973,  0.00573065,  0.26035845,
#          0.19766244,  0.30924967,  0.13790756, -0.0784334 ,  0.06865068,
#          0.0192849 , -0.27631053, -0.00213539, -0.0187077 , -0.21167736,
#          0.19562729, -1.1454778 , -0.38499683, -0.37997487, -0.6714918 ,
#          0.93040603, -0.85983044], dtype=float32),
#  'намазать': array([ 0.15472241, -0.27527606,  0.35089102,  0.12641335,  0.08488045,
#         -0.12282852, -0.12509933,  0.04616302, -0.28344715,  0.03658094,
#          0.3276746 ,  0.45723188,  0.0888233 , -0.09322184, -0.28491506,
#         -0.05552204, -0.0120308 , -0.04542752,  0.02938461,  0.08070335,
#          0.18739821,  0.3871541 ,  0.02710294, -0.36867532,  0.17582208,
#         -0.09193192, -0.07434411, -0.41866708,  0.03161548, -0.3587464 ,
#          0.04892769, -0.4151961 ], dtype=float32),
#  'отчёт': array([-0.5200822 ,  1.5745034 , -1.2402029 , -1.1528722 , -0.5077472 ,
#          1.1947471 , -0.40671584,  0.22149599,  0.21904251,  1.273883  ,
#         -0.2973618 , -0.12523113,  1.2237791 , -1.9449978 ,  0.36769864,
#         -0.37490174, -1.1192617 , -0.13573126, -1.9882652 ,  0.71628755,
#          2.3231351 ,  0.71584666,  0.27548656,  1.6080554 ,  1.6740174 ,
#          0.95285463, -1.3669968 , -1.1748295 ,  0.47017458, -0.10573003,
#          0.01874678, -0.490616  ], dtype=float32),
#  ...}

# %% [markdown]
# ### 4. Закодируйте значения целевого признака (категория обращения). Разделите данные на обучающую и тестирующую выборку.

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(y_str)
y
# Out:
# array([0, 0, 0, ..., 0, 8, 0])

# %%
corpus_vec = [[word_vectors[word] for word in doc] for doc in X]

# %%
len(corpus_vec)
# Out:
# 10000

# %%
corpus_vec_one_dim = torch.nn.utils.rnn.pad_sequence([torch.tensor(x) for x in corpus_vec], batch_first=True)

# %%
len(corpus_vec_one_dim)
# Out:
# 10000

# %%
X_train, X_test, y_train, y_test = train_test_split(corpus_vec_one_dim, np.array(y), test_size=0.1, stratify=y, shuffle=True)

# %%
train_ds = TensorDataset(torch.tensor(X_train, dtype=torch.float32).cuda(), torch.from_numpy(y_train).type(torch.long).cuda())
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)
# Out:
# <ipython-input-180-ac4091729f68>:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_ds = TensorDataset(torch.tensor(X_train, dtype=torch.float32).cuda(), torch.from_numpy(y_train).type(torch.long).cuda())

# %%
test_ds = TensorDataset(torch.tensor(X_test, dtype=torch.float32).cuda(), torch.tensor(y_test).reshape(-1,1).type(torch.long).cuda())
test_dl = DataLoader(test_ds, batch_size=256, shuffle=True)
# Out:
# <ipython-input-181-12742d7bbe37>:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_ds = TensorDataset(torch.tensor(X_test, dtype=torch.float32).cuda(), torch.tensor(y_test).reshape(-1,1).type(torch.long).cuda())

# %% [markdown]
# ### 5. С помощью PyTorch соберите и обучите три нейронных сети для решения задачи классификации (предсказания категории обращения); количество слоев и значения других параметров конфигурируете по вашему усмотрению:

# %% [markdown]
# #### RNN

# %%
X_train.shape
# Out:
# torch.Size([9000, 191, 32])

# %%
y_train
# Out:
# array([ 0,  0,  0, ...,  0, 11, 11])

# %%
INPUT_SIZE = X_train.shape[2]
HIDDEN_SIZE = 128

# %%
class RNNModel(nn.Module):
    def __init__(self, input_size: int, hidden_size: int) -> None:
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size=input_size, hidden_size=hidden_size, batch_first=True)
        self.linear = nn.Linear(hidden_size, 15)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        out, h = self.rnn(x)
        y = self.linear(h.squeeze(0))
        return y

rnn = RNNModel(INPUT_SIZE, HIDDEN_SIZE).cuda()

# %%
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(rnn.parameters(), lr=0.0025)

# %%
all(param.is_cuda for param in rnn.parameters())
# Out:
# True

# %%
epochs = 50
for epoch in range(epochs):
    for x, y in train_dl:
        outputs = rnn(x)
        loss_value = loss(outputs, y)
        optimizer.zero_grad()
        loss_value.backward()
        optimizer.step()

    print(f"Эпоха {epoch + 1}, Значение функции потерь: {loss_value.item()}")
# Out:
# Эпоха 1, Значение функции потерь: 1.4311494827270508
# Эпоха 2, Значение функции потерь: 1.383643388748169
# Эпоха 3, Значение функции потерь: 1.267279863357544
# Эпоха 4, Значение функции потерь: 1.2832894325256348
# Эпоха 5, Значение функции потерь: 1.2918986082077026
# Эпоха 6, Значение функции потерь: 1.6374574899673462
# Эпоха 7, Значение функции потерь: 1.4478998184204102
# Эпоха 8, Значение функции потерь: 1.5597985982894897
# Эпоха 9, Значение функции потерь: 1.320909857749939
# Эпоха 10, Значение функции потерь: 1.2415077686309814
# Эпоха 11, Значение функции потерь: 1.457364797592163
# Эпоха 12, Значение функции потерь: 1.5204041004180908
# Эпоха 13, Значение функции потерь: 1.3025500774383545
# Эпоха 14, Значение функции потерь: 1.0718073844909668
# Эпоха 15, Значение функции потерь: 0.9505273103713989
# Эпоха 16, Значение функции потерь: 1.4744417667388916
# Эпоха 17, Значение функции потерь: 0.7291814088821411
# Эпоха 18, Значение функции потерь: 1.047696828842163
# Эпоха 19, Значение функции потерь: 1.1231391429901123
# Эпоха 20, Значение функции потерь: 1.2554857730865479
# Эпоха 21, Значение функции потерь: 1.1785272359848022
# Эпоха 22, Значение функции потерь: 1.3404042720794678
# Эпоха 23, Значение функции потерь: 1.266969084739685
# Эпоха 24, Значение функции потерь: 1.2795956134796143
# Эпоха 25, Значение функции потерь: 1.4552009105682373
# Эпоха 26, Значение функции потерь: 1.626007318496704
# Эпоха 27, Значение функции потерь: 1.233079195022583
# Эпоха 28, Значение функции потерь: 0.8824487924575806
# Эпоха 29, Значение функции потерь: 1.1521400213241577
# Эпоха 30, Значение функции потерь: 1.448237657546997
# Эпоха 31, Значение функции потерь: 1.0695091485977173
# Эпоха 32, Значение функции потерь: 1.4596197605133057
# Эпоха 33, Значение функции потерь: 1.1473413705825806
# Эпоха 34, Значение функции потерь: 1.6495615243911743
# Эпоха 35, Значение функции потерь: 1.5143094062805176
# Эпоха 36, Значение функции потерь: 1.4724934101104736
# Эпоха 37, Значение функции потерь: 1.2713979482650757
# Эпоха 38, Значение функции потерь: 1.4967212677001953
# Эпоха 39, Значение функции потерь: 1.376578450202942
# Эпоха 40, Значение функции потерь: 1.3293544054031372
# Эпоха 41, Значение функции потерь: 1.5337011814117432
# Эпоха 42, Значение функции потерь: 1.4828763008117676
# Эпоха 43, Значение функции потерь: 1.7353451251983643
# Эпоха 44, Значение функции потерь: 1.3431289196014404
# Эпоха 45, Значение функции потерь: 1.3820865154266357
# Эпоха 46, Значение функции потерь: 1.1761332750320435
# Эпоха 47, Значение функции потерь: 0.9922423362731934
# Эпоха 48, Значение функции потерь: 1.403898000717163
# Эпоха 49, Значение функции потерь: 1.466026782989502
# Эпоха 50, Значение функции потерь: 1.1789593696594238

# %%
sm = nn.Softmax(1).cuda()

# %%
y_pred = torch.argmax(sm(rnn(X_test.cuda())).cpu(), dim=1)

print(classification_report(
    y_test,
    y_pred.cpu().detach().numpy(),
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       584
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00        13
#            3       0.00      0.00      0.00        13
#            4       0.00      0.00      0.00         4
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        31
#            7       0.00      0.00      0.00         4
#            8       0.00      0.00      0.00        20
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00       236
#           12       0.00      0.00      0.00        11
#           13       0.00      0.00      0.00        26
#           14       0.00      0.00      0.00         5
#
#     accuracy                           0.58      1000
#    macro avg       0.04      0.07      0.05      1000
# weighted avg       0.34      0.58      0.43      1000
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1736: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# #### LSTM

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size: int, hidden_size: int) -> None:
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, batch_first=True)
        self.linear = nn.Linear(hidden_size, 15)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        out, (h, c) = self.lstm(x)
        y = self.linear(h.squeeze(0))
        return y

lstm = LSTMModel(INPUT_SIZE, HIDDEN_SIZE).cuda()

# %%
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lstm.parameters(), lr=0.0025)

# %%
epochs = 50
for epoch in range(epochs):
    for x, y in train_dl:
        outputs = lstm(x)
        loss_value = loss(outputs, y)
        optimizer.zero_grad()
        loss_value.backward()
        optimizer.step()

    print(f"Эпоха {epoch + 1}, Значение функции потерь: {loss_value.item()}")
# Out:
# Эпоха 1, Значение функции потерь: 1.0545998811721802
# Эпоха 2, Значение функции потерь: 1.4772090911865234
# Эпоха 3, Значение функции потерь: 1.146073341369629
# Эпоха 4, Значение функции потерь: 1.432945728302002
# Эпоха 5, Значение функции потерь: 1.4908427000045776
# Эпоха 6, Значение функции потерь: 1.0412677526474
# Эпоха 7, Значение функции потерь: 1.1031217575073242
# Эпоха 8, Значение функции потерь: 1.521390676498413
# Эпоха 9, Значение функции потерь: 1.4805948734283447
# Эпоха 10, Значение функции потерь: 1.220950722694397
# Эпоха 11, Значение функции потерь: 1.25678288936615
# Эпоха 12, Значение функции потерь: 1.269113302230835
# Эпоха 13, Значение функции потерь: 1.6073312759399414
# Эпоха 14, Значение функции потерь: 1.3458689451217651
# Эпоха 15, Значение функции потерь: 1.6384025812149048
# Эпоха 16, Значение функции потерь: 1.4180195331573486
# Эпоха 17, Значение функции потерь: 1.243863821029663
# Эпоха 18, Значение функции потерь: 1.823279619216919
# Эпоха 19, Значение функции потерь: 1.5898053646087646
# Эпоха 20, Значение функции потерь: 1.2678265571594238
# Эпоха 21, Значение функции потерь: 1.6950289011001587
# Эпоха 22, Значение функции потерь: 1.6663669347763062
# Эпоха 23, Значение функции потерь: 1.5012000799179077
# Эпоха 24, Значение функции потерь: 1.3887851238250732
# Эпоха 25, Значение функции потерь: 1.5195642709732056
# Эпоха 26, Значение функции потерь: 1.301543116569519
# Эпоха 27, Значение функции потерь: 1.0200531482696533
# Эпоха 28, Значение функции потерь: 1.2177534103393555
# Эпоха 29, Значение функции потерь: 1.324578046798706
# Эпоха 30, Значение функции потерь: 1.1252129077911377
# Эпоха 31, Значение функции потерь: 1.321224570274353
# Эпоха 32, Значение функции потерь: 1.427988052368164
# Эпоха 33, Значение функции потерь: 1.1682504415512085
# Эпоха 34, Значение функции потерь: 1.3471646308898926
# Эпоха 35, Значение функции потерь: 1.5319312810897827
# Эпоха 36, Значение функции потерь: 1.5278517007827759
# Эпоха 37, Значение функции потерь: 1.4169448614120483
# Эпоха 38, Значение функции потерь: 1.3066565990447998
# Эпоха 39, Значение функции потерь: 1.038759469985962
# Эпоха 40, Значение функции потерь: 1.5222814083099365
# Эпоха 41, Значение функции потерь: 1.437447190284729
# Эпоха 42, Значение функции потерь: 1.2456324100494385
# Эпоха 43, Значение функции потерь: 1.218754529953003
# Эпоха 44, Значение функции потерь: 0.9481639862060547
# Эпоха 45, Значение функции потерь: 1.6641654968261719
# Эпоха 46, Значение функции потерь: 1.5687429904937744
# Эпоха 47, Значение функции потерь: 1.397469162940979
# Эпоха 48, Значение функции потерь: 1.3956966400146484
# Эпоха 49, Значение функции потерь: 1.6364740133285522
# Эпоха 50, Значение функции потерь: 1.4868443012237549

# %%
sm = nn.Softmax(1).cuda()

# %%
y_pred = torch.argmax(sm(lstm(X_test.cuda())).cpu(), dim=1)

print(classification_report(
    y_test,
    y_pred.cpu().detach().numpy(),
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       584
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00        13
#            3       0.00      0.00      0.00        13
#            4       0.00      0.00      0.00         4
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        31
#            7       0.00      0.00      0.00         4
#            8       0.00      0.00      0.00        20
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00       236
#           12       0.00      0.00      0.00        11
#           13       0.00      0.00      0.00        26
#           14       0.00      0.00      0.00         5
#
#     accuracy                           0.58      1000
#    macro avg       0.04      0.07      0.05      1000
# weighted avg       0.34      0.58      0.43      1000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# #### GRU

# %%
class GRUModel(nn.Module):
    def __init__(self, input_size: int, hidden_size: int) -> None:
        super(GRUModel, self).__init__()
        self.gru = nn.GRU(input_size=input_size, hidden_size=hidden_size, batch_first=True)
        self.linear = nn.Linear(hidden_size, 15)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        out, h = self.gru(x)
        y = self.linear(h.squeeze(0))
        return y

gru = GRUModel(INPUT_SIZE, HIDDEN_SIZE).cuda()

# %%
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(gru.parameters(), lr=0.0025)

# %%
epochs = 50
for epoch in range(epochs):
    for x, y in train_dl:
        outputs = gru(x)
        loss_value = loss(outputs, y)
        optimizer.zero_grad()
        loss_value.backward()
        optimizer.step()

    print(f"Эпоха {epoch + 1}, Значение функции потерь: {loss_value.item()}")
# Out:
# Эпоха 1, Значение функции потерь: 1.490487813949585
# Эпоха 2, Значение функции потерь: 1.6580743789672852
# Эпоха 3, Значение функции потерь: 1.1968626976013184
# Эпоха 4, Значение функции потерь: 1.2106678485870361
# Эпоха 5, Значение функции потерь: 0.6336907148361206
# Эпоха 6, Значение функции потерь: 0.24605122208595276
# Эпоха 7, Значение функции потерь: 0.3169252574443817
# Эпоха 8, Значение функции потерь: 0.18240150809288025
# Эпоха 9, Значение функции потерь: 0.2973821759223938
# Эпоха 10, Значение функции потерь: 0.2070135623216629
# Эпоха 11, Значение функции потерь: 0.25355297327041626
# Эпоха 12, Значение функции потерь: 0.4475637376308441
# Эпоха 13, Значение функции потерь: 0.12715286016464233
# Эпоха 14, Значение функции потерь: 0.19285225868225098
# Эпоха 15, Значение функции потерь: 0.0647289901971817
# Эпоха 16, Значение функции потерь: 0.16539506614208221
# Эпоха 17, Значение функции потерь: 0.4474617838859558
# Эпоха 18, Значение функции потерь: 0.04484887793660164
# Эпоха 19, Значение функции потерь: 0.016239803284406662
# Эпоха 20, Значение функции потерь: 0.3182196021080017
# Эпоха 21, Значение функции потерь: 0.07128952443599701
# Эпоха 22, Значение функции потерь: 0.01237574964761734
# Эпоха 23, Значение функции потерь: 0.09315920621156693
# Эпоха 24, Значение функции потерь: 0.028775949031114578
# Эпоха 25, Значение функции потерь: 0.0893562063574791
# Эпоха 26, Значение функции потерь: 0.0779181569814682
# Эпоха 27, Значение функции потерь: 0.08128868043422699
# Эпоха 28, Значение функции потерь: 0.055525265634059906
# Эпоха 29, Значение функции потерь: 0.017499128356575966
# Эпоха 30, Значение функции потерь: 0.0356573648750782
# Эпоха 31, Значение функции потерь: 0.033391185104846954
# Эпоха 32, Значение функции потерь: 0.009578848257660866
# Эпоха 33, Значение функции потерь: 0.044275786727666855
# Эпоха 34, Значение функции потерь: 0.01037134975194931
# Эпоха 35, Значение функции потерь: 0.009109855629503727
# Эпоха 36, Значение функции потерь: 0.0880829244852066
# Эпоха 37, Значение функции потерь: 0.007588595151901245
# Эпоха 38, Значение функции потерь: 0.020614447072148323
# Эпоха 39, Значение функции потерь: 0.14554062485694885
# Эпоха 40, Значение функции потерь: 0.0166181530803442
# Эпоха 41, Значение функции потерь: 0.07853023707866669
# Эпоха 42, Значение функции потерь: 0.19443504512310028
# Эпоха 43, Значение функции потерь: 0.004463729448616505
# Эпоха 44, Значение функции потерь: 0.1503300964832306
# Эпоха 45, Значение функции потерь: 0.015731992200016975
# Эпоха 46, Значение функции потерь: 0.11424420773983002
# Эпоха 47, Значение функции потерь: 0.19778327643871307
# Эпоха 48, Значение функции потерь: 0.021662099286913872
# Эпоха 49, Значение функции потерь: 0.09194309264421463
# Эпоха 50, Значение функции потерь: 0.009135880507528782

# %%
sm = nn.Softmax(1).cuda()

# %%
y_pred = torch.argmax(sm(gru(X_test.cuda())).cpu(), dim=1)

print(classification_report(
    y_test,
    y_pred.cpu().detach().numpy(),
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       584
#            1       0.57      0.80      0.67         5
#            2       0.90      0.69      0.78        13
#            3       0.71      0.77      0.74        13
#            4       0.00      0.00      0.00         4
#            5       0.88      0.95      0.91        37
#            6       0.86      0.77      0.81        31
#            7       1.00      0.50      0.67         4
#            8       0.83      0.75      0.79        20
#            9       1.00      0.25      0.40         4
#           10       0.75      0.86      0.80         7
#           11       0.88      0.90      0.89       236
#           12       0.71      0.45      0.56        11
#           13       0.77      0.65      0.71        26
#           14       0.80      0.80      0.80         5
#
#     accuracy                           0.90      1000
#    macro avg       0.77      0.67      0.70      1000
# weighted avg       0.90      0.90      0.90      1000
