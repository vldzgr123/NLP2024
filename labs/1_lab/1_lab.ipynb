# %% [markdown]
# # Лабораторная работа 1. Извлечение признаков из текстовых данных
#
#
# ## Задание
# - Реализовать алгоритм получения контекстных эмбеддингов (векторных представлений) слов.
#
# - Реализовать один из алгоритмов CBoW или SkipGram для получения собственных моделей Word2Vec для выбранных данных.
#
# - Визуализировать векторные представления в малой размерности.
#
#
#
# ## Ход работы
# 1. Загрузить коллекцию текстовых документов: просьбы жильцов. Можете использовать не весь датасет (подмножество строк таблицы). В этой ЛР вас интересует столбец с текстом обращений жильцов. Можете загрузить любой датасет для классификации текстовых данных.
#
# 2. Рассмотреть каждый текстовый документ отдельно. Выполнить предварительную обработку текстовых данных (как в ЛР 8 по ML). Токенизация, лемматизация (стемминг), удаление стоп-слов.
#
# 3. Составить матрицу контекстных эмбеддингов слов.
#
# 4. С помощью PCA уменьшить размер контекстных эмбеддингов (размер задать самостоятельно).
#
# 5. С помощью PyTorch реализовать один из алгоритмов Word2Vec: CBoW или SkipGram. Получить векторные представления текстов с помощью собственной реализации одного из этих алгоритмов.
#
# 6. Сохранить полученные различными способами векторные представления в файлы tsv. Визуализировать их с помощью сервиса Projector от авторов TensorFlow.

# %%
import pandas as pd
import torch
from torch import nn
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
from pymorphy3 import MorphAnalyzer
import string
from gensim.models import Word2Vec
import numpy as np
from sklearn.decomposition import PCA
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ### 1. Загрузить коллекцию текстовых документов: просьбы жильцов. Можете использовать не весь датасет (подмножество строк таблицы). В этой ЛР вас интересует столбец с текстом обращений жильцов. Можете загрузить любой датасет для классификации текстовых данных.

# %%
data = pd.read_csv("../../data/Petitions.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59889 entries, 0 to 59888
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    59889 non-null  int64
#  1   public_petition_text  59889 non-null  object
#  2   reason_category       59889 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %%
data.head(1000)
# Out:
#           id                               public_petition_text  \
# 0    3168490                                     снег на дороге
# 1    3219678                очистить кабельный киоск от рекламы
# 2    2963920  Просим убрать все деревья и кустарники, которы...
# 3    3374910  Неудовлетворительное состояние парадной - надп...
# 4    3336285                                           Граффити
# ..       ...                                                ...
# 995  3279475      Повреждения дорожного покрытия проезжей части
# 996  3356222  дворник убрал песок у подъезда и высыпал его н...
# 997  3276541                        Нужно заделать ямы во дворе
# 998  3032938                              демонтировать решетку
# 999  3034986                                     граффити на ТП
#
#                                    reason_category
# 0                                  Благоустройство
# 1                                  Благоустройство
# 2                                  Благоустройство
# 3                                   Содержание МКД
# 4                                  Благоустройство
# ..                                             ...
# 995                                Благоустройство
# 996                                Благоустройство
# 997                                Благоустройство
# 998  Нарушение правил пользования общим имуществом
# 999                                Благоустройство
#
# [1000 rows x 3 columns]

# %%
data = data.head(10000)

# %%
data.drop(["id", "reason_category"], axis=1, inplace=True)

# %% [markdown]
# ### 2. Рассмотреть каждый текстовый документ отдельно. Выполнить предварительную обработку текстовых данных (как в ЛР 8 по ML). Токенизация, лемматизация (стемминг), удаление стоп-слов.

# %% [markdown]
# Удаление всех символов, которые не являются цифрами, буквами и пробелами, и токенизация

# %%
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('punkt_tab')

# %%
morph = MorphAnalyzer()
stopwords = stopwords.words("russian")


def preProccesingData(text):
    only_letters = re.sub("[^\s^\w]+", " ", text)
    tokenized = word_tokenize(only_letters)
    normalized = [morph.normal_forms(word)[0] for word in tokenized]
    no_stop_words = [
        word
        for word in normalized
        if ((word not in string.punctuation) and (word not in stopwords) and word.isalpha())
    ]
    return no_stop_words

# %%
data = data['public_petition_text'].apply(preProccesingData).tolist()
data[:10]
# Out:
# [['снег', 'дорога'],
#  ['очистить', 'кабельный', 'киоск', 'реклама'],
#  ['просить',
#   'убрать',
#   'всё',
#   'дерево',
#   'кустарник',
#   'который',
#   'выйти',
#   'предел',
#   'газон',
#   'пешеходный',
#   'зона',
#   'начинать',
#   'подъезд',
#   'подъезд',
#   'фасад',
#   'дом',
#   'сторона',
#   'ул',
#   'наличный'],
#  ['неудовлетворительный', 'состояние', 'парадный', 'надпись', 'дверь', 'этаж'],
#  ['граффити'],
#  ['необходимо',
#   'проверить',
#   'законность',
#   'установка',
#   'вывеска',
#   'фасад',
#   'мкд',
#   'адрес',
#   'проспект',
#   'непокорённый',
#   'случай',
#   'вывеска',
#   'установить',
#   'незаконно',
#   'её',
#   'необходимо',
#   'демонтировать'],
#  ['уборка',
#   'производиться',
#   'лестница',
#   'очень',
#   'грязно',
#   'весь',
#   'этаж',
#   'вплоть',
#   'го',
#   'звонок',
#   'жкс',
#   'дать',
#   'результат'],
#  ['мусор'],
#  ['отсутствовать', 'освещение', 'лестничный', 'площадка', 'этаж', 'парадный'],
#  ['делать', 'благоустройство', 'никто', 'убирать', 'мусор', 'ежедневно']]

# %% [markdown]
# ### 3. Составить матрицу контекстных эмбеддингов слов.

# %%
all_words = [word for document in data for word in document]

# %%
all_words[:10]
# Out:
# ['снег',
#  'дорога',
#  'очистить',
#  'кабельный',
#  'киоск',
#  'реклама',
#  'просить',
#  'убрать',
#  'всё',
#  'дерево']

# %%
vocab = set(all_words)
vocab_len = len(vocab)
vocab_len
# Out:
# 7771

# %%
id_word = dict(enumerate(vocab))
id_word
# Out:
# {0: 'отломать',
#  1: 'строиться',
#  2: 'издевательство',
#  3: 'пара',
#  4: 'промежуточный',
#  5: 'вместе',
#  6: 'вывозить',
#  7: 'шурф',
#  8: 'предприниматься',
#  9: 'огорождение',
#  10: 'добрго',
#  11: 'малоохтинский',
#  12: 'песочница',
#  13: 'лужие',
#  14: 'материальный',
#  15: 'быстро',
#  16: 'время',
#  17: 'колёрный',
#  18: 'нарушеннго',
#  19: 'взудитие',
#  20: 'реальность',
#  21: 'прозрачный',
#  22: 'стена',
#  23: 'наверху',
#  24: 'комар',
#  25: 'выступать',
#  26: 'результативный',
#  27: 'сфетофора',
#  28: 'коляска',
#  29: 'готовый',
#  30: 'лом',
#  31: 'посредством',
#  32: 'выбоина',
#  33: 'элемент',
#  34: 'оно',
#  35: 'планировочный',
#  36: 'недостоверный',
#  37: 'пётр',
#  38: 'наклеить',
#  39: 'недомыть',
#  40: 'гнилостный',
#  41: 'согласовать',
#  42: 'сердобольский',
#  43: 'первомайский',
#  44: 'деревенский',
#  45: 'срок',
#  46: 'свыше',
#  47: 'импровизированный',
#  48: 'дезинфицировать',
#  49: 'справа',
#  50: 'разобрать',
#  51: 'физически',
#  52: 'примыкать',
#  53: 'подводный',
#  54: 'эвакуационный',
#  55: 'повсеместно',
#  56: 'освещёние',
#  57: 'блестеть',
#  58: 'контур',
#  59: 'бить',
#  60: 'миграция',
#  61: 'зимой',
#  62: 'воскресение',
#  63: 'вербный',
#  64: 'русановский',
#  65: 'мнение',
#  66: 'вопрос',
#  67: 'сук',
#  68: 'восстановителтный',
#  69: 'перечисленный',
#  70: 'освежить',
#  71: 'уворачиваться',
#  72: 'фёдоров',
#  73: 'поехать',
#  74: 'зазывала',
#  75: 'пополнять',
#  76: 'основание',
#  77: 'брус',
#  78: 'однокомнатный',
#  79: 'сохранность',
#  80: 'грвфитти',
#  81: 'щит',
#  82: 'перчатка',
#  83: 'серебряный',
#  84: 'натянуть',
#  85: 'ригель',
#  86: 'выкопировка',
#  87: 'расположение',
#  88: 'классификационный',
#  89: 'налоговый',
#  90: 'легковоспламенимый',
#  91: 'складывать',
#  92: 'красноармейский',
#  93: 'безнадёжно',
#  94: 'запланировать',
#  95: 'мошуваловый',
#  96: 'верейский',
#  97: 'таллинский',
#  98: 'верёвочный',
#  99: 'темнота',
#  100: 'семечко',
#  101: 'максимально',
#  102: 'очищаться',
#  103: 'тройка',
#  104: 'корп',
#  105: 'ти',
#  106: 'вблизи',
#  107: 'участник',
#  108: 'скакать',
#  109: 'тд',
#  110: 'кладовка',
#  111: 'хранение',
#  112: 'возможность',
#  113: 'мужчина',
#  114: 'урна',
#  115: 'обнаглеть',
#  116: 'нецелесообразный',
#  117: 'кондиционирование',
#  118: 'наземный',
#  119: 'фрунзенский',
#  120: 'трава',
#  121: 'вый',
#  122: 'волейбол',
#  123: 'целостность',
#  124: 'съезжать',
#  125: 'кустодиевый',
#  126: 'специальный',
#  127: 'грузовой',
#  128: 'подсохнуть',
#  129: 'прибор',
#  130: 'кривой',
#  131: 'беспорядочный',
#  132: 'взыскание',
#  133: 'расклеивание',
#  134: 'освещать',
#  135: 'обводный',
#  136: 'половина',
#  137: 'благо',
#  138: 'джд',
#  139: 'турник',
#  140: 'можайский',
#  141: 'вонять',
#  142: 'захлапываться',
#  143: 'отозвать',
#  144: 'давать',
#  145: 'тий',
#  146: 'мытый',
#  147: 'окрашиваться',
#  148: 'путешественник',
#  149: 'принудить',
#  150: 'актуальный',
#  151: 'ькача',
#  152: 'сомнительно',
#  153: 'план',
#  154: 'отсекать',
#  155: 'отштукатурить',
#  156: 'спонсировать',
#  157: 'водоотведение',
#  158: 'красногородский',
#  159: 'шестнадцатый',
#  160: 'ломбард',
#  161: 'прусак',
#  162: 'коврик',
#  163: 'газон',
#  164: 'предпринимать',
#  165: 'цокольный',
#  166: 'пищевой',
#  167: 'откидной',
#  168: 'парковаться',
#  169: 'докладывать',
#  170: 'маркиз',
#  171: 'оштукатурить',
#  172: 'видный',
#  173: 'крупский',
#  174: 'жб',
#  175: 'аппарта',
#  176: 'складирование',
#  177: 'продолжать',
#  178: 'разрыть',
#  179: 'заново',
#  180: 'президент',
#  181: 'ввполнить',
#  182: 'включить',
#  183: 'перекрёсток',
#  184: 'сделка',
#  185: 'перила',
#  186: 'главное',
#  187: 'марат',
#  188: 'пригласить',
#  189: 'разновидность',
#  190: 'боязнь',
#  191: 'малыгин',
#  192: 'колеровка',
#  193: 'устранять',
#  194: 'фантик',
#  195: 'соль',
#  196: 'грязь',
#  197: 'обнаружение',
#  198: 'невероятный',
#  199: 'изыскание',
#  200: 'вызванивать',
#  201: 'вчерашний',
#  202: 'поворачивать',
#  203: 'шесть',
#  204: 'маркин',
#  205: 'скуда',
#  206: 'просадка',
#  207: 'буквально',
#  208: 'лество',
#  209: 'роспись',
#  210: 'огонь',
#  211: 'обрастать',
#  212: 'кустарный',
#  213: 'электрощит',
#  214: 'оживлённый',
#  215: 'белградский',
#  216: 'грабли',
#  217: 'чинить',
#  218: 'озеленитель',
#  219: 'следствие',
#  220: 'сдаваться',
#  221: 'карьера',
#  222: 'прекратить',
#  223: 'погода',
#  224: 'дора',
#  225: 'казаков',
#  226: 'забиваться',
#  227: 'скопление',
#  228: 'дёргаться',
#  229: 'тридцать',
#  230: 'заставский',
#  231: 'высоко',
#  232: 'товарищество',
#  233: 'рассеянный',
#  234: 'проф',
#  235: 'коап',
#  236: 'сожаление',
#  237: 'богатырский',
#  238: 'суд',
#  239: 'электроподстанция',
#  240: 'потенциальный',
#  241: 'вывалиться',
#  242: 'негорючий',
#  243: 'отчитаться',
#  244: 'эты',
#  245: 'петербургский',
#  246: 'углублённый',
#  247: 'ознакомить',
#  248: 'проволока',
#  249: 'отделочный',
#  250: 'обещать',
#  251: 'буква',
#  252: 'дача',
#  253: 'сливной',
#  254: 'вязаный',
#  255: 'воспользоваться',
#  256: 'цеплять',
#  257: 'ламповый',
#  258: 'наклеивание',
#  259: 'разрушение',
#  260: 'провалиться',
#  261: 'трубка',
#  262: 'автоматически',
#  263: 'отваливать',
#  264: 'безобразный',
#  265: 'электрощитовой',
#  266: 'отклониться',
#  267: 'работодатель',
#  268: 'рекламный',
#  269: 'толкование',
#  270: 'кошка',
#  271: 'радищев',
#  272: 'юго',
#  273: 'свищь',
#  274: 'денисовский',
#  275: 'виленский',
#  276: 'коммерческий',
#  277: 'барельеф',
#  278: 'оформить',
#  279: 'марь',
#  280: 'повторять',
#  281: 'утрата',
#  282: 'зуб',
#  283: 'выясниться',
#  284: 'соколов',
#  285: 'контролировать',
#  286: 'гарькавый',
#  287: 'ласточкин',
#  288: 'пандус',
#  289: 'пища',
#  290: 'наружний',
#  291: 'левый',
#  292: 'неоднократный',
#  293: 'патрубок',
#  294: 'кабельный',
#  295: 'беспредел',
#  296: 'заливать',
#  297: 'учесть',
#  298: 'тихий',
#  299: 'доу',
#  300: 'оптико',
#  301: 'оригинальный',
#  302: 'бц',
#  303: 'переставать',
#  304: 'ехать',
#  305: 'вертикаль',
#  306: 'неполадка',
#  307: 'байконурский',
#  308: 'заславский',
#  309: 'ограничиваться',
#  310: 'загрузить',
#  311: 'футбольный',
#  312: 'двигатель',
#  313: 'месяц',
#  314: 'ободрать',
#  315: 'косяк',
#  316: 'развоздушивать',
#  317: 'подтекать',
#  318: 'белый',
#  319: 'полгода',
#  320: 'сообщение',
#  321: 'бомжатник',
#  322: 'оттенок',
#  323: 'подтечь',
#  324: 'пионерстрой',
#  325: 'лететь',
#  326: 'жилой',
#  327: 'сдвинуть',
#  328: 'убиваться',
#  329: 'регламент',
#  330: 'отчёт',
#  331: 'плюсовой',
#  332: 'относиться',
#  333: 'бухаретский',
#  334: 'сваливание',
#  335: 'хозяйство',
#  336: 'железо',
#  337: 'этажность',
#  338: 'отслоение',
#  339: 'комплекс',
#  340: 'коллега',
#  341: 'ненадлежащий',
#  342: 'муж',
#  343: 'истлевать',
#  344: 'продемонстрировать',
#  345: 'пачка',
#  346: 'высыпаться',
#  347: 'лёгкий',
#  348: 'глаз',
#  349: 'диск',
#  350: 'сторонний',
#  351: 'гск',
#  352: 'фигурировать',
#  353: 'теплосеть',
#  354: 'курьер',
#  355: 'закончиться',
#  356: 'сухой',
#  357: 'путин',
#  358: 'авангардный',
#  359: 'припарковаться',
#  360: 'временный',
#  361: 'отселиться',
#  362: 'понять',
#  363: 'сообщаться',
#  364: 'третий',
#  365: 'закрываться',
#  366: 'дёргать',
#  367: 'академик',
#  368: 'автолюбитель',
#  369: 'прогрессия',
#  370: 'вандальный',
#  371: 'недостаток',
#  372: 'обман',
#  373: 'грязевый',
#  374: 'слишком',
#  375: 'морозко',
#  376: 'болт',
#  377: 'оборона',
#  378: 'пятёрочка',
#  379: 'складываться',
#  380: 'нужный',
#  381: 'врать',
#  382: 'написать',
#  383: 'нерегулярно',
#  384: 'моющий',
#  385: 'курсант',
#  386: 'забирать',
#  387: 'сорваться',
#  388: 'опорожняться',
#  389: 'назначить',
#  390: 'ежемесячно',
#  391: 'возмлжность',
#  392: 'перемычка',
#  393: 'личность',
#  394: 'травмоопасность',
#  395: 'собрание',
#  396: 'наглядность',
#  397: 'интернет',
#  398: 'посредине',
#  399: 'краснодонский',
#  400: 'начальство',
#  401: 'дворовый',
#  402: 'мо',
#  403: 'крайний',
#  404: 'подставлять',
#  405: 'нахимов',
#  406: 'энергосберегающий',
#  407: 'джон',
#  408: 'течь',
#  409: 'передвинуть',
#  410: 'гдеть',
#  411: 'пьяный',
#  412: 'засор',
#  413: 'подоконник',
#  414: 'вывести',
#  415: 'основываться',
#  416: 'жизнеспособный',
#  417: 'терраса',
#  418: 'побелка',
#  419: 'экосити',
#  420: 'растение',
#  421: 'нож',
#  422: 'устать',
#  423: 'испоганить',
#  424: 'гжи',
#  425: 'рувд',
#  426: 'таракашка',
#  427: 'догрог',
#  428: 'мм',
#  429: 'рассыпать',
#  430: 'гупрэп',
#  431: 'садов',
#  432: 'уехать',
#  433: 'стикер',
#  434: 'продавить',
#  435: 'гагарин',
#  436: 'настроить',
#  437: 'проба',
#  438: 'напросто',
#  439: 'кавалергардский',
#  440: 'зависать',
#  441: 'ливневка',
#  442: 'рваться',
#  443: 'утро',
#  444: 'моп',
#  445: 'окей',
#  446: 'мех',
#  447: 'лично',
#  448: 'нерегулярный',
#  449: 'тончить',
#  450: 'владимир',
#  451: 'электробудка',
#  452: 'закончить',
#  453: 'запинаться',
#  454: 'прицеп',
#  455: 'удельный',
#  456: 'новиков',
#  457: 'удивлять',
#  458: 'проливать',
#  459: 'кафельный',
#  460: 'провод',
#  461: 'побелить',
#  462: 'починка',
#  463: 'чуткий',
#  464: 'нести',
#  465: 'реагировать',
#  466: 'садик',
#  467: 'тесто',
#  468: 'напротив',
#  469: 'неопрятно',
#  470: 'искажённый',
#  471: 'белить',
#  472: 'напротяжение',
#  473: 'привязать',
#  474: 'подписываться',
#  475: 'x',
#  476: 'вера',
#  477: 'стрелка',
#  478: 'утилизировать',
#  479: 'стачка',
#  480: 'пост',
#  481: 'вытекать',
#  482: 'палацио',
#  483: 'пересечение',
#  484: 'тротуарв',
#  485: 'однажды',
#  486: 'цирк',
#  487: 'возраст',
#  488: 'оштрафовать',
#  489: 'жилкома',
#  490: 'западный',
#  491: 'перекоситься',
#  492: 'задерживать',
#  493: 'вытяжной',
#  494: 'плинтус',
#  495: 'вероятность',
#  496: 'равномерно',
#  497: 'депо',
#  498: 'положительный',
#  499: 'расписаться',
#  500: 'наклон',
#  501: 'кад',
#  502: 'ландшафтный',
#  503: 'спецкомиссия',
#  504: 'полезно',
#  505: 'прямой',
#  506: 'чай',
#  507: 'управлять',
#  508: 'засунуть',
#  509: 'ложа',
#  510: 'скотч',
#  511: 'ямка',
#  512: 'деградировать',
#  513: 'рещётка',
#  514: 'кстати',
#  515: 'гвс',
#  516: 'озеленить',
#  517: 'колодец',
#  518: 'облезть',
#  519: 'теплоизолировать',
#  520: 'благоустройство',
#  521: 'частичный',
#  522: 'подниматься',
#  523: 'петля',
#  524: 'захарьевский',
#  525: 'признак',
#  526: 'ежегодно',
#  527: 'провайдер',
#  528: 'спасать',
#  529: 'карусель',
#  530: 'зацепиться',
#  531: 'мусороприемник',
#  532: 'потолочный',
#  533: 'соотвествовать',
#  534: 'дольщик',
#  535: 'трижды',
#  536: 'забор',
#  537: 'долго',
#  538: 'связываться',
#  539: 'бортовый',
#  540: 'пространство',
#  541: 'демонтировать',
#  542: 'захламление',
#  543: 'направо',
#  544: 'выглядить',
#  545: 'уголок',
#  546: 'переулок',
#  547: 'выкладывать',
#  548: 'наляпать',
#  549: 'участие',
#  550: 'воздух',
#  551: 'фиктивно',
#  552: 'телефон',
#  553: 'сказать',
#  554: 'шаг',
#  555: 'больый',
#  556: 'иван',
#  557: 'фон',
#  558: 'неизвестно',
#  559: 'застройка',
#  560: 'ода',
#  561: 'левашовский',
#  562: 'узел',
#  563: 'осветить',
#  564: 'нумерация',
#  565: 'скат',
#  566: 'ух',
#  567: 'пообещать',
#  568: 'неактуальный',
#  569: 'насыпной',
#  570: 'портал',
#  571: 'моментальный',
#  572: 'холодильник',
#  573: 'напряжение',
#  574: 'кузнечный',
#  575: 'негорт',
#  576: 'десница',
#  577: 'предоставить',
#  578: 'самолёт',
#  579: 'главстроить',
#  580: 'митрополикать',
#  581: 'сгрести',
#  582: 'будка',
#  583: 'профилактика',
#  584: 'желание',
#  585: 'предвгай',
#  586: 'выше',
#  587: 'подвойский',
#  588: 'королева',
#  589: 'просъб',
#  590: 'высококачественный',
#  591: 'уважение',
#  592: 'санузел',
#  593: 'дольшея',
#  594: 'изначальный',
#  595: 'правило',
#  596: 'гипермаркет',
#  597: 'износить',
#  598: 'протокол',
#  599: 'высадить',
#  600: 'недвижимость',
#  601: 'нерасчистить',
#  602: 'охт',
#  603: 'зеленогорский',
#  604: 'отписываться',
#  605: 'комитет',
#  606: 'захламлять',
#  607: 'расположить',
#  608: 'прочий',
#  609: 'выгружать',
#  610: 'реставрация',
#  611: 'лопнуть',
#  612: 'подводник',
#  613: 'пособие',
#  614: 'существенный',
#  615: 'тсж',
#  616: 'дёрнуть',
#  617: 'повезти',
#  618: 'указываться',
#  619: 'поочерёдно',
#  620: 'сеть',
#  621: 'лифт',
#  622: 'металл',
#  623: 'рогод',
#  624: 'курский',
#  625: 'кошмар',
#  626: 'рюмочный',
#  627: 'полотенцешушить',
#  628: 'вода',
#  629: 'водоём',
#  630: 'суббота',
#  631: 'жертва',
#  632: 'суворов',
#  633: 'инвентарь',
#  634: 'наглухо',
#  635: 'наклоняться',
#  636: 'газораспределительный',
#  637: 'общедомовой',
#  638: 'исходить',
#  639: 'пояснение',
#  640: 'путь',
#  641: 'всё',
#  642: 'строить',
#  643: 'молодец',
#  644: 'маркет',
#  645: 'отсек',
#  646: 'тормозить',
#  647: 'яндекс',
#  648: 'видео',
#  649: 'вышеизложенный',
#  650: 'насквозь',
#  651: 'владимирский',
#  652: 'тратить',
#  653: 'набиться',
#  654: 'проспект',
#  655: 'вряд',
#  656: 'подтвердиться',
#  657: 'калининский',
#  658: 'исполнитель',
#  659: 'вывалить',
#  660: 'замерзать',
#  661: 'сломать',
#  662: 'петербург',
#  663: 'прилететь',
#  664: 'режим',
#  665: 'кустарник',
#  666: 'госстрой',
#  667: 'решетчатый',
#  668: 'четверг',
#  669: 'часть',
#  670: 'способ',
#  671: 'заневский',
#  672: 'продуктовый',
#  673: 'стучать',
#  674: 'висеть',
#  675: 'помойка',
#  676: 'повалить',
#  677: 'легко',
#  678: 'общаться',
#  679: 'отслаивание',
#  680: 'съёмка',
#  681: 'целый',
#  682: 'мусоропроводный',
#  683: 'широта',
#  684: 'крепиться',
#  685: 'вручную',
#  686: 'отслаиваться',
#  687: 'качель',
#  688: 'головка',
#  689: 'предложение',
#  690: 'стабильно',
#  691: 'передача',
#  692: 'соответствие',
#  693: 'электроарматура',
#  694: 'ржавчина',
#  695: 'вазон',
#  696: 'тоьький',
#  697: 'поликарбонат',
#  698: 'превышать',
#  699: 'сигаретный',
#  700: 'виниловый',
#  701: 'вывозиться',
#  702: 'водослив',
#  703: 'болото',
#  704: 'автозапчасть',
#  705: 'крышечка',
#  706: 'румянцевский',
#  707: 'подбрасывать',
#  708: 'дерптский',
#  709: 'родитель',
#  710: 'петар',
#  711: 'ответсвенность',
#  712: 'ведущий',
#  713: 'лишний',
#  714: 'нестись',
#  715: 'щикододка',
#  716: 'обирать',
#  717: 'орлово',
#  718: 'жать',
#  719: 'удерживать',
#  720: 'влючить',
#  721: 'контейнеина',
#  722: 'строй',
#  723: 'ов',
#  724: 'ланскома',
#  725: 'порасти',
#  726: 'слободский',
#  727: 'раковина',
#  728: 'отнести',
#  729: 'сначала',
#  730: 'надптси',
#  731: 'светло',
#  732: 'консольный',
#  733: 'физический',
#  734: 'полировать',
#  735: 'запирание',
#  736: 'оказывать',
#  737: 'фонтанный',
#  738: 'форточка',
#  739: 'й',
#  740: 'следить',
#  741: 'мес',
#  742: 'оплата',
#  743: 'негде',
#  744: 'счищать',
#  745: 'илёд',
#  746: 'гуща',
#  747: 'прорвать',
#  748: 'период',
#  749: 'разваливаться',
#  750: 'переставить',
#  751: 'дым',
#  752: 'выгул',
#  753: 'вложить',
#  754: 'тухлый',
#  755: 'супемаркет',
#  756: 'находящаяс',
#  757: 'капот',
#  758: 'грп',
#  759: 'орлов',
#  760: 'раздербанить',
#  761: 'вешаться',
#  762: 'купить',
#  763: 'ра',
#  764: 'отказываться',
#  765: 'мириада',
#  766: 'рыбацкий',
#  767: 'род',
#  768: 'жидкость',
#  769: 'наведоваться',
#  770: 'исписать',
#  771: 'послать',
#  772: 'богданов',
#  773: 'комерческий',
#  774: 'бездействовать',
#  775: 'оставлять',
#  776: 'окрестность',
#  777: 'рушиться',
#  778: 'соблюсти',
#  779: 'вдвое',
#  780: 'разбить',
#  781: 'видеофиксация',
#  782: 'человеческий',
#  783: 'старый',
#  784: 'осуществлять',
#  785: 'шпатлёвка',
#  786: 'шаровой',
#  787: 'портить',
#  788: 'двп',
#  789: 'выдвинуть',
#  790: 'вывеска',
#  791: 'хотя',
#  792: 'промерзать',
#  793: 'лепнина',
#  794: 'уд',
#  795: 'причинить',
#  796: 'замотанный',
#  797: 'егоров',
#  798: 'наступать',
#  799: 'лаз',
#  800: 'неступить',
#  801: 'михаил',
#  802: 'скамейка',
#  803: 'отчасти',
#  804: 'рехколовский',
#  805: 'энтузиаст',
#  806: 'гренадерский',
#  807: 'неоднородность',
#  808: 'искрить',
#  809: 'готовность',
#  810: 'dns',
#  811: 'дополнительно',
#  812: 'замкнутый',
#  813: 'ванная',
#  814: 'баск',
#  815: 'лепёха',
#  816: 'неработающий',
#  817: 'вредитель',
#  818: 'пискарёвский',
#  819: 'арбузный',
#  820: 'приход',
#  821: 'называться',
#  822: 'риск',
#  823: 'нестерпимый',
#  824: 'ложный',
#  825: 'предупреждение',
#  826: 'ровность',
#  827: 'коридорный',
#  828: 'петербурый',
#  829: 'накопиться',
#  830: 'поверженный',
#  831: 'схема',
#  832: 'футбол',
#  833: 'забрызгать',
#  834: 'xxxxxxxxxxxxxxx',
#  835: 'диаметр',
#  836: 'норкоман',
#  837: 'контроль',
#  838: 'парк',
#  839: 'набор',
#  840: 'пирил',
#  841: 'наблюдать',
#  842: 'накладный',
#  843: 'раскряжёвка',
#  844: 'образование',
#  845: 'автоматизировать',
#  846: 'теплоизоляция',
#  847: 'ножка',
#  848: 'опорожнять',
#  849: 'gorod',
#  850: 'волна',
#  851: 'нагреваться',
#  852: 'х',
#  853: 'дрл',
#  854: 'спецтанспорт',
#  855: 'серпуховский',
#  856: 'надолго',
#  857: 'весна',
#  858: 'заочный',
#  859: 'разровнять',
#  860: 'замерзание',
#  861: 'опора',
#  862: 'генерал',
#  863: 'клавиша',
#  864: 'снабдить',
#  865: 'юридический',
#  866: 'загарадительный',
#  867: 'тратуаре',
#  868: 'пригодиться',
#  869: 'установоенный',
#  870: 'палец',
#  871: 'указанно',
#  872: 'выборы',
#  873: 'пить',
#  874: 'пытаться',
#  875: 'подзода',
#  876: 'запор',
#  877: 'российский',
#  878: 'околонулевой',
#  879: 'крысиный',
#  880: 'становиться',
#  881: 'вселяться',
#  882: 'электрошкаф',
#  883: 'копия',
#  884: 'дели',
#  885: 'хомут',
#  886: 'безответственно',
#  887: 'подвеска',
#  888: 'водоотводный',
#  889: 'спам',
#  890: 'стройка',
#  891: 'вымостить',
#  892: 'герметичный',
#  893: 'чайковский',
#  894: 'заносить',
#  895: 'временной',
#  896: 'ливнёвка',
#  897: 'сыграть',
#  898: 'предохранитель',
#  899: 'язык',
#  900: 'фуражный',
#  901: 'подтвердить',
#  902: 'простолюдин',
#  903: 'высохнуть',
#  904: 'несоблюдаться',
#  905: 'квадратный',
#  906: 'удалой',
#  907: 'сползти',
#  908: 'очередь',
#  909: 'комплектность',
#  910: 'большевик',
#  911: 'топливный',
#  912: 'контейнерный',
#  913: 'жуткий',
#  914: 'согласный',
#  915: 'смёт',
#  916: 'опорный',
#  917: 'анбо',
#  918: 'письмо',
#  919: 'ниша',
#  920: 'принять',
#  921: 'телефонный',
#  922: 'добровольно',
#  923: 'прилагать',
#  924: 'издеваться',
#  925: 'мемориальный',
#  926: 'листав',
#  927: 'поручень',
#  928: 'отпадать',
#  929: 'расколоться',
#  930: 'радиус',
#  931: 'вышкстоящий',
#  932: 'блюхер',
#  933: 'демонтаж',
#  934: 'пробка',
#  935: 'боков',
#  936: 'вредительство',
#  937: 'ковид',
#  938: 'двигать',
#  939: 'проводка',
#  940: 'незаизолировать',
#  941: 'прога',
#  942: 'случай',
#  943: 'разворотный',
#  944: 'собственник',
#  945: 'деформироваться',
#  946: 'знать',
#  947: 'дождаться',
#  948: 'хороший',
#  949: 'дождь',
#  950: 'презжий',
#  951: 'матрац',
#  952: 'облагородить',
#  953: 'отколоть',
#  954: 'никакой',
#  955: 'животное',
#  956: 'уплотнять',
#  957: 'бутыль',
#  958: 'поэт',
#  959: 'запредел',
#  960: 'строго',
#  961: 'бфа',
#  962: 'понизиться',
#  963: 'убогость',
#  964: 'востановить',
#  965: 'жх',
#  966: 'прибраться',
#  967: 'витрина',
#  968: 'ворота',
#  969: 'кирпич',
#  970: 'массовый',
#  971: 'xxxxxxxxxxxxxxxx',
#  972: 'геометрический',
#  973: 'гангутский',
#  974: 'поперечный',
#  975: 'увеличиваться',
#  976: 'обилие',
#  977: 'подвальный',
#  978: 'шлиссельбургский',
#  979: 'впрямую',
#  980: 'разводный',
#  981: 'торчать',
#  982: 'песок',
#  983: 'протечка',
#  984: 'издаваться',
#  985: 'кт',
#  986: 'измалевать',
#  987: 'грозить',
#  988: 'запуск',
#  989: 'кондиционный',
#  990: 'дрезденский',
#  991: 'капремонт',
#  992: 'нагнуться',
#  993: 'посыпка',
#  994: 'собственность',
#  995: 'справляться',
#  996: 'выгодный',
#  997: 'соединить',
#  998: 'наблюдение',
#  999: 'превышение',
#  ...}

# %%
pd.DataFrame(data=id_word, columns=["id", "word"]).to_csv("id_word.tsv", index=False)

# %%
word_id = {v: k for k, v in id_word.items()}
word_id
# Out:
# {'отломать': 0,
#  'строиться': 1,
#  'издевательство': 2,
#  'пара': 3,
#  'промежуточный': 4,
#  'вместе': 5,
#  'вывозить': 6,
#  'шурф': 7,
#  'предприниматься': 8,
#  'огорождение': 9,
#  'добрго': 10,
#  'малоохтинский': 11,
#  'песочница': 12,
#  'лужие': 13,
#  'материальный': 14,
#  'быстро': 15,
#  'время': 16,
#  'колёрный': 17,
#  'нарушеннго': 18,
#  'взудитие': 19,
#  'реальность': 20,
#  'прозрачный': 21,
#  'стена': 22,
#  'наверху': 23,
#  'комар': 24,
#  'выступать': 25,
#  'результативный': 26,
#  'сфетофора': 27,
#  'коляска': 28,
#  'готовый': 29,
#  'лом': 30,
#  'посредством': 31,
#  'выбоина': 32,
#  'элемент': 33,
#  'оно': 34,
#  'планировочный': 35,
#  'недостоверный': 36,
#  'пётр': 37,
#  'наклеить': 38,
#  'недомыть': 39,
#  'гнилостный': 40,
#  'согласовать': 41,
#  'сердобольский': 42,
#  'первомайский': 43,
#  'деревенский': 44,
#  'срок': 45,
#  'свыше': 46,
#  'импровизированный': 47,
#  'дезинфицировать': 48,
#  'справа': 49,
#  'разобрать': 50,
#  'физически': 51,
#  'примыкать': 52,
#  'подводный': 53,
#  'эвакуационный': 54,
#  'повсеместно': 55,
#  'освещёние': 56,
#  'блестеть': 57,
#  'контур': 58,
#  'бить': 59,
#  'миграция': 60,
#  'зимой': 61,
#  'воскресение': 62,
#  'вербный': 63,
#  'русановский': 64,
#  'мнение': 65,
#  'вопрос': 66,
#  'сук': 67,
#  'восстановителтный': 68,
#  'перечисленный': 69,
#  'освежить': 70,
#  'уворачиваться': 71,
#  'фёдоров': 72,
#  'поехать': 73,
#  'зазывала': 74,
#  'пополнять': 75,
#  'основание': 76,
#  'брус': 77,
#  'однокомнатный': 78,
#  'сохранность': 79,
#  'грвфитти': 80,
#  'щит': 81,
#  'перчатка': 82,
#  'серебряный': 83,
#  'натянуть': 84,
#  'ригель': 85,
#  'выкопировка': 86,
#  'расположение': 87,
#  'классификационный': 88,
#  'налоговый': 89,
#  'легковоспламенимый': 90,
#  'складывать': 91,
#  'красноармейский': 92,
#  'безнадёжно': 93,
#  'запланировать': 94,
#  'мошуваловый': 95,
#  'верейский': 96,
#  'таллинский': 97,
#  'верёвочный': 98,
#  'темнота': 99,
#  'семечко': 100,
#  'максимально': 101,
#  'очищаться': 102,
#  'тройка': 103,
#  'корп': 104,
#  'ти': 105,
#  'вблизи': 106,
#  'участник': 107,
#  'скакать': 108,
#  'тд': 109,
#  'кладовка': 110,
#  'хранение': 111,
#  'возможность': 112,
#  'мужчина': 113,
#  'урна': 114,
#  'обнаглеть': 115,
#  'нецелесообразный': 116,
#  'кондиционирование': 117,
#  'наземный': 118,
#  'фрунзенский': 119,
#  'трава': 120,
#  'вый': 121,
#  'волейбол': 122,
#  'целостность': 123,
#  'съезжать': 124,
#  'кустодиевый': 125,
#  'специальный': 126,
#  'грузовой': 127,
#  'подсохнуть': 128,
#  'прибор': 129,
#  'кривой': 130,
#  'беспорядочный': 131,
#  'взыскание': 132,
#  'расклеивание': 133,
#  'освещать': 134,
#  'обводный': 135,
#  'половина': 136,
#  'благо': 137,
#  'джд': 138,
#  'турник': 139,
#  'можайский': 140,
#  'вонять': 141,
#  'захлапываться': 142,
#  'отозвать': 143,
#  'давать': 144,
#  'тий': 145,
#  'мытый': 146,
#  'окрашиваться': 147,
#  'путешественник': 148,
#  'принудить': 149,
#  'актуальный': 150,
#  'ькача': 151,
#  'сомнительно': 152,
#  'план': 153,
#  'отсекать': 154,
#  'отштукатурить': 155,
#  'спонсировать': 156,
#  'водоотведение': 157,
#  'красногородский': 158,
#  'шестнадцатый': 159,
#  'ломбард': 160,
#  'прусак': 161,
#  'коврик': 162,
#  'газон': 163,
#  'предпринимать': 164,
#  'цокольный': 165,
#  'пищевой': 166,
#  'откидной': 167,
#  'парковаться': 168,
#  'докладывать': 169,
#  'маркиз': 170,
#  'оштукатурить': 171,
#  'видный': 172,
#  'крупский': 173,
#  'жб': 174,
#  'аппарта': 175,
#  'складирование': 176,
#  'продолжать': 177,
#  'разрыть': 178,
#  'заново': 179,
#  'президент': 180,
#  'ввполнить': 181,
#  'включить': 182,
#  'перекрёсток': 183,
#  'сделка': 184,
#  'перила': 185,
#  'главное': 186,
#  'марат': 187,
#  'пригласить': 188,
#  'разновидность': 189,
#  'боязнь': 190,
#  'малыгин': 191,
#  'колеровка': 192,
#  'устранять': 193,
#  'фантик': 194,
#  'соль': 195,
#  'грязь': 196,
#  'обнаружение': 197,
#  'невероятный': 198,
#  'изыскание': 199,
#  'вызванивать': 200,
#  'вчерашний': 201,
#  'поворачивать': 202,
#  'шесть': 203,
#  'маркин': 204,
#  'скуда': 205,
#  'просадка': 206,
#  'буквально': 207,
#  'лество': 208,
#  'роспись': 209,
#  'огонь': 210,
#  'обрастать': 211,
#  'кустарный': 212,
#  'электрощит': 213,
#  'оживлённый': 214,
#  'белградский': 215,
#  'грабли': 216,
#  'чинить': 217,
#  'озеленитель': 218,
#  'следствие': 219,
#  'сдаваться': 220,
#  'карьера': 221,
#  'прекратить': 222,
#  'погода': 223,
#  'дора': 224,
#  'казаков': 225,
#  'забиваться': 226,
#  'скопление': 227,
#  'дёргаться': 228,
#  'тридцать': 229,
#  'заставский': 230,
#  'высоко': 231,
#  'товарищество': 232,
#  'рассеянный': 233,
#  'проф': 234,
#  'коап': 235,
#  'сожаление': 236,
#  'богатырский': 237,
#  'суд': 238,
#  'электроподстанция': 239,
#  'потенциальный': 240,
#  'вывалиться': 241,
#  'негорючий': 242,
#  'отчитаться': 243,
#  'эты': 244,
#  'петербургский': 245,
#  'углублённый': 246,
#  'ознакомить': 247,
#  'проволока': 248,
#  'отделочный': 249,
#  'обещать': 250,
#  'буква': 251,
#  'дача': 252,
#  'сливной': 253,
#  'вязаный': 254,
#  'воспользоваться': 255,
#  'цеплять': 256,
#  'ламповый': 257,
#  'наклеивание': 258,
#  'разрушение': 259,
#  'провалиться': 260,
#  'трубка': 261,
#  'автоматически': 262,
#  'отваливать': 263,
#  'безобразный': 264,
#  'электрощитовой': 265,
#  'отклониться': 266,
#  'работодатель': 267,
#  'рекламный': 268,
#  'толкование': 269,
#  'кошка': 270,
#  'радищев': 271,
#  'юго': 272,
#  'свищь': 273,
#  'денисовский': 274,
#  'виленский': 275,
#  'коммерческий': 276,
#  'барельеф': 277,
#  'оформить': 278,
#  'марь': 279,
#  'повторять': 280,
#  'утрата': 281,
#  'зуб': 282,
#  'выясниться': 283,
#  'соколов': 284,
#  'контролировать': 285,
#  'гарькавый': 286,
#  'ласточкин': 287,
#  'пандус': 288,
#  'пища': 289,
#  'наружний': 290,
#  'левый': 291,
#  'неоднократный': 292,
#  'патрубок': 293,
#  'кабельный': 294,
#  'беспредел': 295,
#  'заливать': 296,
#  'учесть': 297,
#  'тихий': 298,
#  'доу': 299,
#  'оптико': 300,
#  'оригинальный': 301,
#  'бц': 302,
#  'переставать': 303,
#  'ехать': 304,
#  'вертикаль': 305,
#  'неполадка': 306,
#  'байконурский': 307,
#  'заславский': 308,
#  'ограничиваться': 309,
#  'загрузить': 310,
#  'футбольный': 311,
#  'двигатель': 312,
#  'месяц': 313,
#  'ободрать': 314,
#  'косяк': 315,
#  'развоздушивать': 316,
#  'подтекать': 317,
#  'белый': 318,
#  'полгода': 319,
#  'сообщение': 320,
#  'бомжатник': 321,
#  'оттенок': 322,
#  'подтечь': 323,
#  'пионерстрой': 324,
#  'лететь': 325,
#  'жилой': 326,
#  'сдвинуть': 327,
#  'убиваться': 328,
#  'регламент': 329,
#  'отчёт': 330,
#  'плюсовой': 331,
#  'относиться': 332,
#  'бухаретский': 333,
#  'сваливание': 334,
#  'хозяйство': 335,
#  'железо': 336,
#  'этажность': 337,
#  'отслоение': 338,
#  'комплекс': 339,
#  'коллега': 340,
#  'ненадлежащий': 341,
#  'муж': 342,
#  'истлевать': 343,
#  'продемонстрировать': 344,
#  'пачка': 345,
#  'высыпаться': 346,
#  'лёгкий': 347,
#  'глаз': 348,
#  'диск': 349,
#  'сторонний': 350,
#  'гск': 351,
#  'фигурировать': 352,
#  'теплосеть': 353,
#  'курьер': 354,
#  'закончиться': 355,
#  'сухой': 356,
#  'путин': 357,
#  'авангардный': 358,
#  'припарковаться': 359,
#  'временный': 360,
#  'отселиться': 361,
#  'понять': 362,
#  'сообщаться': 363,
#  'третий': 364,
#  'закрываться': 365,
#  'дёргать': 366,
#  'академик': 367,
#  'автолюбитель': 368,
#  'прогрессия': 369,
#  'вандальный': 370,
#  'недостаток': 371,
#  'обман': 372,
#  'грязевый': 373,
#  'слишком': 374,
#  'морозко': 375,
#  'болт': 376,
#  'оборона': 377,
#  'пятёрочка': 378,
#  'складываться': 379,
#  'нужный': 380,
#  'врать': 381,
#  'написать': 382,
#  'нерегулярно': 383,
#  'моющий': 384,
#  'курсант': 385,
#  'забирать': 386,
#  'сорваться': 387,
#  'опорожняться': 388,
#  'назначить': 389,
#  'ежемесячно': 390,
#  'возмлжность': 391,
#  'перемычка': 392,
#  'личность': 393,
#  'травмоопасность': 394,
#  'собрание': 395,
#  'наглядность': 396,
#  'интернет': 397,
#  'посредине': 398,
#  'краснодонский': 399,
#  'начальство': 400,
#  'дворовый': 401,
#  'мо': 402,
#  'крайний': 403,
#  'подставлять': 404,
#  'нахимов': 405,
#  'энергосберегающий': 406,
#  'джон': 407,
#  'течь': 408,
#  'передвинуть': 409,
#  'гдеть': 410,
#  'пьяный': 411,
#  'засор': 412,
#  'подоконник': 413,
#  'вывести': 414,
#  'основываться': 415,
#  'жизнеспособный': 416,
#  'терраса': 417,
#  'побелка': 418,
#  'экосити': 419,
#  'растение': 420,
#  'нож': 421,
#  'устать': 422,
#  'испоганить': 423,
#  'гжи': 424,
#  'рувд': 425,
#  'таракашка': 426,
#  'догрог': 427,
#  'мм': 428,
#  'рассыпать': 429,
#  'гупрэп': 430,
#  'садов': 431,
#  'уехать': 432,
#  'стикер': 433,
#  'продавить': 434,
#  'гагарин': 435,
#  'настроить': 436,
#  'проба': 437,
#  'напросто': 438,
#  'кавалергардский': 439,
#  'зависать': 440,
#  'ливневка': 441,
#  'рваться': 442,
#  'утро': 443,
#  'моп': 444,
#  'окей': 445,
#  'мех': 446,
#  'лично': 447,
#  'нерегулярный': 448,
#  'тончить': 449,
#  'владимир': 450,
#  'электробудка': 451,
#  'закончить': 452,
#  'запинаться': 453,
#  'прицеп': 454,
#  'удельный': 455,
#  'новиков': 456,
#  'удивлять': 457,
#  'проливать': 458,
#  'кафельный': 459,
#  'провод': 460,
#  'побелить': 461,
#  'починка': 462,
#  'чуткий': 463,
#  'нести': 464,
#  'реагировать': 465,
#  'садик': 466,
#  'тесто': 467,
#  'напротив': 468,
#  'неопрятно': 469,
#  'искажённый': 470,
#  'белить': 471,
#  'напротяжение': 472,
#  'привязать': 473,
#  'подписываться': 474,
#  'x': 475,
#  'вера': 476,
#  'стрелка': 477,
#  'утилизировать': 478,
#  'стачка': 479,
#  'пост': 480,
#  'вытекать': 481,
#  'палацио': 482,
#  'пересечение': 483,
#  'тротуарв': 484,
#  'однажды': 485,
#  'цирк': 486,
#  'возраст': 487,
#  'оштрафовать': 488,
#  'жилкома': 489,
#  'западный': 490,
#  'перекоситься': 491,
#  'задерживать': 492,
#  'вытяжной': 493,
#  'плинтус': 494,
#  'вероятность': 495,
#  'равномерно': 496,
#  'депо': 497,
#  'положительный': 498,
#  'расписаться': 499,
#  'наклон': 500,
#  'кад': 501,
#  'ландшафтный': 502,
#  'спецкомиссия': 503,
#  'полезно': 504,
#  'прямой': 505,
#  'чай': 506,
#  'управлять': 507,
#  'засунуть': 508,
#  'ложа': 509,
#  'скотч': 510,
#  'ямка': 511,
#  'деградировать': 512,
#  'рещётка': 513,
#  'кстати': 514,
#  'гвс': 515,
#  'озеленить': 516,
#  'колодец': 517,
#  'облезть': 518,
#  'теплоизолировать': 519,
#  'благоустройство': 520,
#  'частичный': 521,
#  'подниматься': 522,
#  'петля': 523,
#  'захарьевский': 524,
#  'признак': 525,
#  'ежегодно': 526,
#  'провайдер': 527,
#  'спасать': 528,
#  'карусель': 529,
#  'зацепиться': 530,
#  'мусороприемник': 531,
#  'потолочный': 532,
#  'соотвествовать': 533,
#  'дольщик': 534,
#  'трижды': 535,
#  'забор': 536,
#  'долго': 537,
#  'связываться': 538,
#  'бортовый': 539,
#  'пространство': 540,
#  'демонтировать': 541,
#  'захламление': 542,
#  'направо': 543,
#  'выглядить': 544,
#  'уголок': 545,
#  'переулок': 546,
#  'выкладывать': 547,
#  'наляпать': 548,
#  'участие': 549,
#  'воздух': 550,
#  'фиктивно': 551,
#  'телефон': 552,
#  'сказать': 553,
#  'шаг': 554,
#  'больый': 555,
#  'иван': 556,
#  'фон': 557,
#  'неизвестно': 558,
#  'застройка': 559,
#  'ода': 560,
#  'левашовский': 561,
#  'узел': 562,
#  'осветить': 563,
#  'нумерация': 564,
#  'скат': 565,
#  'ух': 566,
#  'пообещать': 567,
#  'неактуальный': 568,
#  'насыпной': 569,
#  'портал': 570,
#  'моментальный': 571,
#  'холодильник': 572,
#  'напряжение': 573,
#  'кузнечный': 574,
#  'негорт': 575,
#  'десница': 576,
#  'предоставить': 577,
#  'самолёт': 578,
#  'главстроить': 579,
#  'митрополикать': 580,
#  'сгрести': 581,
#  'будка': 582,
#  'профилактика': 583,
#  'желание': 584,
#  'предвгай': 585,
#  'выше': 586,
#  'подвойский': 587,
#  'королева': 588,
#  'просъб': 589,
#  'высококачественный': 590,
#  'уважение': 591,
#  'санузел': 592,
#  'дольшея': 593,
#  'изначальный': 594,
#  'правило': 595,
#  'гипермаркет': 596,
#  'износить': 597,
#  'протокол': 598,
#  'высадить': 599,
#  'недвижимость': 600,
#  'нерасчистить': 601,
#  'охт': 602,
#  'зеленогорский': 603,
#  'отписываться': 604,
#  'комитет': 605,
#  'захламлять': 606,
#  'расположить': 607,
#  'прочий': 608,
#  'выгружать': 609,
#  'реставрация': 610,
#  'лопнуть': 611,
#  'подводник': 612,
#  'пособие': 613,
#  'существенный': 614,
#  'тсж': 615,
#  'дёрнуть': 616,
#  'повезти': 617,
#  'указываться': 618,
#  'поочерёдно': 619,
#  'сеть': 620,
#  'лифт': 621,
#  'металл': 622,
#  'рогод': 623,
#  'курский': 624,
#  'кошмар': 625,
#  'рюмочный': 626,
#  'полотенцешушить': 627,
#  'вода': 628,
#  'водоём': 629,
#  'суббота': 630,
#  'жертва': 631,
#  'суворов': 632,
#  'инвентарь': 633,
#  'наглухо': 634,
#  'наклоняться': 635,
#  'газораспределительный': 636,
#  'общедомовой': 637,
#  'исходить': 638,
#  'пояснение': 639,
#  'путь': 640,
#  'всё': 641,
#  'строить': 642,
#  'молодец': 643,
#  'маркет': 644,
#  'отсек': 645,
#  'тормозить': 646,
#  'яндекс': 647,
#  'видео': 648,
#  'вышеизложенный': 649,
#  'насквозь': 650,
#  'владимирский': 651,
#  'тратить': 652,
#  'набиться': 653,
#  'проспект': 654,
#  'вряд': 655,
#  'подтвердиться': 656,
#  'калининский': 657,
#  'исполнитель': 658,
#  'вывалить': 659,
#  'замерзать': 660,
#  'сломать': 661,
#  'петербург': 662,
#  'прилететь': 663,
#  'режим': 664,
#  'кустарник': 665,
#  'госстрой': 666,
#  'решетчатый': 667,
#  'четверг': 668,
#  'часть': 669,
#  'способ': 670,
#  'заневский': 671,
#  'продуктовый': 672,
#  'стучать': 673,
#  'висеть': 674,
#  'помойка': 675,
#  'повалить': 676,
#  'легко': 677,
#  'общаться': 678,
#  'отслаивание': 679,
#  'съёмка': 680,
#  'целый': 681,
#  'мусоропроводный': 682,
#  'широта': 683,
#  'крепиться': 684,
#  'вручную': 685,
#  'отслаиваться': 686,
#  'качель': 687,
#  'головка': 688,
#  'предложение': 689,
#  'стабильно': 690,
#  'передача': 691,
#  'соответствие': 692,
#  'электроарматура': 693,
#  'ржавчина': 694,
#  'вазон': 695,
#  'тоьький': 696,
#  'поликарбонат': 697,
#  'превышать': 698,
#  'сигаретный': 699,
#  'виниловый': 700,
#  'вывозиться': 701,
#  'водослив': 702,
#  'болото': 703,
#  'автозапчасть': 704,
#  'крышечка': 705,
#  'румянцевский': 706,
#  'подбрасывать': 707,
#  'дерптский': 708,
#  'родитель': 709,
#  'петар': 710,
#  'ответсвенность': 711,
#  'ведущий': 712,
#  'лишний': 713,
#  'нестись': 714,
#  'щикододка': 715,
#  'обирать': 716,
#  'орлово': 717,
#  'жать': 718,
#  'удерживать': 719,
#  'влючить': 720,
#  'контейнеина': 721,
#  'строй': 722,
#  'ов': 723,
#  'ланскома': 724,
#  'порасти': 725,
#  'слободский': 726,
#  'раковина': 727,
#  'отнести': 728,
#  'сначала': 729,
#  'надптси': 730,
#  'светло': 731,
#  'консольный': 732,
#  'физический': 733,
#  'полировать': 734,
#  'запирание': 735,
#  'оказывать': 736,
#  'фонтанный': 737,
#  'форточка': 738,
#  'й': 739,
#  'следить': 740,
#  'мес': 741,
#  'оплата': 742,
#  'негде': 743,
#  'счищать': 744,
#  'илёд': 745,
#  'гуща': 746,
#  'прорвать': 747,
#  'период': 748,
#  'разваливаться': 749,
#  'переставить': 750,
#  'дым': 751,
#  'выгул': 752,
#  'вложить': 753,
#  'тухлый': 754,
#  'супемаркет': 755,
#  'находящаяс': 756,
#  'капот': 757,
#  'грп': 758,
#  'орлов': 759,
#  'раздербанить': 760,
#  'вешаться': 761,
#  'купить': 762,
#  'ра': 763,
#  'отказываться': 764,
#  'мириада': 765,
#  'рыбацкий': 766,
#  'род': 767,
#  'жидкость': 768,
#  'наведоваться': 769,
#  'исписать': 770,
#  'послать': 771,
#  'богданов': 772,
#  'комерческий': 773,
#  'бездействовать': 774,
#  'оставлять': 775,
#  'окрестность': 776,
#  'рушиться': 777,
#  'соблюсти': 778,
#  'вдвое': 779,
#  'разбить': 780,
#  'видеофиксация': 781,
#  'человеческий': 782,
#  'старый': 783,
#  'осуществлять': 784,
#  'шпатлёвка': 785,
#  'шаровой': 786,
#  'портить': 787,
#  'двп': 788,
#  'выдвинуть': 789,
#  'вывеска': 790,
#  'хотя': 791,
#  'промерзать': 792,
#  'лепнина': 793,
#  'уд': 794,
#  'причинить': 795,
#  'замотанный': 796,
#  'егоров': 797,
#  'наступать': 798,
#  'лаз': 799,
#  'неступить': 800,
#  'михаил': 801,
#  'скамейка': 802,
#  'отчасти': 803,
#  'рехколовский': 804,
#  'энтузиаст': 805,
#  'гренадерский': 806,
#  'неоднородность': 807,
#  'искрить': 808,
#  'готовность': 809,
#  'dns': 810,
#  'дополнительно': 811,
#  'замкнутый': 812,
#  'ванная': 813,
#  'баск': 814,
#  'лепёха': 815,
#  'неработающий': 816,
#  'вредитель': 817,
#  'пискарёвский': 818,
#  'арбузный': 819,
#  'приход': 820,
#  'называться': 821,
#  'риск': 822,
#  'нестерпимый': 823,
#  'ложный': 824,
#  'предупреждение': 825,
#  'ровность': 826,
#  'коридорный': 827,
#  'петербурый': 828,
#  'накопиться': 829,
#  'поверженный': 830,
#  'схема': 831,
#  'футбол': 832,
#  'забрызгать': 833,
#  'xxxxxxxxxxxxxxx': 834,
#  'диаметр': 835,
#  'норкоман': 836,
#  'контроль': 837,
#  'парк': 838,
#  'набор': 839,
#  'пирил': 840,
#  'наблюдать': 841,
#  'накладный': 842,
#  'раскряжёвка': 843,
#  'образование': 844,
#  'автоматизировать': 845,
#  'теплоизоляция': 846,
#  'ножка': 847,
#  'опорожнять': 848,
#  'gorod': 849,
#  'волна': 850,
#  'нагреваться': 851,
#  'х': 852,
#  'дрл': 853,
#  'спецтанспорт': 854,
#  'серпуховский': 855,
#  'надолго': 856,
#  'весна': 857,
#  'заочный': 858,
#  'разровнять': 859,
#  'замерзание': 860,
#  'опора': 861,
#  'генерал': 862,
#  'клавиша': 863,
#  'снабдить': 864,
#  'юридический': 865,
#  'загарадительный': 866,
#  'тратуаре': 867,
#  'пригодиться': 868,
#  'установоенный': 869,
#  'палец': 870,
#  'указанно': 871,
#  'выборы': 872,
#  'пить': 873,
#  'пытаться': 874,
#  'подзода': 875,
#  'запор': 876,
#  'российский': 877,
#  'околонулевой': 878,
#  'крысиный': 879,
#  'становиться': 880,
#  'вселяться': 881,
#  'электрошкаф': 882,
#  'копия': 883,
#  'дели': 884,
#  'хомут': 885,
#  'безответственно': 886,
#  'подвеска': 887,
#  'водоотводный': 888,
#  'спам': 889,
#  'стройка': 890,
#  'вымостить': 891,
#  'герметичный': 892,
#  'чайковский': 893,
#  'заносить': 894,
#  'временной': 895,
#  'ливнёвка': 896,
#  'сыграть': 897,
#  'предохранитель': 898,
#  'язык': 899,
#  'фуражный': 900,
#  'подтвердить': 901,
#  'простолюдин': 902,
#  'высохнуть': 903,
#  'несоблюдаться': 904,
#  'квадратный': 905,
#  'удалой': 906,
#  'сползти': 907,
#  'очередь': 908,
#  'комплектность': 909,
#  'большевик': 910,
#  'топливный': 911,
#  'контейнерный': 912,
#  'жуткий': 913,
#  'согласный': 914,
#  'смёт': 915,
#  'опорный': 916,
#  'анбо': 917,
#  'письмо': 918,
#  'ниша': 919,
#  'принять': 920,
#  'телефонный': 921,
#  'добровольно': 922,
#  'прилагать': 923,
#  'издеваться': 924,
#  'мемориальный': 925,
#  'листав': 926,
#  'поручень': 927,
#  'отпадать': 928,
#  'расколоться': 929,
#  'радиус': 930,
#  'вышкстоящий': 931,
#  'блюхер': 932,
#  'демонтаж': 933,
#  'пробка': 934,
#  'боков': 935,
#  'вредительство': 936,
#  'ковид': 937,
#  'двигать': 938,
#  'проводка': 939,
#  'незаизолировать': 940,
#  'прога': 941,
#  'случай': 942,
#  'разворотный': 943,
#  'собственник': 944,
#  'деформироваться': 945,
#  'знать': 946,
#  'дождаться': 947,
#  'хороший': 948,
#  'дождь': 949,
#  'презжий': 950,
#  'матрац': 951,
#  'облагородить': 952,
#  'отколоть': 953,
#  'никакой': 954,
#  'животное': 955,
#  'уплотнять': 956,
#  'бутыль': 957,
#  'поэт': 958,
#  'запредел': 959,
#  'строго': 960,
#  'бфа': 961,
#  'понизиться': 962,
#  'убогость': 963,
#  'востановить': 964,
#  'жх': 965,
#  'прибраться': 966,
#  'витрина': 967,
#  'ворота': 968,
#  'кирпич': 969,
#  'массовый': 970,
#  'xxxxxxxxxxxxxxxx': 971,
#  'геометрический': 972,
#  'гангутский': 973,
#  'поперечный': 974,
#  'увеличиваться': 975,
#  'обилие': 976,
#  'подвальный': 977,
#  'шлиссельбургский': 978,
#  'впрямую': 979,
#  'разводный': 980,
#  'торчать': 981,
#  'песок': 982,
#  'протечка': 983,
#  'издаваться': 984,
#  'кт': 985,
#  'измалевать': 986,
#  'грозить': 987,
#  'запуск': 988,
#  'кондиционный': 989,
#  'дрезденский': 990,
#  'капремонт': 991,
#  'нагнуться': 992,
#  'посыпка': 993,
#  'собственность': 994,
#  'справляться': 995,
#  'выгодный': 996,
#  'соединить': 997,
#  'наблюдение': 998,
#  'превышение': 999,
#  ...}

# %%
matrix_context = np.zeros((vocab_len, vocab_len))
window_size = 2

for doc in data:
    for i, word_one in enumerate(doc):
        for word_two in doc[i - window_size : i + window_size + 1]:
            if word_two != word_one:
                matrix_context[word_id[word_one], word_id[word_two]] += 1

# %%
list(pd.DataFrame(all_words)[0])
# Out:
# ['снег',
#  'дорога',
#  'очистить',
#  'кабельный',
#  'киоск',
#  'реклама',
#  'просить',
#  'убрать',
#  'всё',
#  'дерево',
#  'кустарник',
#  'который',
#  'выйти',
#  'предел',
#  'газон',
#  'пешеходный',
#  'зона',
#  'начинать',
#  'подъезд',
#  'подъезд',
#  'фасад',
#  'дом',
#  'сторона',
#  'ул',
#  'наличный',
#  'неудовлетворительный',
#  'состояние',
#  'парадный',
#  'надпись',
#  'дверь',
#  'этаж',
#  'граффити',
#  'необходимо',
#  'проверить',
#  'законность',
#  'установка',
#  'вывеска',
#  'фасад',
#  'мкд',
#  'адрес',
#  'проспект',
#  'непокорённый',
#  'случай',
#  'вывеска',
#  'установить',
#  'незаконно',
#  'её',
#  'необходимо',
#  'демонтировать',
#  'уборка',
#  'производиться',
#  'лестница',
#  'очень',
#  'грязно',
#  'весь',
#  'этаж',
#  'вплоть',
#  'го',
#  'звонок',
#  'жкс',
#  'дать',
#  'результат',
#  'мусор',
#  'отсутствовать',
#  'освещение',
#  'лестничный',
#  'площадка',
#  'этаж',
#  'парадный',
#  'делать',
#  'благоустройство',
#  'никто',
#  'убирать',
#  'мусор',
#  'ежедневно',
#  'просьба',
#  'закрасить',
#  'реклама',
#  'забор',
#  'снег',
#  'тротуар',
#  'убрать',
#  'проблема',
#  'регулярный',
#  'вывоз',
#  'мусор',
#  'рисунок',
#  'пожалуйста',
#  'удалить',
#  'бетонный',
#  'обрубка',
#  'ржавый',
#  'арматура',
#  'газон',
#  'дом',
#  'адрес',
#  'улица',
#  'тухачевский',
#  'далее',
#  'мусор',
#  'асфальт',
#  'ланский',
#  'шоссе',
#  'парадный',
#  'повредить',
#  'почтовый',
#  'ящик',
#  'просить',
#  'заменить',
#  'кривой',
#  'висеть',
#  'просьба',
#  'поправить',
#  'подьезд',
#  'этаж',
#  'плохой',
#  'уборка',
#  'улица',
#  'мусор',
#  'тротуар',
#  'газон',
#  'прямо',
#  'офис',
#  'муниципал',
#  'надпись',
#  'забор',
#  'убрать',
#  'частично',
#  'разрушить',
#  'ограждение',
#  'контейнерный',
#  'площадка',
#  'демонтаж',
#  'рекламный',
#  'вывеска',
#  'фасад',
#  'образоваться',
#  'повреждение',
#  'требоваться',
#  'произвести',
#  'работа',
#  'качественный',
#  'восстановление',
#  'штукатурный',
#  'окрасочный',
#  'слой',
#  'соответствовать',
#  'колерный',
#  'палитра',
#  'предварительно',
#  'подготовить',
#  'поверхность',
#  'оштукатурить',
#  'удалить',
#  'грязь',
#  'неровность',
#  'фотофиксация',
#  'прилагаться',
#  'надпись',
#  'стена',
#  'м',
#  'этаж',
#  'й',
#  'парадный',
#  'лифтовый',
#  'холл',
#  'скол',
#  'напольный',
#  'плитка',
#  'очистить',
#  'неудовлетворительный',
#  'состояние',
#  'покрытие',
#  'неудовлетворительный',
#  'состояние',
#  'парадный',
#  'потрескаться',
#  'штукатурка',
#  'облезлый',
#  'краска',
#  'входной',
#  'холл',
#  'дом',
#  'регулярно',
#  'отключать',
#  'горячий',
#  'вода',
#  'предупреждение',
#  'подчёркивать',
#  'протяжение',
#  'довольно',
#  'длительный',
#  'период',
#  'месяц',
#  'отключение',
#  'происходить',
#  'будний',
#  'день',
#  'период',
#  'листва',
#  'газон',
#  'реклама',
#  'опор',
#  'освещёние',
#  'мешок',
#  'собранный',
#  'мусор',
#  'школа',
#  'разбитый',
#  'машина',
#  'фара',
#  'требоваться',
#  'уборка',
#  'подъезд',
#  'санкт',
#  'петербург',
#  'ул',
#  'ярослав',
#  'гашек',
#  'далее',
#  'подъезд',
#  'несанкционированный',
#  'размещение',
#  'объявление',
#  'дверь',
#  'порча',
#  'общедомовый',
#  'имущество',
#  'мкд',
#  'всё',
#  'объявление',
#  'должный',
#  'размещиться',
#  'информационный',
#  'стенд',
#  'улица',
#  'халтурин',
#  'рядом',
#  'пешеходный',
#  'переход',
#  'напротив',
#  'дом',
#  'больший',
#  'яма',
#  'мусор',
#  'вне',
#  'контейнер',
#  'вывозить',
#  'мусор',
#  'очистить',
#  'столб',
#  'реклама',
#  'оставлять',
#  'след',
#  'бумага',
#  'клей',
#  'просьба',
#  'покрасить',
#  'почтовый',
#  'ящик',
#  'первый',
#  'центральный',
#  'парадный',
#  'жилой',
#  'дом',
#  'адрес',
#  'гражданский',
#  'проспект',
#  'дом',
#  'корпус',
#  'литера',
#  'центр',
#  'общеквартирный',
#  'коридор',
#  'шестой',
#  'этаж',
#  'парадный',
#  'район',
#  'лифтовый',
#  'площадка',
#  'незаконно',
#  'храниться',
#  'старый',
#  'грязный',
#  'выкинуть',
#  'деревянный',
#  'дверь',
#  'просить',
#  'убрать',
#  'первый',
#  'этаж',
#  'разбитый',
#  'стекло',
#  'дверь',
#  'сторона',
#  'двор',
#  'просить',
#  'заменить',
#  'спасибо',
#  'решётка',
#  'добрый',
#  'день',
#  'наш',
#  'дом',
#  'архивный',
#  'пара',
#  'систематически',
#  'работать',
#  'домофон',
#  'неоднократно',
#  'обращаться',
#  'ук',
#  'лично',
#  'ген',
#  'директор',
#  'ук',
#  'эталон',
#  'сервис',
#  'ремонтировать',
#  'привентивный',
#  'просьба',
#  'вмешаться',
#  'дом',
#  'человек',
#  'грудной',
#  'ребёнок',
#  'вынудить',
#  'подниматься',
#  'лесничестница',
#  'попасть',
#  'домой',
#  'детский',
#  'площадка',
#  'сломать',
#  'дуга',
#  'удерживать',
#  'верёвочный',
#  'сетка',
#  'который',
#  'ребёнок',
#  'залезать',
#  'горка',
#  'время',
#  'использование',
#  'верёвочный',
#  'сетка',
#  'весь',
#  'конструкция',
#  'сильно',
#  'качаться',
#  'любой',
#  'момент',
#  'мочь',
#  'упасть',
#  'придорожный',
#  'парадный',
#  'этаж',
#  'требовать',
#  'привести',
#  'кабель',
#  'канал',
#  'защитный',
#  'крышка',
#  'надлежащий',
#  'состояние',
#  'вывозиться',
#  'строительный',
#  'мусор',
#  'территория',
#  'двор',
#  'экскримент',
#  'лестница',
#  'необходимо',
#  'убрать',
#  'продизенфицировать',
#  'гореть',
#  'фонарь',
#  'открыть',
#  'люк',
#  'снег',
#  'убрать',
#  'проезжий',
#  'часть',
#  'тротуар',
#  'парадный',
#  'адрес',
#  'спб',
#  'улица',
#  'лиственный',
#  'дом',
#  'корпус',
#  'пол',
#  'год',
#  'общий',
#  'лестничный',
#  'клетка',
#  'этаж',
#  'лежать',
#  'строительный',
#  'мусор',
#  'который',
#  'никто',
#  'убирать',
#  'парадный',
#  'ужасный',
#  'состояние',
#  'внутренний',
#  'покраска',
#  'стена',
#  'краска',
#  'отваливаться',
#  'кусок',
#  'закрасить',
#  'отдельный',
#  'участник',
#  'стена',
#  'подтёк',
#  'стена',
#  'требоваться',
#  'провести',
#  'косметический',
#  'ремонт',
#  'полный',
#  'покраска',
#  'стена',
#  'яма',
#  'асфальт',
#  'санкционировать',
#  'размещение',
#  'наружный',
#  'блок',
#  'кондиционер',
#  'портить',
#  'фасад',
#  'дом',
#  'убрать',
#  'очистить',
#  'дорожный',
#  'знак',
#  'самоклей',
#  'мусор',
#  'надпись',
#  'киоск',
#  'напротив',
#  'дом',
#  'колпино',
#  'пр',
#  'ленин',
#  'напротив',
#  'аптека',
#  'лекоптторг',
#  'пожалуйста',
#  'восстановить',
#  'асфальт',
#  'второй',
#  'подъезд',
#  'адрес',
#  'улица',
#  'крюков',
#  'далее',
#  'граффити',
#  'самовольный',
#  'установка',
#  'конструкция',
#  'препятствовать',
#  'парковка',
#  'автотранспорт',
#  'дворовый',
#  'территория',
#  'фасад',
#  'сторона',
#  'щербаков',
#  'пер',
#  'оформить',
#  'общедолевой',
#  'собственность',
#  'земельный',
#  'участок',
#  'данный',
#  'факт',
#  'расценивать',
#  'самозахват',
#  'территория',
#  'просить',
#  'демонтировать',
#  'конструкция',
#  'обеспечить',
#  'исполнение',
#  'управлять',
#  'организация',
#  'дом',
#  'письмо',
#  'предписание',
#  'администрация',
#  'центральный',
#  'район',
#  'ряд',
#  'рамка',
#  'некоторый',
#  'данный',
#  'двор',
#  'дом',
#  'история',
#  'некоторый',
#  'рамка',
#  'обращение',
#  'снять',
#  'привычный',
#  'замок',
#  'однако',
#  'конструкция',
#  'продолжать',
#  'существовать',
#  'замок',
#  'скорее',
#  'весь',
#  'появиться',
#  'близкий',
#  'время',
#  'уровень',
#  'собственник',
#  'управлять',
#  'организация',
#  'данный',
#  'вопрос',
#  'решаться',
#  'сквер',
#  'внутридворовый',
#  'территория',
#  'завалить',
#  'мусор',
#  'лужа',
#  'пешеходный',
#  'переход',
#  'неудовлетворительный',
#  'состояние',
#  'фасад',
#  'дом',
#  'просить',
#  'произвести',
#  'капитальный',
#  'ремонт',
#  'фасад',
#  'жилой',
#  'дом',
#  'необходимо',
#  'покрасить',
#  'скамейка',
#  'возле',
#  'парадный',
#  'работать',
#  'лифт',
#  'день',
#  'сильно',
#  'загрязнить',
#  'территория',
#  'вокруг',
#  'дом',
#  'территория',
#  'газон',
#  'дом',
#  'убираться',
#  'яма',
#  'проезжий',
#  'часть',
#  'превышать',
#  'п',
#  'п',
#  'гост',
#  'р',
#  'очистить',
#  'снег',
#  'гололёд',
#  'парковка',
#  'машина',
#  'газон',
#  'просить',
#  'поставить',
#  'ограждение',
#  'графити',
#  'сторона',
#  'парадный',
#  'свет',
#  'подъезд',
#  'этаж',
#  'каждый',
#  'вкручивать',
#  'новый',
#  'лампа',
#  'хватать',
#  'месяц',
#  'необходимо',
#  'разобраться',
#  'причина',
#  'почему',
#  'часто',
#  'перегорать',
#  'лампа',
#  'фасад',
#  'отвалиться',
#  'облицовочный',
#  'панель',
#  'плитка',
#  'угрожать',
#  'безопасность',
#  'человек',
#  'просить',
#  'закрасить',
#  'фасад',
#  'гараж',
#  'парадный',
#  'гореть',
#  'освещение',
#  'обращение',
#  'председатель',
#  'жск',
#  'светлановец',
#  'помогать',
#  'спб',
#  'ул',
#  'гаврскай',
#  'далее',
#  'парадный',
#  'кв',
#  'этаж',
#  'просить',
#  'принять',
#  'мера',
#  'весь',
#  'прочее',
#  'использоваться',
#  'ртуть',
#  'содержать',
#  'лампа',
#  'мусор',
#  'газон',
#  'бутылка',
#  'бумага',
#  'отмыть',
#  'стекло',
#  'парадный',
#  'номер',
#  'просить',
#  'очистить',
#  'знак',
#  'реклама',
#  'гнить',
#  'фасад',
#  'нужно',
#  'штукатуривание',
#  'покраска',
#  'газонный',
#  'ограждение',
#  'необходимо',
#  'отремонтировать',
#  'перекосить',
#  'труба',
#  'установить',
#  'норматив',
#  'парадный',
#  'этаж',
#  'работать',
#  'освещение',
#  'оборудование',
#  'детский',
#  'площадка',
#  'требовать',
#  'ремонт',
#  'просадка',
#  'вокруг',
#  'колодец',
#  'трансформаторный',
#  'пожстанция',
#  'нанести',
#  'надпись',
#  'позорище',
#  'гора',
#  'мусор',
#  'свалка',
#  'придомовый',
#  'территория',
#  'граффити',
#  'ранее',
#  'работа',
#  'устранение',
#  'проблема',
#  'слабый',
#  'напор',
#  'холодный',
#  'вода',
#  'устранить',
#  'некачественно',
#  'эффект',
#  'временный',
#  'проблема',
#  'вернуться',
#  'замена',
#  'труба',
#  'хвс',
#  'произвести',
#  'весь',
#  'стояк',
#  'лишь',
#  'частично',
#  'невозможно',
#  'разбавить',
#  'горячий',
#  'вода',
#  'перепад',
#  'слабый',
#  'напор',
#  'приходиться',
#  'набирать',
#  'вода',
#  'ведро',
#  'помыться',
#  'обжечь',
#  'тело',
#  'вода',
#  'течь',
#  'тонкий',
#  'струя',
#  'посуда',
#  'проблемный',
#  'помыть',
#  'мусор',
#  'внутридворовый',
#  'территория',
#  'ул',
#  'крупский',
#  'ходить',
#  'здравствуйте',
#  'ужасный',
#  'состояние',
#  'парадный',
#  'ограждение',
#  'газон',
#  'сильно',
#  'заржавелый',
#  'необходимый',
#  'покраска',
#  'возможность',
#  'падение',
#  'опора',
#  'уличный',
#  'освещение',
#  'фонарный',
#  'столб',
#  'добрый',
#  'день',
#  'протечка',
#  'паркинг',
#  'улица',
#  'адмирал',
#  'трибуц',
#  'дом',
#  'нижний',
#  'уровень',
#  'около',
#  'вход',
#  'ую',
#  'парадный',
#  'фото',
#  'сделать',
#  'проблема',
#  'актуальный',
#  'каждый',
#  'год',
#  'весна',
#  'либо',
#  'время',
#  'сильный',
#  'осадки',
#  'обращение',
#  'офис',
#  'управлять',
#  'компания',
#  'сообщить',
#  'проблема',
#  'решаться',
#  'помощь',
#  'уборочный',
#  'машинка',
#  'который',
#  'ремонт',
#  'также',
#  'ук',
#  'сообщить',
#  'избавиться',
#  'протечка',
#  'проблема',
#  'актуальный',
#  'ук',
#  'ответить',
#  'вода',
#  'появиться',
#  'снова',
#  'уборка',
#  'просить',
#  'основательный',
#  'решение',
#  'проблема',
#  'спасибо',
#  'проезжать',
#  'часть',
#  'дорога',
#  'двор',
#  'очень',
#  'грязный',
#  'уборка',
#  'производиться',
#  'неудовлетворительно',
#  'сей',
#  'пора',
#  'асфальт',
#  'остаток',
#  'песчаный',
#  'смесь',
#  'который',
#  'рассыпать',
#  'зимой',
#  'середина',
#  'апрель',
#  'просить',
#  'провести',
#  'уборка',
#  'отмыть',
#  'дорога',
#  'двор',
#  'песок',
#  'грязь',
#  'ролгод',
#  'мусор',
#  'возле',
#  'контейнерный',
#  'площадка',
#  'спб',
#  'ул',
#  'кор',
#  'ая',
#  'парадный',
#  'отсутствовать',
#  'защитный',
#  'плафон',
#  'лампа',
#  'освещение',
#  'этаж',
#  'тсодда',
#  'длительный',
#  'время',
#  'разместить',
#  'несанкционированный',
#  'рекламный',
#  'объявление',
#  'рекламный',
#  'щит',
#  'весь',
#  'исписать',
#  'растрескивание',
#  'отделочный',
#  'материал',
#  'квартирный',
#  'холл',
#  'этаж',
#  'песок',
#  'добрый',
#  'день',
#  'недавно',
#  'двор',
#  'дом',
#  'адрес',
#  'гражданский',
#  'проспект',
#  'производиться',
#  'работа',
#  'ремонт',
#  'дорога',
#  'благоустройство',
#  'придомовый',
#  'территория',
#  'число',
#  'привести',
#  'восстановить',
#  'газон',
#  'территория',
#  'прилегать',
#  'детский',
#  'площадка',
#  'также',
#  'пустырь',
#  'находиться',
#  'электрический',
#  'подстанция',
#  'число',
#  'закрытый',
#  'дверной',
#  'оконный',
#  'проём',
#  'забросить',
#  'строение',
#  'который',
#  'попытка',
#  'организация',
#  'свалка',
#  'мусор',
#  'предотвращение',
#  'парковка',
#  'автотранспорт',
#  'восстановить',
#  'газон',
#  'установить',
#  'ограничитель',
#  'полусфера',
#  'данный',
#  'момент',
#  'сфера',
#  'отсутствовать',
#  'газон',
#  'осуществляться',
#  'парковка',
#  'автотранспорт',
#  'весь',
#  'газон',
#  'превратиться',
#  'разъездить',
#  'дорога',
#  'просить',
#  'дать',
#  'разъяснение',
#  'почему',
#  'благоустроенный',
#  'территория',
#  'превратиться',
#  'отстойник',
#  'автомобиль',
#  'неубранный',
#  'снег',
#  'тротуар',
#  'неубранный',
#  'снег',
#  'скользко',
#  'требоваться',
#  'посыпка',
#  'уборка',
#  'производиться',
#  'большой',
#  'месяц',
#  'проставляться',
#  'день',
#  'светить',
#  'надпись',
#  'похожий',
#  'свастика',
#  'фашистский',
#  'двор',
#  'напротив',
#  'детский',
#  'площадка',
#  'двор',
#  'снег',
#  'убрать',
#  'ещё',
#  'гололёд',
#  'лужа',
#  'незаконный',
#  'реклама',
#  'фасад',
#  'здание',
#  'надпись',
#  'будка',
#  'решётка',
#  'подъезд',
#  'мусоропровод',
#  'этаж',
#  'отсутствовать',
#  'освещение',
#  'фото',
#  'прилагаться',
#  'просьба',
#  'закрасить',
#  'смыть',
#  'граффити',
#  'парадный',
#  'подъезд',
#  'крайний',
#  'левый',
#  'лифт',
#  'неисправный',
#  'освещение',
#  'работать',
#  'светильник',
#  'второй',
#  'светить',
#  'еле',
#  'еле',
#  'председатель',
#  'тсж',
#  'ленинградский',
#  'вечер',
#  'отказываться',
#  ...]

# %% [markdown]
# ### 4. С помощью PCA уменьшить размер контекстных эмбеддингов (размер задать самостоятельно).

# %%
matrix_context_pca = PCA(n_components=3).fit_transform(matrix_context)

# %%
matrix_context_pca_round = np.round(matrix_context_pca, 5)

# %%
matrix_context_with_word = dict()

for i, word in id_word.items():
    matrix_context_with_word[word] = matrix_context_pca[i]
    
matrix_context_with_word
# Out:
# {'отломать': array([-1.44553453,  0.62872399, -0.02597886]),
#  'строиться': array([-1.50660367,  0.30338148, -0.08694989]),
#  'издевательство': array([-1.52272705,  0.44373145, -0.12269015]),
#  'пара': array([ 7.44616998, -6.99959938,  4.40037903]),
#  'промежуточный': array([-0.78875216,  0.98021995,  0.18064898]),
#  'вместе': array([-0.86855884, -0.27485124,  0.23199031]),
#  'вывозить': array([-0.0225091 , -1.23262574, -0.42693644]),
#  'шурф': array([-1.55199799,  0.35615122, -0.10110165]),
#  'предприниматься': array([-1.62286778,  0.40371952, -0.12079827]),
#  'огорождение': array([-1.44647844,  0.59977447, -0.02518229]),
#  'добрго': array([-1.65630525,  0.43927732, -0.10478637]),
#  'малоохтинский': array([-0.92839808,  0.27829357, -0.30479659]),
#  'песочница': array([-0.72648198, -0.59184534, -0.21725171]),
#  'лужие': array([-1.48009783,  0.06318099, -0.24140961]),
#  'материальный': array([-1.62919524,  0.42054926, -0.11245925]),
#  'быстро': array([-1.55337765,  0.31533121, -0.13597353]),
#  'время': array([14.30823188, -1.41891214, -6.12285288]),
#  'колёрный': array([-1.62606784,  0.42084946, -0.10966988]),
#  'нарушеннго': array([-1.51790024,  0.16027873, -0.14133144]),
#  'взудитие': array([-1.65630525,  0.43927732, -0.10478637]),
#  'реальность': array([-1.53954115,  0.41308039, -0.12995126]),
#  'прозрачный': array([-1.53941105,  0.3264334 , -0.11278978]),
#  'стена': array([115.84453638,   2.50666228,  30.95454764]),
#  'наверху': array([-1.54727142,  0.49670167,  0.01956451]),
#  'комар': array([-0.72363906,  0.84507084,  0.28826551]),
#  'выступать': array([-1.46882685,  0.18209399, -0.1209232 ]),
#  'результативный': array([-1.63855253,  0.41616487, -0.10374871]),
#  'сфетофора': array([-1.65630525,  0.43927732, -0.10478637]),
#  'коляска': array([ 3.21481214, -0.51746982, -0.65355957]),
#  'готовый': array([-1.44807031,  0.55666756, -0.04283436]),
#  'лом': array([-1.54545842,  0.25183945, -0.18712915]),
#  'посредством': array([-1.61041798,  0.37466223, -0.11135354]),
#  'выбоина': array([ 1.42900307, -0.78531464,  0.86058214]),
#  'элемент': array([ 6.71571708, -6.47017133,  1.97051179]),
#  'оно': array([-0.62927827,  0.1543435 , -0.34543414]),
#  'планировочный': array([-1.64501199,  0.43866702, -0.10145598]),
#  'недостоверный': array([-0.91621148,  0.77223745,  0.06908035]),
#  'пётр': array([-1.64576722,  0.42824042, -0.09848497]),
#  'наклеить': array([-1.27138001,  0.04073346, -0.05461859]),
#  'недомыть': array([-1.64500864,  0.44156623, -0.10693673]),
#  'гнилостный': array([-1.2177255 ,  0.70278583, -0.62475423]),
#  'согласовать': array([-1.23869561, -0.12792407, -0.12500067]),
#  'сердобольский': array([-1.58756442,  0.39961774, -0.04425464]),
#  'первомайский': array([-1.50624533,  0.20976045, -0.26362175]),
#  'деревенский': array([-1.63553292,  0.42278127, -0.10113811]),
#  'срок': array([ 2.06934685, -1.36933286, -0.4394277 ]),
#  'свыше': array([-1.46420612,  0.57466947, -0.18972925]),
#  'импровизированный': array([-1.04749106,  0.6803313 ,  0.39285145]),
#  'дезинфицировать': array([-0.72744437,  0.70561853,  0.01754474]),
#  'справа': array([ 8.87004255,  4.04562501, -1.8342699 ]),
#  'разобрать': array([-0.52801208,  0.62223155,  0.31261125]),
#  'физически': array([-1.54257626,  0.4988426 , -0.13032419]),
#  'примыкать': array([ 0.43334974, -1.6005521 , -0.00424929]),
#  'подводный': array([-1.61728661,  0.39155262, -0.12436481]),
#  'эвакуационный': array([ 5.47469681,  4.89854889, -0.35101982]),
#  'повсеместно': array([-1.52332359,  0.21976045, -0.23266644]),
#  'освещёние': array([-1.30049654,  0.12491232, -0.05898955]),
#  'блестеть': array([-1.55941172,  0.40413897, -0.10062931]),
#  'контур': array([-1.25990948,  0.52006511, -0.05142585]),
#  'бить': array([-1.55047897,  0.40985356, -0.1274286 ]),
#  'миграция': array([-1.6211354 ,  0.44230242, -0.10993229]),
#  'зимой': array([-0.9351666 ,  0.02339179,  0.12287313]),
#  'воскресение': array([-1.45127903,  0.34932576, -0.17350958]),
#  'вербный': array([-1.36102576,  0.19267545, -0.20419398]),
#  'русановский': array([-0.29025442, -1.28343644,  0.30702943]),
#  'мнение': array([-1.32302517,  0.34583459, -0.16506928]),
#  'вопрос': array([ 2.48282075, -1.9007499 ,  0.02185727]),
#  'сук': array([-1.65412876,  0.43867309, -0.10195969]),
#  'восстановителтный': array([-1.60163042,  0.40400882, -0.09534431]),
#  'перечисленный': array([-1.09884115, -0.11354384, -0.17170872]),
#  'освежить': array([-1.59280059,  0.31805834, -0.09147437]),
#  'уворачиваться': array([-1.64061065,  0.41258576, -0.10104295]),
#  'фёдоров': array([-1.37354006,  0.10187856, -0.23037169]),
#  'поехать': array([-1.49681204,  0.56465294, -0.13229338]),
#  'зазывала': array([-1.62371473,  0.42039697, -0.10222521]),
#  'пополнять': array([-1.59135773,  0.3994227 , -0.10522019]),
#  'основание': array([ 0.73871099, -0.8364197 ,  0.09795481]),
#  'брус': array([-1.64284409,  0.4110126 , -0.10565803]),
#  'однокомнатный': array([-1.28528304,  0.47606824, -0.37931273]),
#  'сохранность': array([-1.54006417,  0.36306133, -0.13239965]),
#  'грвфитти': array([-1.65630525,  0.43927732, -0.10478637]),
#  'щит': array([ 5.9108835, -4.447068 ,  0.3934247]),
#  'перчатка': array([-1.64627085,  0.41162605, -0.10631393]),
#  'серебряный': array([-1.60837842,  0.40097884, -0.09173349]),
#  'натянуть': array([-1.48667504,  0.25316672, -0.07990869]),
#  'ригель': array([-1.64144605,  0.45586517, -0.1050712 ]),
#  'выкопировка': array([-1.53238064,  0.32550204, -0.08760334]),
#  'расположение': array([-0.13057927,  1.14943982, -0.52323987]),
#  'классификационный': array([-1.60709504,  0.3856153 , -0.1098548 ]),
#  'налоговый': array([-1.61988104,  0.39671844, -0.11119987]),
#  'легковоспламенимый': array([-1.48958786,  0.24510236, -0.10137157]),
#  'складывать': array([-1.39281398,  0.18430865, -0.10559017]),
#  'красноармейский': array([-1.43776461,  0.24072803, -0.2556194 ]),
#  'безнадёжно': array([-1.5800307 ,  0.37191704, -0.09129851]),
#  'запланировать': array([ 0.08773265, -0.33144668, -0.39461954]),
#  'мошуваловый': array([-1.57092209,  0.29666366, -0.11589413]),
#  'верейский': array([-1.30070288,  0.49632565, -0.177741  ]),
#  'таллинский': array([-1.52224311,  0.20455477, -0.15266975]),
#  'верёвочный': array([-1.47560784,  0.36386031, -0.13826611]),
#  'темнота': array([-1.37522463,  0.16743672, -0.11522093]),
#  'семечко': array([-1.63098143,  0.39294166, -0.11246775]),
#  'максимально': array([-1.23971105,  0.15272294, -0.0551756 ]),
#  'очищаться': array([-0.38529405, -0.8352269 ,  0.37638737]),
#  'тройка': array([-1.54588901,  0.3729922 , -0.09366681]),
#  'корп': array([ 21.11261705, -13.86497381,   4.83775567]),
#  'ти': array([-1.58815789,  0.38985109, -0.09497664]),
#  'вблизи': array([ 0.02181114, -0.37746368,  0.7164152 ]),
#  'участник': array([-1.4374555 ,  0.32334603, -0.20092202]),
#  'скакать': array([-1.63919288,  0.4401626 , -0.10198227]),
#  'тд': array([-1.54238337,  0.38506966, -0.11114414]),
#  'кладовка': array([-1.53605717,  0.47132458, -0.14876738]),
#  'хранение': array([-1.21649206,  0.37175905, -0.27505794]),
#  'возможность': array([ 2.69830516, -0.82175665, -2.00120959]),
#  'мужчина': array([-1.6408281 ,  0.42167467, -0.10894084]),
#  'урна': array([10.07460872, -4.39885659, -3.74440456]),
#  'обнаглеть': array([-1.61710064,  0.41034229, -0.1067565 ]),
#  'нецелесообразный': array([-1.58206659,  0.4137088 , -0.10976653]),
#  'кондиционирование': array([-1.37848189,  0.12939462, -0.31628272]),
#  'наземный': array([-1.52111683,  0.30167773, -0.08605829]),
#  'фрунзенский': array([-1.47512511,  0.33186813, -0.1408634 ]),
#  'трава': array([-0.16731235, -0.65641732,  0.38074259]),
#  'вый': array([-1.59323406,  0.39238986, -0.09870089]),
#  'волейбол': array([-1.62629678,  0.4138518 , -0.08870997]),
#  'целостность': array([-0.78086058,  0.40235526,  0.01369523]),
#  'съезжать': array([-1.56201831,  0.25056954, -0.12081671]),
#  'кустодиевый': array([-1.65630525,  0.43927732, -0.10478637]),
#  'специальный': array([-0.55758708, -0.04102195, -0.82600074]),
#  'грузовой': array([19.59655316, 13.25945409, -5.75857515]),
#  'подсохнуть': array([-1.61609911,  0.39942273, -0.10966321]),
#  'прибор': array([-0.77754259,  0.30253995, -0.16442318]),
#  'кривой': array([-1.28957744,  0.17515138, -0.17977336]),
#  'беспорядочный': array([-1.65630525,  0.43927732, -0.10478637]),
#  'взыскание': array([-1.61641623,  0.39357071, -0.10167535]),
#  'расклеивание': array([ 0.01456592, -2.20840331,  0.22785319]),
#  'освещать': array([-0.8263757 , -0.65299222, -0.27574759]),
#  'обводный': array([-1.56071001,  0.29661199, -0.14123724]),
#  'половина': array([-0.65930278,  0.276417  , -0.31257108]),
#  'благо': array([-1.26006195,  0.66213184, -0.61758817]),
#  'джд': array([-1.65630525,  0.43927732, -0.10478637]),
#  'турник': array([-1.62937399,  0.39278224, -0.09714131]),
#  'можайский': array([-0.59030494, -0.88606497, -0.12592588]),
#  'вонять': array([ 0.61917546,  1.15300899, -2.38422949]),
#  'захлапываться': array([-1.61235052,  0.48890221, -0.09438599]),
#  'отозвать': array([-1.46104527,  0.324212  , -0.09340926]),
#  'давать': array([-0.39560608, -0.39401026,  0.64724365]),
#  'тий': array([-1.51130462,  0.42648814, -0.11317203]),
#  'мытый': array([-1.26025992,  0.76805477,  0.47957887]),
#  'окрашиваться': array([-1.41356884,  0.56400489, -0.34482256]),
#  'путешественник': array([-1.37425792, -0.01647607, -0.31074815]),
#  'принудить': array([-1.52433516,  0.32118054, -0.1429713 ]),
#  'актуальный': array([ 0.32207221,  0.63146114, -0.16123809]),
#  'ькача': array([-1.50592427,  0.19223969, -0.2234759 ]),
#  'сомнительно': array([-1.64185251,  0.38920826, -0.09219666]),
#  'план': array([ 0.82659484, -0.76598219,  0.53421913]),
#  'отсекать': array([-0.27241558,  1.53604933,  1.29207393]),
#  'отштукатурить': array([-1.41052591,  0.38384544, -0.18884938]),
#  'спонсировать': array([-1.64895499,  0.43673641, -0.09778763]),
#  'водоотведение': array([-1.47799399,  0.37034629, -0.07625103]),
#  'красногородский': array([-1.29171532, -0.00152058,  0.16858582]),
#  'шестнадцатый': array([-1.06815976,  0.65432945,  0.42300022]),
#  'ломбард': array([-1.33120413,  0.01940934,  0.25094704]),
#  'прусак': array([-1.63235984,  0.40153255, -0.11164921]),
#  'коврик': array([-0.41258712,  0.89516018,  0.28274809]),
#  'газон': array([ 58.7112145 , -70.35847173,   8.19970504]),
#  'предпринимать': array([-1.28383083,  0.05907948, -0.1413231 ]),
#  'цокольный': array([-1.10670573,  0.6681609 ,  0.47280701]),
#  'пищевой': array([-0.89528428, -0.37586989, -0.15015329]),
#  'откидной': array([-1.60888129,  0.39770704, -0.11005626]),
#  'парковаться': array([ 1.11600125, -3.60502437, -0.03894566]),
#  'докладывать': array([-1.5484075 ,  0.39253886, -0.10942881]),
#  'маркиз': array([-1.31916029,  0.39428118, -0.15268981]),
#  'оштукатурить': array([-0.67663541, -0.16476459,  0.03754423]),
#  'видный': array([ 2.70959933,  0.21321945, -0.38247303]),
#  'крупский': array([ 0.06076371, -1.08072757, -0.35326246]),
#  'жб': array([-1.15717038, -0.26827419, -0.09768017]),
#  'аппарта': array([-1.65405128,  0.43457183, -0.10326949]),
#  'складирование': array([-1.37433146, -0.01632788, -0.06854771]),
#  'продолжать': array([-0.07538877,  0.13239657, -0.82869151]),
#  'разрыть': array([-1.51019568,  0.39394275, -0.1073376 ]),
#  'заново': array([-1.45470151,  0.21138312, -0.1123671 ]),
#  'президент': array([-1.64356733,  0.42376222, -0.11305574]),
#  'ввполнить': array([-1.5151076 ,  0.35407964, -0.05100201]),
#  'включить': array([ 0.00184954,  0.58304687, -0.55881458]),
#  'перекрёсток': array([ 0.62901158, -2.77426857, -1.08116723]),
#  'сделка': array([-1.62172981,  0.41419324, -0.1049353 ]),
#  'перила': array([7.69561267, 4.98446254, 2.39495582]),
#  'главное': array([-1.51253173,  0.37513588, -0.10087363]),
#  'марат': array([-1.29152544, -0.00209568,  0.1694539 ]),
#  'пригласить': array([-1.64931904,  0.44194117, -0.09890248]),
#  'разновидность': array([-1.63060073,  0.36613377, -0.09467946]),
#  'боязнь': array([-1.55739981,  0.28190316, -0.20336956]),
#  'малыгин': array([-1.08065349,  0.57065191, -0.54983478]),
#  'колеровка': array([-1.601925  ,  0.40001354, -0.09628414]),
#  'устранять': array([-1.08021001,  0.54544705, -0.09868338]),
#  'фантик': array([-1.4311787 ,  0.18238752, -0.10138488]),
#  'соль': array([-0.49035706, -0.45252063,  0.36309123]),
#  'грязь': array([ 45.77396313, -13.27188233,   1.2897054 ]),
#  'обнаружение': array([-1.58935381,  0.43212154, -0.13081809]),
#  'невероятный': array([-1.646507  ,  0.42294977, -0.10502554]),
#  'изыскание': array([-1.60368026,  0.32335909, -0.12859313]),
#  'вызванивать': array([-1.38888033,  0.09843912, -0.10069441]),
#  'вчерашний': array([-1.19705304,  0.65502302, -0.5953473 ]),
#  'поворачивать': array([-1.56423535,  0.33090752, -0.09907822]),
#  'шесть': array([-0.72800712,  0.61756954, -0.67978298]),
#  'маркин': array([-1.48041143,  0.16314504, -0.28728225]),
#  'скуда': array([-1.59762702,  0.39859023, -0.09139566]),
#  'просадка': array([ 1.02901914, -2.1371002 ,  0.4186641 ]),
#  'буквально': array([-1.38491563,  0.14971746, -0.29420378]),
#  'лество': array([-1.4099587 ,  0.10134758, -0.10217681]),
#  'роспись': array([-1.20434866,  0.60997601,  0.1715805 ]),
#  'огонь': array([-1.65118492,  0.43079814, -0.10429383]),
#  'обрастать': array([-1.52791105,  0.37529005, -0.13650681]),
#  'кустарный': array([-1.64452629,  0.44056958, -0.10793519]),
#  'электрощит': array([ 1.45527089, -0.41201512,  2.57351576]),
#  'оживлённый': array([-1.50997453,  0.23653116, -0.20568638]),
#  'белградский': array([ 0.89226131, -2.01918915,  0.24589498]),
#  'грабли': array([-1.50070878,  0.24297679, -0.10390687]),
#  'чинить': array([-1.29426284,  0.66246662, -0.06690196]),
#  'озеленитель': array([-1.53442465,  0.3933341 , -0.15328776]),
#  'следствие': array([-0.17343548,  1.0511984 , -0.13519317]),
#  'сдаваться': array([-1.65313892,  0.43561617, -0.10508725]),
#  'карьера': array([-1.54595281,  0.24731691, -0.19932969]),
#  'прекратить': array([-1.37108502,  0.114156  , -0.07518855]),
#  'погода': array([-1.14653147,  0.40300275, -0.38854509]),
#  'дора': array([-1.65374078,  0.43817585, -0.1057104 ]),
#  'казаков': array([ 0.82059596, -1.03187155, -0.89989308]),
#  'забиваться': array([-1.65596471,  0.4385822 , -0.10578237]),
#  'скопление': array([ 0.66268463, -2.31109965, -0.06670542]),
#  'дёргаться': array([-1.59741718,  0.42318013, -0.10149217]),
#  'тридцать': array([-1.57976094,  0.23060187, -0.14956711]),
#  'заставский': array([-1.62228896,  0.4336151 , -0.1178442 ]),
#  'высоко': array([-1.63336286,  0.42915577, -0.10595478]),
#  'товарищество': array([-1.64423348,  0.4221353 , -0.11048167]),
#  'рассеянный': array([-1.64347962,  0.45380302, -0.11401669]),
#  'проф': array([-1.6107903 ,  0.40140356, -0.10809424]),
#  'коап': array([-1.61346141,  0.31620059, -0.06247554]),
#  'сожаление': array([-0.77663549,  0.35218021, -0.62137076]),
#  'богатырский': array([ 0.16271284, -1.56594239,  0.97703371]),
#  'суд': array([-1.54321431,  0.33405923, -0.14322884]),
#  'электроподстанция': array([-0.52412721, -0.76948109,  0.40667025]),
#  'потенциальный': array([-1.63144558,  0.44617842, -0.13151201]),
#  'вывалиться': array([-1.59878512,  0.39359906, -0.11644607]),
#  'негорючий': array([-1.48339292,  0.55437144, -0.1851795 ]),
#  'отчитаться': array([-1.14414036,  0.20529028,  0.05675412]),
#  'эты': array([-1.22765064,  0.65107931, -0.61526625]),
#  'петербургский': array([-1.36334266,  0.12597295,  0.26027533]),
#  'углублённый': array([-1.25452221,  0.66833835, -0.61437671]),
#  'ознакомить': array([-1.65061197,  0.43858811, -0.10727131]),
#  'проволока': array([-1.33387634,  0.09222511, -0.11234783]),
#  'отделочный': array([-1.569437  ,  0.4236043 , -0.11360966]),
#  'обещать': array([-0.48875431,  0.26976023, -0.12796211]),
#  'буква': array([-1.26606122, -0.09752309,  0.23886605]),
#  'дача': array([-1.58621213,  0.40854487, -0.06257336]),
#  'сливной': array([-1.59475912,  0.47107764, -0.12762091]),
#  'вязаный': array([-1.64708393,  0.43446543, -0.10331162]),
#  'воспользоваться': array([-1.60515952,  0.42166707, -0.1064904 ]),
#  'цеплять': array([-1.21416498,  0.72365733,  0.06354967]),
#  'ламповый': array([-1.56010225,  0.42350712, -0.1237683 ]),
#  'наклеивание': array([-1.57007993,  0.30240984, -0.06817494]),
#  'разрушение': array([-0.34047825, -0.67298487, -0.3037246 ]),
#  'провалиться': array([-0.77582091, -0.48266039, -0.14476703]),
#  'трубка': array([-0.73075006,  0.94433531, -1.12044964]),
#  'автоматически': array([-1.22506043, -0.01109285, -0.18558528]),
#  'отваливать': array([-1.59664654,  0.32020686, -0.10247916]),
#  'безобразный': array([-1.00761213,  0.62238208, -0.5892608 ]),
#  'электрощитовой': array([-1.42129941,  0.4661514 , -0.20048513]),
#  'отклониться': array([-1.50624338,  0.28615518, -0.08969331]),
#  'работодатель': array([-1.63953019,  0.41239317, -0.10369725]),
#  'рекламный': array([ 20.11678007, -35.13427364,   3.04183255]),
#  'толкование': array([-1.64885767,  0.44110171, -0.11017154]),
#  'кошка': array([-1.02814197,  0.38224586, -0.23547935]),
#  'радищев': array([-1.57901755,  0.34552353, -0.09961015]),
#  'юго': array([-0.9420224 ,  0.00928164, -0.49053681]),
#  'свищь': array([-1.64516465,  0.44686492, -0.10017674]),
#  'денисовский': array([-1.09202871, -0.23865888, -0.21898295]),
#  'виленский': array([-1.65630525,  0.43927732, -0.10478637]),
#  'коммерческий': array([-1.54814076,  0.2869481 , -0.10901168]),
#  'барельеф': array([-1.63562329,  0.40469514, -0.10291335]),
#  'оформить': array([-1.2449634 ,  0.3637578 , -0.08438769]),
#  'марь': array([-1.60662835,  0.4000075 , -0.10006454]),
#  'повторять': array([-1.61454136,  0.35075335, -0.08107074]),
#  'утрата': array([-1.63065783,  0.41761382, -0.10568183]),
#  'зуб': array([-1.57397252,  0.33712166, -0.07794525]),
#  'выясниться': array([-1.3632775 ,  0.14274138,  0.26706027]),
#  'соколов': array([-1.38051253,  0.13782078,  0.26467324]),
#  'контролировать': array([-0.85514215,  0.36145014,  0.21056567]),
#  'гарькавый': array([-1.38960517,  0.14228656, -0.30928369]),
#  'ласточкин': array([-1.62662372,  0.37691719, -0.12500178]),
#  'пандус': array([ 1.28707021, -0.09731863, -0.13652354]),
#  'пища': array([-1.64079958,  0.4375211 , -0.09919877]),
#  'наружний': array([-1.48088462,  0.48524495, -0.11100927]),
#  'левый': array([ 4.29439491,  1.73223108, -0.39444747]),
#  'неоднократный': array([ 0.62546206, -0.89859034,  1.12302887]),
#  'патрубок': array([-1.64411495,  0.41895004, -0.10659329]),
#  'кабельный': array([-0.33924145, -1.21413941, -0.4652666 ]),
#  'беспредел': array([-1.55364187,  0.36295417, -0.08029158]),
#  'заливать': array([-1.14168418,  0.10835997,  0.35072074]),
#  'учесть': array([-1.23644035,  0.54378422, -0.32579733]),
#  'тихий': array([-1.56430608,  0.29893674, -0.18741449]),
#  'доу': array([-1.31688496, -0.03684654, -0.17234743]),
#  'оптико': array([-1.61243744,  0.44517457, -0.09512972]),
#  'оригинальный': array([-1.41238213,  0.44172099, -0.16767091]),
#  'бц': array([-1.53704763,  0.22059758, -0.11290709]),
#  'переставать': array([-1.62796957,  0.43317177, -0.10187539]),
#  'ехать': array([2.23433286, 2.29437529, 2.66358877]),
#  'вертикаль': array([-1.53034347,  0.40065452, -0.14665858]),
#  'неполадка': array([-1.36861439,  0.50687105, -0.24663212]),
#  'байконурский': array([-0.97666701, -0.34414287,  0.57612378]),
#  'заславский': array([-1.50595639,  0.16956126, -0.20362955]),
#  'ограничиваться': array([-1.6222008 ,  0.44142089, -0.10842908]),
#  'загрузить': array([-1.36852155,  0.43765754, -0.19513706]),
#  'футбольный': array([-1.23769223,  0.12348445, -0.19898624]),
#  'двигатель': array([-1.63411578,  0.43057336, -0.09936726]),
#  'месяц': array([23.44398716,  3.28418028,  0.19024127]),
#  'ободрать': array([-1.04417785,  0.12078021,  0.27425388]),
#  'косяк': array([-0.87274679,  0.77857758, -0.56157451]),
#  'развоздушивать': array([-1.59864569,  0.41968049, -0.10591241]),
#  'подтекать': array([-1.65297482,  0.4399005 , -0.10480495]),
#  'белый': array([-0.17953846,  0.68659461, -1.1686831 ]),
#  'полгода': array([-0.26169838,  0.21130034, -0.51670279]),
#  'сообщение': array([ 3.82749066, -0.94440167, -0.72794074]),
#  'бомжатник': array([-1.62798041,  0.43707805, -0.10353353]),
#  'оттенок': array([-1.52367541,  0.32632881, -0.13139995]),
#  'подтечь': array([1.49560797, 1.9283449 , 0.02528851]),
#  'пионерстрой': array([-1.54157672,  0.37525008, -0.18118012]),
#  'лететь': array([-0.83130567, -0.64931328, -0.27632681]),
#  'жилой': array([ 23.28511466, -19.2159434 ,  12.34699972]),
#  'сдвинуть': array([-1.56132254,  0.4208805 , -0.10813281]),
#  'убиваться': array([-1.4929312 ,  0.27259568, -0.16769088]),
#  'регламент': array([-1.28731356,  0.30709153, -0.07137048]),
#  'отчёт': array([0.118424  , 0.13754944, 0.05116004]),
#  'плюсовой': array([-1.64173346,  0.43685556, -0.09608209]),
#  'относиться': array([ 0.51554281, -1.1990839 ,  0.42284705]),
#  'бухаретский': array([-1.55304528,  0.32443136, -0.21714246]),
#  'сваливание': array([-1.61913197,  0.40127237, -0.11179327]),
#  'хозяйство': array([-1.61119261,  0.33964851, -0.0990743 ]),
#  'железо': array([-1.60369425,  0.40080321, -0.10497443]),
#  'этажность': array([-1.22093254,  0.7566767 ,  0.47646802]),
#  'отслоение': array([-0.01753198,  0.55921939,  0.42420893]),
#  'комплекс': array([-1.19267453,  0.00745106, -0.05538815]),
#  'коллега': array([-1.59922792,  0.41962362, -0.115587  ]),
#  'ненадлежащий': array([6.05185355, 1.5111405 , 1.10758942]),
#  'муж': array([-1.4976011 ,  0.29373147, -0.07939989]),
#  'истлевать': array([-1.60815024,  0.45826747, -0.12124057]),
#  'продемонстрировать': array([-1.64785647,  0.43509056, -0.10035459]),
#  'пачка': array([-1.64343212,  0.41826251, -0.10904584]),
#  'высыпаться': array([-1.26683571, -0.05421615, -0.07759924]),
#  'лёгкий': array([-0.98088708,  0.73584135, -0.24101969]),
#  'глаз': array([-1.56843339,  0.39918444, -0.09828586]),
#  'диск': array([-1.63214225,  0.40192772, -0.10332632]),
#  'сторонний': array([-1.64110579,  0.41945478, -0.10493533]),
#  'гск': array([-1.65630525,  0.43927732, -0.10478637]),
#  'фигурировать': array([-1.63255188,  0.43381873, -0.1064905 ]),
#  'теплосеть': array([-1.39509004,  0.57518418, -0.3441816 ]),
#  'курьер': array([-1.43234704,  0.658117  , -0.2686466 ]),
#  'закончиться': array([-1.23255722,  0.40321445, -0.34507272]),
#  'сухой': array([3.72849379, 0.90432383, 2.20339983]),
#  'путин': array([-1.62630238,  0.42325133, -0.09980785]),
#  'авангардный': array([-1.12669774, -0.25653971,  0.07359566]),
#  'припарковаться': array([-1.61072249,  0.39834076, -0.1029915 ]),
#  'временный': array([-1.57792004,  0.36896515, -0.10056825]),
#  'отселиться': array([-1.65630525,  0.43927732, -0.10478637]),
#  'понять': array([-1.49030798,  0.27427748, -0.09510525]),
#  'сообщаться': array([-1.11157103,  0.550977  , -0.30762113]),
#  'третий': array([21.96971643, 12.83188307,  3.70790694]),
#  'закрываться': array([22.80319994, 16.25550137, -1.34618284]),
#  'дёргать': array([-1.06291397,  0.82501424, -0.55798205]),
#  'академик': array([-1.44247714,  0.1850242 , -0.18701002]),
#  'автолюбитель': array([-1.64878379,  0.42954512, -0.10512653]),
#  'прогрессия': array([-1.59758201,  0.39630989, -0.09766876]),
#  'вандальный': array([-0.55551442, -0.93503684, -0.68444562]),
#  'недостаток': array([-1.00003019,  0.27611123,  0.01079155]),
#  'обман': array([-1.13406065, -0.30915966, -0.11260167]),
#  'грязевый': array([-1.59296938,  0.2843231 , -0.12287008]),
#  'слишком': array([-1.50724789,  0.23494592, -0.1406864 ]),
#  'морозко': array([-1.26129846,  0.06686091,  0.18912697]),
#  'болт': array([-1.58262416,  0.40247692, -0.10758517]),
#  'оборона': array([-0.81381047, -0.56412316, -0.02083193]),
#  'пятёрочка': array([ 0.36591498, -1.21555712,  0.22812185]),
#  'складываться': array([-1.25842407,  0.02619017, -0.22705912]),
#  'нужный': array([2.07855007, 0.79609438, 1.49020558]),
#  'врать': array([-1.55228198,  0.28347096, -0.11495847]),
#  'написать': array([-0.83967594,  0.25213036, -0.2164256 ]),
#  'нерегулярно': array([-1.47902771,  0.53820586, -0.20586643]),
#  'моющий': array([0.15586409, 0.67598608, 0.66753783]),
#  'курсант': array([-1.29256694,  0.47242635, -0.38122765]),
#  'забирать': array([-1.65630525,  0.43927732, -0.10478637]),
#  'сорваться': array([-1.62228648,  0.41329692, -0.11091492]),
#  'опорожняться': array([-1.62626834,  0.42935107, -0.09711601]),
#  'назначить': array([-1.054454  ,  0.13575209, -0.27171127]),
#  'ежемесячно': array([-0.17852907, -0.1657592 ,  0.16092124]),
#  'возмлжность': array([-1.62146532,  0.35574249, -0.10623992]),
#  'перемычка': array([-1.19515951,  0.82135488,  0.4665034 ]),
#  'личность': array([-1.42160391,  0.55864144, -0.32032992]),
#  'травмоопасность': array([-1.58124108,  0.36178577, -0.13661059]),
#  'собрание': array([-0.21809682, -0.61602548, -0.01122639]),
#  'наглядность': array([-1.43244555,  0.38503024, -0.15782451]),
#  'интернет': array([-1.15909345, -0.12180943, -0.10081391]),
#  'посредине': array([-0.95400896,  0.16685733, -0.69114753]),
#  'краснодонский': array([-0.69779182, -0.33148748, -0.16134254]),
#  'начальство': array([-1.61763768,  0.45034328, -0.10446641]),
#  'дворовый': array([  8.19204676, -11.5507999 ,   1.27199544]),
#  'мо': array([-1.52609056,  0.30358985, -0.07662787]),
#  'крайний': array([-0.97899823, -0.02526876, -0.11500476]),
#  'подставлять': array([-1.62774578,  0.35781963, -0.06566002]),
#  'нахимов': array([-1.2536201 ,  0.39190296, -0.35491233]),
#  'энергосберегающий': array([-0.93196436,  0.72686813,  0.37450271]),
#  'джон': array([-0.89849626, -0.59389088, -0.10845752]),
#  'течь': array([2.68406522, 1.28757824, 0.85972902]),
#  'передвинуть': array([-1.33350044,  0.12402281, -0.08594605]),
#  'гдеть': array([-0.86643178,  1.13450099,  1.02290003]),
#  'пьяный': array([-1.63523354,  0.42215499, -0.10588153]),
#  'засор': array([-0.43866106,  0.50406476, -0.46360939]),
#  'подоконник': array([6.4927845 , 3.12068026, 0.89076689]),
#  'вывести': array([ 1.1311235 , -3.22858293, -0.01535908]),
#  'основываться': array([-1.65630525,  0.43927732, -0.10478637]),
#  'жизнеспособный': array([-1.57368472,  0.3790808 , -0.09229635]),
#  'терраса': array([-1.56548065,  0.48461971,  0.01788865]),
#  'побелка': array([-0.25035719,  0.39430021, -0.47561937]),
#  'экосити': array([-1.65630525,  0.43927732, -0.10478637]),
#  'растение': array([-1.51250226,  0.14142556, -0.13647292]),
#  'нож': array([-1.65432845,  0.43610953, -0.10394003]),
#  'устать': array([-1.57123064,  0.38257476, -0.1547709 ]),
#  'испоганить': array([-1.14147233,  0.50566014, -0.38858501]),
#  'гжи': array([-1.47420242,  0.57730402, -0.19895463]),
#  'рувд': array([-1.64751074,  0.42498229, -0.10364193]),
#  'таракашка': array([-1.48673176,  0.4124427 , -0.19541676]),
#  'догрог': array([-1.55123363,  0.29936131, -0.13567494]),
#  'мм': array([-1.47932514,  0.36529579, -0.18242134]),
#  'рассыпать': array([-0.89946172,  0.30608228,  0.35365845]),
#  'гупрэп': array([-1.65630525,  0.43927732, -0.10478637]),
#  'садов': array([-1.56326619,  0.20828719, -0.15319154]),
#  'уехать': array([0.41677722, 1.26525389, 0.94407297]),
#  'стикер': array([-1.53822075,  0.29361753, -0.14521037]),
#  'продавить': array([-1.64245758,  0.41955432, -0.10266031]),
#  'гагарин': array([-0.93716599,  0.30049956, -0.74370924]),
#  'настроить': array([-1.5597546 ,  0.51054899, -0.07937711]),
#  'проба': array([-1.63024927,  0.40036578, -0.10222988]),
#  'напросто': array([-1.51881564,  0.47630584, -0.11201481]),
#  'кавалергардский': array([-0.7935523 , -0.7425767 ,  0.41734784]),
#  'зависать': array([-1.54491084,  0.43667677, -0.10691205]),
#  'ливневка': array([-0.74161479,  0.94959412,  0.02215963]),
#  'рваться': array([-1.58890416,  0.39216764, -0.11441257]),
#  'утро': array([-0.61943294,  0.74703884,  0.22448979]),
#  'моп': array([7.02167185, 6.8214676 , 4.88888304]),
#  'окей': array([-1.41329928,  0.10597691, -0.13515942]),
#  'мех': array([-1.47547617,  0.49188157,  0.02975625]),
#  'лично': array([-1.61068167,  0.39691419, -0.10317199]),
#  'нерегулярный': array([-0.69462572,  1.04715209,  0.09512621]),
#  'тончить': array([-0.87417298,  0.99556389, -0.03458343]),
#  'владимир': array([-1.65573587,  0.44006567, -0.10635043]),
#  'электробудка': array([-1.65630525,  0.43927732, -0.10478637]),
#  'закончить': array([-1.22470402,  0.53998818, -0.17332338]),
#  'запинаться': array([-1.56452988,  0.29104559, -0.13184102]),
#  'прицеп': array([-1.32631455,  0.04631605, -0.08624983]),
#  'удельный': array([-0.22819607, -0.54650783,  0.21723443]),
#  'новиков': array([-1.09583536, -0.21030261,  0.10793053]),
#  'удивлять': array([-1.58225978,  0.40434346, -0.08889248]),
#  'проливать': array([-1.61428632,  0.43841497, -0.09442963]),
#  'кафельный': array([-1.13402326,  0.76542179,  0.50954182]),
#  'провод': array([ 7.371008  ,  0.4504153 , -1.67575062]),
#  'побелить': array([-1.30103133,  0.38422599, -0.09563334]),
#  'починка': array([-1.30507834,  0.61238684, -0.02908657]),
#  'чуткий': array([-1.49708021,  0.22422289, -0.08952309]),
#  'нести': array([-0.13183352, -0.80271452,  0.66835446]),
#  'реагировать': array([ 1.83779592,  0.59394613, -0.71979053]),
#  'садик': array([-0.33736324, -0.52315991, -0.57496084]),
#  'тесто': array([-1.63893064,  0.43120046, -0.10255948]),
#  'напротив': array([ 22.66405112, -13.73523276,   4.25664226]),
#  'неопрятно': array([-1.36372364,  0.11401848, -0.04346922]),
#  'искажённый': array([-1.64617894,  0.41227225, -0.10059145]),
#  'белить': array([-1.4810233 ,  0.44127724, -0.19735376]),
#  'напротяжение': array([-1.65630525,  0.43927732, -0.10478637]),
#  'привязать': array([-1.58533363,  0.43435122, -0.105185  ]),
#  'подписываться': array([-1.04929592,  0.64171087,  0.180649  ]),
#  'x': array([2.84420641, 2.94896076, 0.32337559]),
#  'вера': array([-1.55283274,  0.30902538, -0.20575323]),
#  'стрелка': array([-1.51246863,  0.40946737, -0.11218225]),
#  'утилизировать': array([-1.29828267, -0.00919758, -0.07305587]),
#  'стачка': array([ 0.88731936, -2.00502526,  1.32301032]),
#  'пост': array([-1.51568976,  0.31747389, -0.10410738]),
#  'вытекать': array([-1.53976788,  0.22190188, -0.11696011]),
#  'палацио': array([-1.56038518,  0.29504084, -0.13513395]),
#  'пересечение': array([ 0.20170463, -2.35474852, -0.62334014]),
#  'тротуарв': array([-1.65630525,  0.43927732, -0.10478637]),
#  'однажды': array([-1.63768637,  0.42734119, -0.10343533]),
#  'цирк': array([-1.37175595,  0.58486661, -0.36242856]),
#  'возраст': array([-1.55703437,  0.41099122, -0.10800493]),
#  'оштрафовать': array([-1.59607916,  0.35134652, -0.10339523]),
#  'жилкома': array([-1.59928098,  0.43429943, -0.12610588]),
#  'западный': array([-0.14712998, -0.64714792, -0.30698104]),
#  'перекоситься': array([-1.62808918,  0.4199209 , -0.10617854]),
#  'задерживать': array([-1.60715704,  0.37713663, -0.10878098]),
#  'вытяжной': array([-1.65630525,  0.43927732, -0.10478637]),
#  'плинтус': array([-0.54780292,  0.88215582,  0.28923405]),
#  'вероятность': array([-1.36043422,  0.33718483, -0.14799052]),
#  'равномерно': array([-1.10875277,  0.37325021, -0.07291274]),
#  'депо': array([-1.60052727,  0.31413733, -0.141546  ]),
#  'положительный': array([-1.57822814,  0.48471805, -0.08993226]),
#  'расписаться': array([-1.22476369,  0.68307268, -0.61540832]),
#  'наклон': array([-1.39486051,  0.40166036, -0.19504593]),
#  'кад': array([-1.56017642,  0.31069625, -0.10616852]),
#  'ландшафтный': array([-1.58996628,  0.31920688, -0.13676436]),
#  'спецкомиссия': array([-1.60082867,  0.32469534, -0.11181736]),
#  'полезно': array([-1.42880801,  0.40664925, -0.1836411 ]),
#  'прямой': array([-1.28671597,  0.4121009 , -0.02104927]),
#  'чай': array([-1.63905375,  0.42845244, -0.09759696]),
#  'управлять': array([ 5.89230273, -1.14301198,  1.4466097 ]),
#  'засунуть': array([-1.65395016,  0.43697065, -0.10543105]),
#  'ложа': array([-1.64873608,  0.43341548, -0.10195618]),
#  'скотч': array([-1.15085719, -0.01981897, -0.08322014]),
#  'ямка': array([-1.61843079,  0.43741995, -0.10471493]),
#  'деградировать': array([-1.62933126,  0.37628794, -0.11008021]),
#  'рещётка': array([-1.50481939,  0.2123609 , -0.24516345]),
#  'кстати': array([-1.626303  ,  0.41633973, -0.1082872 ]),
#  'гвс': array([-0.61981161,  0.00093765,  0.4725356 ]),
#  'озеленить': array([-1.53967726,  0.25877457, -0.13663671]),
#  'колодец': array([ 2.41404341, -1.73170376, -0.68047544]),
#  'облезть': array([-1.54532111,  0.40839222, -0.07518968]),
#  'теплоизолировать': array([-1.40070978,  0.54472243, -0.33355536]),
#  'благоустройство': array([ 2.23768751, -6.12387217, -0.68855451]),
#  'частичный': array([-1.46020234,  0.18592998, -0.13082976]),
#  'подниматься': array([-0.48668103,  0.7861037 ,  0.97514843]),
#  'петля': array([-0.64159082,  0.9956401 , -0.33618821]),
#  'захарьевский': array([-1.2506762 , -0.01573578,  0.16621934]),
#  'признак': array([-1.31803361,  0.44797088, -0.22102875]),
#  'ежегодно': array([-1.57430053,  0.4236993 , -0.12029351]),
#  'провайдер': array([-0.72561112,  0.93811325, -0.69519152]),
#  'спасать': array([-1.64802496,  0.44113505, -0.10247597]),
#  'карусель': array([-1.49879017,  0.2993699 , -0.08865592]),
#  'зацепиться': array([-1.64598663,  0.43611053, -0.10705325]),
#  'мусороприемник': array([-0.78401628,  0.315616  ,  0.46527107]),
#  'потолочный': array([-0.15533358,  1.5181034 ,  1.39243141]),
#  'соотвествовать': array([-1.46401581,  0.26542649, -0.08274642]),
#  'дольщик': array([-1.58216597,  0.41094807, -0.12946304]),
#  'трижды': array([-1.63950328,  0.44446251, -0.10469549]),
#  'забор': array([ 5.76586722, -8.74669073, -1.40051684]),
#  'долго': array([-8.74924721e-01,  3.07641321e-01, -3.60992949e-04]),
#  'связываться': array([-1.59476809,  0.41637805, -0.08287165]),
#  'бортовый': array([-1.65238967,  0.43328416, -0.10462698]),
#  'пространство': array([ 0.57020527,  0.52761996, -0.01200084]),
#  'демонтировать': array([  9.60928493, -11.79464414,  -0.2720318 ]),
#  'захламление': array([-0.93810797,  0.84473141,  0.39588721]),
#  'направо': array([0.02383688, 1.38330517, 0.37545818]),
#  'выглядить': array([-1.65600408,  0.43831629, -0.104255  ]),
#  'уголок': array([-1.14184743,  0.54331887, -0.25835502]),
#  'переулок': array([ 5.09241521, -4.39342203,  1.60310911]),
#  'выкладывать': array([-1.3911446 ,  0.5149252 ,  0.02819418]),
#  'наляпать': array([-1.63422998,  0.43532165, -0.09639811]),
#  'участие': array([-1.2544057 ,  0.48438807,  0.1663841 ]),
#  'воздух': array([-0.27086587,  0.37630952, -1.26462426]),
#  'фиктивно': array([-1.64863171,  0.43503059, -0.11195275]),
#  'телефон': array([-0.06066229,  0.41196364,  0.95186325]),
#  'сказать': array([-0.53254696, -0.2429801 ,  0.28307036]),
#  'шаг': array([-1.5751831 ,  0.41163041, -0.05867953]),
#  'больый': array([-1.65630525,  0.43927732, -0.10478637]),
#  'иван': array([ 0.74545561, -2.47450802,  1.19653827]),
#  'фон': array([-1.63983032,  0.42373612, -0.11679769]),
#  'неизвестно': array([-1.47319399,  0.47386139,  0.00744756]),
#  'застройка': array([-1.65560651,  0.43737701, -0.10444095]),
#  'ода': array([-1.65474194,  0.44086167, -0.10487977]),
#  'левашовский': array([-1.06154042, -0.33186431,  0.13920621]),
#  'узел': array([-1.05205392,  0.54255042,  0.10693752]),
#  'осветить': array([-0.37919513,  1.15007146,  0.85313617]),
#  'нумерация': array([0.07287105, 1.09782048, 0.53316399]),
#  'скат': array([-1.59964605,  0.33211828, -0.1298844 ]),
#  'ух': array([-1.65630525,  0.43927732, -0.10478637]),
#  'пообещать': array([-1.59867232,  0.42203986, -0.11672016]),
#  'неактуальный': array([-1.43522802,  0.21693123, -0.11526415]),
#  'насыпной': array([-1.61931011,  0.37592847, -0.11169628]),
#  'портал': array([ 4.38306705, -0.70786994,  0.89533031]),
#  'моментальный': array([-1.64155122,  0.42225209, -0.1044451 ]),
#  'холодильник': array([-1.54858244,  0.33573503, -0.07160421]),
#  'напряжение': array([-1.49601526,  0.2850601 , -0.08903907]),
#  'кузнечный': array([-0.91630077, -0.45867838,  0.43695646]),
#  'негорт': array([-1.26754131,  0.10966636, -0.09210367]),
#  'десница': array([-1.25747667,  0.55547401, -0.00227065]),
#  'предоставить': array([ 2.45431658,  0.48811656, -0.85948738]),
#  'самолёт': array([-1.64156187,  0.43520059, -0.10278851]),
#  'главстроить': array([-1.42776884,  0.17718043, -0.09253385]),
#  'митрополикать': array([-1.4864913 ,  0.19857346, -0.09750526]),
#  'сгрести': array([-1.25283161, -0.15811631, -0.18354489]),
#  'будка': array([ 0.36694413, -1.72600298, -0.40887768]),
#  'профилактика': array([-1.59091471,  0.32697249, -0.07864602]),
#  'желание': array([-1.39976882,  0.18778961, -0.08684145]),
#  'предвгай': array([-1.63567545,  0.41308615, -0.11465926]),
#  'выше': array([16.1691172 , 10.02702641, 14.04009678]),
#  'подвойский': array([ 1.01855311, -2.56180676,  1.35080234]),
#  'королева': array([ 0.00954311, -0.85891455, -1.20976182]),
#  'просъб': array([-1.58379706,  0.43832476, -0.14190506]),
#  'высококачественный': array([-1.65374672,  0.43937884, -0.10648076]),
#  'уважение': array([-1.21171078,  0.08599072,  0.2511321 ]),
#  'санузел': array([-1.56932833,  0.47214373, -0.1097964 ]),
#  'дольшея': array([-1.61930521,  0.38010046, -0.11125284]),
#  'изначальный': array([-1.52362867,  0.40851328, -0.10342329]),
#  'правило': array([ 3.04112352, -1.99205684,  1.657774  ]),
#  'гипермаркет': array([-1.54531612,  0.2554323 , -0.20787723]),
#  'износить': array([-1.48885598,  0.16621704, -0.05983216]),
#  'протокол': array([-1.3679622 ,  0.31699553, -0.10591689]),
#  'высадить': array([-1.59332637,  0.36206106, -0.12633983]),
#  'недвижимость': array([-1.63863414,  0.42719785, -0.11117496]),
#  'нерасчистить': array([-1.58168645,  0.29608851, -0.10031253]),
#  'охт': array([-1.47625306,  0.2055382 , -0.23722549]),
#  'зеленогорский': array([-1.613642  ,  0.38492354, -0.10958684]),
#  'отписываться': array([-1.62109995,  0.45594658, -0.10815736]),
#  'комитет': array([-0.53176494, -1.60608344, -0.04329317]),
#  'захламлять': array([-1.57351772,  0.28884647, -0.13773573]),
#  'расположить': array([13.65858152, -9.13557244,  5.21753951]),
#  'прочий': array([-1.21159179,  0.61846611, -0.62401813]),
#  'выгружать': array([-1.60691221,  0.46152399, -0.08489898]),
#  'реставрация': array([-0.84459791, -0.37613996, -0.04580045]),
#  'лопнуть': array([-1.52908746,  0.40386361, -0.11052803]),
#  'подводник': array([-1.29761646,  0.01299826,  0.18101869]),
#  'пособие': array([-1.4688139 ,  0.43399808, -0.05775251]),
#  'существенный': array([-1.64727992,  0.43001262, -0.10031521]),
#  'тсж': array([ 3.64561218, -2.80566359,  2.66495179]),
#  'дёрнуть': array([-1.26975692,  0.74596442,  0.07431448]),
#  'повезти': array([-1.64524612,  0.43208413, -0.10460068]),
#  'указываться': array([-1.48914936,  0.31698878, -0.09358471]),
#  'поочерёдно': array([-1.61238026,  0.42583523, -0.10331501]),
#  'сеть': array([-1.1871833 ,  0.09417731, -0.09244122]),
#  'лифт': array([114.82149077,  54.15200492,  11.42454396]),
#  'металл': array([-1.09421324,  0.10629798,  0.02764196]),
#  'рогод': array([-1.36794353, -0.17337687, -0.30608658]),
#  'курский': array([-1.53091237,  0.26271624, -0.22821703]),
#  'кошмар': array([-1.1836216 , -0.11262676, -0.08515017]),
#  'рюмочный': array([-1.06446082,  1.00816752,  0.31262608]),
#  'полотенцешушить': array([-1.57932014,  0.41384287, -0.09862967]),
#  'вода': array([17.82360562, -3.00895406, -2.79064742]),
#  'водоём': array([-1.65630525,  0.43927732, -0.10478637]),
#  'суббота': array([-1.26812148,  0.27802649, -0.07918129]),
#  'жертва': array([-1.33473828,  0.09063079,  0.27088321]),
#  'суворов': array([-1.21621065,  0.59257815, -0.63524206]),
#  'инвентарь': array([-0.68633067,  0.55569985,  0.45095009]),
#  'наглухо': array([-1.17233727,  0.51739293, -0.71783842]),
#  'наклоняться': array([-1.63464827,  0.42393481, -0.10534533]),
#  'газораспределительный': array([-1.24033299, -0.07615956,  0.26279149]),
#  'общедомовой': array([-1.05221095, -0.31531186, -0.17636989]),
#  'исходить': array([-1.11139552, -0.05352234, -0.05725914]),
#  'пояснение': array([-1.28753691,  0.08638401,  0.2611208 ]),
#  'путь': array([ 0.54360313, -0.23298621,  0.34200569]),
#  'всё': array([31.7687705 , -8.57570121,  3.39342159]),
#  'строить': array([-1.52241169,  0.26904683, -0.18848423]),
#  'молодец': array([-1.11362402,  0.72669726,  0.42477298]),
#  'маркет': array([-1.65593891,  0.43854086, -0.1057741 ]),
#  'отсек': array([-1.59821368,  0.40191374, -0.10182747]),
#  'тормозить': array([-1.63889943,  0.41648929, -0.10978317]),
#  'яндекс': array([-1.65364793,  0.43639668, -0.10745446]),
#  'видео': array([-1.08895482,  0.60952827,  0.12969593]),
#  'вышеизложенный': array([-0.24488275, -1.01759612,  0.6382314 ]),
#  'насквозь': array([-1.36197385,  0.43125945, -0.21340421]),
#  'владимирский': array([-1.37175767,  0.05613901, -0.2209782 ]),
#  'тратить': array([-1.30427478,  0.07144073, -0.06843688]),
#  'набиться': array([-1.64434215,  0.43902273, -0.10237441]),
#  'проспект': array([ 41.26209447, -34.69008325,  21.41774018]),
#  'вряд': array([-1.24709353,  0.58393957, -0.25267738]),
#  'подтвердиться': array([-1.54640291,  0.41977489, -0.10812892]),
#  'калининский': array([-0.96566791, -0.74999241, -0.40030344]),
#  'исполнитель': array([ 1.37922305,  0.22242535, -0.28767366]),
#  'вывалить': array([-1.47792761,  0.22885185, -0.10094432]),
#  'замерзать': array([-1.56950436,  0.37833153, -0.10824191]),
#  'сломать': array([19.6410506 ,  8.4719701 ,  0.35558438]),
#  'петербург': array([ 11.19444979, -28.5076228 ,  -0.8146495 ]),
#  'прилететь': array([-1.63310401,  0.40803743, -0.10246949]),
#  'режим': array([-0.74660941,  0.84811013,  0.55673426]),
#  'кустарник': array([-0.5871702 , -0.57722557, -0.12576948]),
#  'госстрой': array([-0.97584551, -0.14683802, -0.01749512]),
#  'решетчатый': array([-0.87136001,  1.05180869, -0.69432735]),
#  'четверг': array([-1.41024547,  0.49644891,  0.03745545]),
#  'часть': array([ 44.37392926, -43.93678098,  -0.46111491]),
#  'способ': array([-0.99466767,  0.63838571,  0.44823198]),
#  'заневский': array([-0.96555619, -0.32962893,  0.52353558]),
#  'продуктовый': array([-1.02252995, -0.20403833,  0.213083  ]),
#  'стучать': array([-1.30303931,  0.59328148, -0.11710919]),
#  'висеть': array([ 9.15081198,  2.6296324 , -0.85926451]),
#  'помойка': array([ 2.03096503, -0.13616358, -0.21622217]),
#  'повалить': array([-1.56392647,  0.20972797, -0.15159767]),
#  'легко': array([-1.61232136,  0.42188065, -0.11191213]),
#  'общаться': array([-1.45047785,  0.23905284, -0.10921978]),
#  'отслаивание': array([-1.65630525,  0.43927732, -0.10478637]),
#  'съёмка': array([-1.52298513,  0.32971819, -0.05908836]),
#  'целый': array([-0.97067798, -0.02412547, -0.1206295 ]),
#  'мусоропроводный': array([-1.48344663,  0.27678135, -0.09078676]),
#  'широта': array([-0.73830453, -0.46401868,  0.5213718 ]),
#  'крепиться': array([-1.3070851 ,  0.66327275, -0.05113145]),
#  'вручную': array([-0.32188173, -0.41705528,  0.10740271]),
#  'отслаиваться': array([-1.40859822,  0.515895  , -0.01210016]),
#  'качель': array([-1.51904745,  0.39821078, -0.05303511]),
#  'головка': array([-1.5438706 ,  0.52171436, -0.13690322]),
#  'предложение': array([-1.16195357, -0.17828355,  0.2303943 ]),
#  'стабильно': array([-1.65274542,  0.43632692, -0.10883998]),
#  'передача': array([-1.27850421,  0.03835812,  0.24834851]),
#  'соответствие': array([ 6.47023906, -1.33695236,  0.42547542]),
#  'электроарматура': array([-1.65471198,  0.44014532, -0.10852591]),
#  'ржавчина': array([-0.0975882 , -0.49134006, -0.07395205]),
#  'вазон': array([-0.34147968, -0.7782187 ,  0.31701532]),
#  'тоьький': array([-1.52686481,  0.37729119, -0.1006049 ]),
#  'поликарбонат': array([-1.45568988,  0.36372091, -0.2096969 ]),
#  'превышать': array([-1.12398893, -0.00277625, -0.1978287 ]),
#  'сигаретный': array([-1.35107025,  0.09339284,  0.24947371]),
#  'виниловый': array([-1.62145341,  0.35615977, -0.09646087]),
#  'вывозиться': array([ 0.83928978, -2.53892939,  0.3379344 ]),
#  'водослив': array([-1.65630525,  0.43927732, -0.10478637]),
#  'болото': array([-1.6326088 ,  0.42311026, -0.10591418]),
#  'автозапчасть': array([-1.64856319,  0.41503809, -0.1000867 ]),
#  'крышечка': array([-1.61839356,  0.4140036 , -0.10998322]),
#  'румянцевский': array([-1.55744597,  0.38712755, -0.12367282]),
#  'подбрасывать': array([-1.48073203,  0.20512078, -0.09447267]),
#  'дерптский': array([-1.65630525,  0.43927732, -0.10478637]),
#  'родитель': array([-1.28091888,  0.10264064, -0.09803599]),
#  'петар': array([-0.89928648,  0.78326125,  0.35836227]),
#  'ответсвенность': array([-1.64611279,  0.42944264, -0.09979532]),
#  'ведущий': array([2.09497696, 0.55805117, 0.32196583]),
#  'лишний': array([-1.48002908,  0.27852374, -0.06296673]),
#  'нестись': array([-0.6092015 ,  0.49763084, -0.91984741]),
#  'щикододка': array([-1.61485825,  0.43553797, -0.10609827]),
#  'обирать': array([-1.49683531,  0.26054689, -0.17864815]),
#  'орлово': array([-0.66151946, -0.77902532,  0.38805325]),
#  'жать': array([-1.5296286 ,  0.39114789, -0.14975185]),
#  'удерживать': array([-1.21050687,  0.71803648,  0.49199589]),
#  'влючить': array([-1.50341977,  0.56235231, -0.12473959]),
#  'контейнеина': array([-0.92326412,  0.44124843, -0.71827237]),
#  'строй': array([-1.0542603 ,  0.41331205, -0.19466524]),
#  'ов': array([-1.64591981,  0.45059397, -0.11686996]),
#  'ланскома': array([-1.15446045, -0.0666637 ,  0.30511843]),
#  'порасти': array([-1.62007419,  0.43019746, -0.10836686]),
#  'слободский': array([-1.27472868, -0.02722641,  0.15441999]),
#  'раковина': array([-1.64932367,  0.44123774, -0.10381669]),
#  'отнести': array([-1.65630525,  0.43927732, -0.10478637]),
#  'сначала': array([0.02513304, 1.06683064, 1.0371754 ]),
#  'надптси': array([-1.30521543, -0.12399262, -0.17305473]),
#  'светло': array([-1.6222267 ,  0.42968403, -0.0955503 ]),
#  'консольный': array([-1.65630005,  0.43923256, -0.1047967 ]),
#  'физический': array([-1.57450785,  0.36603293, -0.07473515]),
#  'полировать': array([-1.64715972,  0.43556923, -0.10221712]),
#  'запирание': array([-0.81141407,  1.00792946, -0.45720105]),
#  'оказывать': array([-1.30015978,  0.44879415, -0.0165756 ]),
#  'фонтанный': array([-1.65630525,  0.43927732, -0.10478637]),
#  'форточка': array([-0.32544638,  1.45163447,  1.64302042]),
#  'й': array([18.46482727,  8.71491247,  4.75540197]),
#  'следить': array([ 0.86235951, -0.64111308,  0.17466697]),
#  'мес': array([-1.15954443,  0.62860689, -0.57851062]),
#  'оплата': array([-1.53053617,  0.47360917, -0.12103648]),
#  'негде': array([-1.611302  ,  0.41601062, -0.10591392]),
#  'счищать': array([-1.58291038,  0.34223167, -0.11562215]),
#  'илёд': array([-1.47510106,  0.27811612, -0.15213935]),
#  'гуща': array([-1.56922895,  0.27370706, -0.10572733]),
#  'прорвать': array([-0.96577058,  0.63621484, -0.28584128]),
#  'период': array([ 0.41213817, -1.25081556,  0.64022518]),
#  'разваливаться': array([-1.34058297,  0.10186062,  0.27266504]),
#  'переставить': array([-1.06156106,  0.59835892,  0.09555891]),
#  'дым': array([-1.62300095,  0.37416462, -0.1088487 ]),
#  'выгул': array([-1.62480152,  0.43024856, -0.11092654]),
#  'вложить': array([-1.45455836,  0.44903565, -0.10181914]),
#  'тухлый': array([-1.59448701,  0.43235411, -0.10215824]),
#  'супемаркет': array([-1.18701621,  0.57287137, -0.6131148 ]),
#  'находящаяс': array([-1.5939086 ,  0.30842041, -0.12289733]),
#  'капот': array([-1.58286582,  0.46254623, -0.11436312]),
#  'грп': array([-1.525106  ,  0.26332561, -0.13016716]),
#  'орлов': array([-1.64071803,  0.42435514, -0.10827974]),
#  'раздербанить': array([-1.62153971,  0.41457472, -0.10483489]),
#  'вешаться': array([-1.5594945 ,  0.37186755, -0.09817706]),
#  'купить': array([-1.23065849,  0.14877725,  0.28571458]),
#  'ра': array([-1.62746625,  0.43303429, -0.08562572]),
#  'отказываться': array([-1.13758767,  0.54084505, -0.16832671]),
#  'мириада': array([-1.52388166,  0.37765639, -0.15760845]),
#  'рыбацкий': array([-0.42744295, -0.9421078 ,  0.93640571]),
#  'род': array([-1.24806898,  0.66209608, -0.61618083]),
#  'жидкость': array([-1.18546208,  0.75259887,  0.49875644]),
#  'наведоваться': array([-1.63875875,  0.40879766, -0.10869636]),
#  'исписать': array([ 0.25776841,  0.23749118, -0.44757951]),
#  'послать': array([-1.32319357,  0.59018639, -0.11848226]),
#  'богданов': array([-1.64907661,  0.43492596, -0.10285235]),
#  'комерческий': array([-1.56571179,  0.38990843, -0.04557682]),
#  'бездействовать': array([-1.08903769,  0.64585618,  0.0224567 ]),
#  'оставлять': array([ 14.78519183, -18.67607647,  -2.39108696]),
#  'окрестность': array([-1.6442417 ,  0.43294462, -0.11424856]),
#  'рушиться': array([-1.58377963,  0.42587355, -0.06404924]),
#  'соблюсти': array([-1.11788438,  0.64600415, -0.17802105]),
#  'вдвое': array([-1.60478766,  0.47088035, -0.14242063]),
#  'разбить': array([-0.39296286,  0.59502803,  0.3155706 ]),
#  'видеофиксация': array([-1.48196935,  0.40689418, -0.0997167 ]),
#  'человеческий': array([-1.42861353,  0.44633632, -0.23056303]),
#  'старый': array([ 5.61289803, -3.50111323, -1.42792169]),
#  'осуществлять': array([-0.69024607, -0.14357264,  0.02692683]),
#  'шпатлёвка': array([-1.4968064 ,  0.33337825, -0.09707538]),
#  'шаровой': array([-1.6176216 ,  0.43181481, -0.10122292]),
#  'портить': array([ 0.63968797, -2.98032834, -0.31038612]),
#  'двп': array([-1.64172206,  0.41289884, -0.10521932]),
#  'выдвинуть': array([-1.51746011,  0.19133978, -0.11953443]),
#  'вывеска': array([ 4.87387672, -8.5820494 , -1.30928646]),
#  'хотя': array([ 2.75642942, -0.1126659 , -0.27744867]),
#  'промерзать': array([ 0.35303834,  1.1687773 , -1.02139873]),
#  'лепнина': array([-1.25377367, -0.09541434, -0.08323209]),
#  'уд': array([-1.53162952,  0.2314339 , -0.12870659]),
#  'причинить': array([-1.53576745,  0.27969071, -0.13860322]),
#  'замотанный': array([-1.65342553,  0.43254777, -0.10568028]),
#  'егоров': array([-1.36935559,  0.10403579, -0.1762465 ]),
#  'наступать': array([-1.63853317,  0.41145922, -0.102545  ]),
#  'лаз': array([-1.27344483,  0.49083397, -0.04220635]),
#  'неступить': array([-1.21434254,  0.70051613, -0.63473456]),
#  'михаил': array([-0.77406499, -0.75931933,  0.0027291 ]),
#  'скамейка': array([ 3.67420889,  0.01780587, -3.23015806]),
#  'отчасти': array([-1.49828043,  0.20582244, -0.11330459]),
#  'рехколовский': array([-1.58892069,  0.40253994, -0.04161902]),
#  'энтузиаст': array([-0.1029848 , -1.35254614,  0.71992917]),
#  'гренадерский': array([-1.13803043, -0.21472743,  0.06776612]),
#  'неоднородность': array([-0.67729326,  0.20728944,  0.63176493]),
#  'искрить': array([-1.35719009,  0.10774732,  0.2508534 ]),
#  'готовность': array([-1.63531914,  0.41491752, -0.10654475]),
#  'dns': array([-1.59753151,  0.3848487 , -0.09777296]),
#  'дополнительно': array([-1.33574   ,  0.43864868, -0.02603421]),
#  'замкнутый': array([-1.61878054,  0.47353817, -0.11639652]),
#  'ванная': array([-0.82687169,  0.32002968, -0.16965823]),
#  'баск': array([-1.65630525,  0.43927732, -0.10478637]),
#  'лепёха': array([-1.64552355,  0.42131955, -0.10786482]),
#  'неработающий': array([-0.89787265,  0.18049566, -0.2800834 ]),
#  'вредитель': array([-1.50286078,  0.24365556, -0.08931303]),
#  'пискарёвский': array([-1.15864899, -0.21362967, -0.28267157]),
#  'арбузный': array([-1.65217137,  0.42961755, -0.10617819]),
#  'приход': array([-1.56073611,  0.40387074, -0.1332008 ]),
#  'называться': array([-1.47779287,  0.42981024, -0.12358828]),
#  'риск': array([-0.96995455, -0.26069513,  0.17265863]),
#  'нестерпимый': array([-1.61101427,  0.45426789, -0.0669076 ]),
#  'ложный': array([-1.31813364,  0.43095215, -0.06624509]),
#  'предупреждение': array([-1.51617226,  0.28693469, -0.10059883]),
#  'ровность': array([-1.52379616,  0.34009242, -0.09125585]),
#  'коридорный': array([-1.01658306,  0.8653775 ,  0.39983177]),
#  'петербурый': array([-1.568684  ,  0.31185129, -0.09034175]),
#  'накопиться': array([-1.65453002,  0.4353685 , -0.10465697]),
#  'поверженный': array([-1.65630525,  0.43927732, -0.10478637]),
#  'схема': array([-1.42211467,  0.25497965, -0.15829563]),
#  'футбол': array([-1.65226418,  0.43933832, -0.10386135]),
#  'забрызгать': array([-1.20599776,  0.57094084, -0.13600759]),
#  'xxxxxxxxxxxxxxx': array([-1.57030155,  0.52470167, -0.10608445]),
#  'диаметр': array([-1.58248532,  0.37422726, -0.10797928]),
#  'норкоман': array([-1.65630525,  0.43927732, -0.10478637]),
#  'контроль': array([0.51915632, 0.10637199, 0.25241765]),
#  'парк': array([-0.30464697, -0.74739706, -0.09709626]),
#  'набор': array([-1.52795703,  0.47388008, -0.10096713]),
#  'пирил': array([-0.98770139,  0.91515283,  0.47597045]),
#  'наблюдать': array([-0.99855663, -0.28923008,  0.27953226]),
#  'накладный': array([-1.58899272,  0.47618866, -0.11363631]),
#  'раскряжёвка': array([-1.65414555,  0.43578402, -0.10632557]),
#  'образование': array([-0.61847746, -0.3706581 , -0.07637384]),
#  'автоматизировать': array([-1.59788279,  0.42799028, -0.09177905]),
#  'теплоизоляция': array([-1.65630525,  0.43927732, -0.10478637]),
#  'ножка': array([-1.63375272,  0.40282613, -0.10181331]),
#  'опорожнять': array([-1.52218006,  0.37309889, -0.15796285]),
#  'gorod': array([-1.45475578, -0.01340952, -0.21885041]),
#  'волна': array([-1.26872076, -0.01374946,  0.22114743]),
#  'нагреваться': array([-1.61488555,  0.41663299, -0.101392  ]),
#  'х': array([2.56030414, 1.68142301, 0.02761187]),
#  'дрл': array([-0.4790398 , -0.30416514,  0.35788372]),
#  'спецтанспорт': array([-1.62610464,  0.37376788, -0.12650559]),
#  'серпуховский': array([-1.12529002, -0.2666744 ,  0.05356788]),
#  'надолго': array([-1.59384307,  0.33454762, -0.10416489]),
#  'весна': array([-0.47798891,  0.2437335 , -0.67900109]),
#  'заочный': array([-1.65263219,  0.44063096, -0.10458388]),
#  'разровнять': array([-1.51825839,  0.35244587, -0.18055456]),
#  'замерзание': array([-1.21234874,  0.64947434, -0.59424749]),
#  'опора': array([ 3.30844391, -2.71974529, -0.73977549]),
#  'генерал': array([-1.09158802, -0.32219777,  0.02941065]),
#  'клавиша': array([-0.95935592, -0.20486677,  0.11681994]),
#  'снабдить': array([-1.65327435,  0.44134912, -0.10546056]),
#  'юридический': array([-1.57283379,  0.2540578 , -0.15421219]),
#  'загарадительный': array([-1.57394648,  0.35002084, -0.12053843]),
#  'тратуаре': array([-1.29483927, -0.14262735, -0.10043923]),
#  'пригодиться': array([-1.64684721,  0.43112332, -0.10884886]),
#  'установоенный': array([-1.62488795,  0.3692864 , -0.12062701]),
#  'палец': array([-0.91775889,  0.21765521,  0.14779763]),
#  'указанно': array([-1.5662272 ,  0.3679741 , -0.10979489]),
#  'выборы': array([-1.61716301,  0.40928925, -0.09220445]),
#  'пить': array([-1.64573792,  0.43427752, -0.09530701]),
#  'пытаться': array([-0.75486928,  0.78042582, -0.84351565]),
#  'подзода': array([-1.53483382,  0.20668759, -0.13423505]),
#  'запор': array([-1.64892497,  0.43236931, -0.10760095]),
#  'российский': array([-1.6080192 ,  0.39134016, -0.10048018]),
#  'околонулевой': array([-1.24202105,  0.710704  , -0.24676153]),
#  'крысиный': array([-1.01715375,  0.98601888,  0.46124776]),
#  'становиться': array([-1.53554893,  0.33611627, -0.10257511]),
#  'вселяться': array([-1.36695089,  0.15064162,  0.26626844]),
#  'электрошкаф': array([-1.43278215,  0.53564722, -0.20326071]),
#  'копия': array([-1.537282  ,  0.43150693, -0.10550943]),
#  'дели': array([-1.63164085,  0.44817209, -0.11324185]),
#  'хомут': array([-1.63527515,  0.43098683, -0.10591298]),
#  'безответственно': array([-1.58640124,  0.395998  , -0.10987181]),
#  'подвеска': array([-1.50733783,  0.36528518, -0.14032951]),
#  'водоотводный': array([-1.61130413,  0.42228366, -0.10909371]),
#  'спам': array([-1.14498685,  0.54562362, -0.59666163]),
#  'стройка': array([-1.39055676, -0.09398208, -0.26030903]),
#  'вымостить': array([-1.37392029,  0.20182457, -0.20397778]),
#  'герметичный': array([-1.64531352,  0.43011275, -0.09605311]),
#  'чайковский': array([-0.76451424,  1.00788055,  0.06404936]),
#  'заносить': array([-1.42148982,  0.11501418, -0.07668364]),
#  'временной': array([-1.35032944, -0.05055113, -0.12307866]),
#  'ливнёвка': array([-1.64383566,  0.44348626, -0.0939464 ]),
#  'сыграть': array([-1.60274187,  0.39709925, -0.10484587]),
#  'предохранитель': array([-1.65541965,  0.43769957, -0.10483421]),
#  'язык': array([-1.22403497,  0.63529367, -0.61952181]),
#  'фуражный': array([-1.35790156,  0.08981804,  0.2534262 ]),
#  'подтвердить': array([0.18587575, 1.15860452, 0.29496478]),
#  'простолюдин': array([-1.63256699,  0.43435074, -0.10419024]),
#  'высохнуть': array([-1.12472302,  0.38153855, -0.15251093]),
#  'несоблюдаться': array([-1.32558278,  0.4158437 , -0.04966288]),
#  'квадратный': array([-1.48157374,  0.10101664, -0.14150892]),
#  'удалой': array([-1.65492081,  0.440011  , -0.10356528]),
#  'сползти': array([-1.60999409,  0.38372089, -0.11865656]),
#  'очередь': array([ 0.31457901,  1.24812461, -1.40175157]),
#  'комплектность': array([-1.60968061,  0.44067737, -0.11670786]),
#  'большевик': array([ 0.43998684, -2.0129749 ,  0.5446877 ]),
#  'топливный': array([-1.43984368,  0.46457215, -0.13075151]),
#  'контейнерный': array([ 17.06538602, -12.97531843,  -4.28176551]),
#  'жуткий': array([ 0.31345876,  0.64074499, -0.26041635]),
#  'согласный': array([-1.41314094,  0.42127085, -0.15871711]),
#  'смёт': array([-1.65630525,  0.43927732, -0.10478637]),
#  'опорный': array([-1.63130706,  0.43117151, -0.10378466]),
#  'анбо': array([-1.63863628,  0.42368308, -0.11168386]),
#  'письмо': array([-0.48623209, -0.23074112,  0.7138559 ]),
#  'ниша': array([-0.99226926,  0.77202221,  0.65920902]),
#  'принять': array([ 15.61335903, -14.20657258,   2.98711579]),
#  'телефонный': array([-1.13478485, -0.12022726,  0.2504593 ]),
#  'добровольно': array([-1.63918568,  0.43416716, -0.10770962]),
#  'прилагать': array([5.54128041, 1.41979909, 2.22967296]),
#  'издеваться': array([-1.3905    ,  0.29735187, -0.14501471]),
#  'мемориальный': array([-1.6520989 ,  0.43808585, -0.1021493 ]),
#  'листав': array([-1.4205234 ,  0.08984522, -0.12271287]),
#  'поручень': array([-0.11520267,  0.3680799 , -1.02425132]),
#  'отпадать': array([-1.51219123,  0.30882831, -0.08901395]),
#  'расколоться': array([-1.63050628,  0.41597514, -0.1042848 ]),
#  'радиус': array([-1.54575032,  0.44577089, -0.1187841 ]),
#  'вышкстоящий': array([-1.64858215,  0.43832145, -0.10020125]),
#  'блюхер': array([-0.32588292, -0.46006328, -0.41443205]),
#  'демонтаж': array([ 2.0122345 , -2.11076999, -0.38312512]),
#  'пробка': array([-0.90694654, -0.22795242, -0.09068434]),
#  'боков': array([-1.63629199,  0.42780981, -0.10143547]),
#  'вредительство': array([-1.32298941,  0.28761655, -0.26094098]),
#  'ковид': array([-1.62854357,  0.41291154, -0.10452536]),
#  'двигать': array([-1.65558071,  0.43751153, -0.10449442]),
#  'проводка': array([ 0.88053052,  1.56770371, -0.51958303]),
#  'незаизолировать': array([-1.64717018,  0.43171702, -0.10876577]),
#  'прога': array([-1.58881745,  0.34473121, -0.13670139]),
#  'случай': array([ 3.32155276, -1.98550666, -0.21777198]),
#  'разворотный': array([-1.65630525,  0.43927732, -0.10478637]),
#  'собственник': array([ 6.83777912, -3.17202098,  2.17726571]),
#  'деформироваться': array([-1.5301564 ,  0.36967311, -0.0781753 ]),
#  'знать': array([-1.07443562,  0.5987695 ,  0.06042362]),
#  'дождаться': array([-1.58789828,  0.31572284, -0.10078713]),
#  'хороший': array([ 0.44995291, -0.51057498, -0.24024598]),
#  'дождь': array([ 1.55994099, -2.22036947,  0.39896052]),
#  'презжий': array([-1.42088171,  0.01150669, -0.11148884]),
#  'матрац': array([-1.49858865,  0.25649298, -0.14153263]),
#  'облагородить': array([-1.37647829,  0.22579138, -0.10434609]),
#  'отколоть': array([-0.96995314,  0.9762571 ,  0.33797875]),
#  'никакой': array([ 2.91406151, -0.59538407, -0.53279494]),
#  'животное': array([-0.32067706, -0.23163509,  0.46557419]),
#  'уплотнять': array([-1.41704342,  0.52063925,  0.03526742]),
#  'бутыль': array([-1.63562329,  0.40469514, -0.10291335]),
#  'поэт': array([-1.37451235,  0.1412485 ,  0.267089  ]),
#  'запредел': array([-1.63857626,  0.44464   , -0.10190019]),
#  'строго': array([-1.19741992,  0.31271908,  0.03206121]),
#  'бфа': array([-1.65600295,  0.4389337 , -0.10508588]),
#  'понизиться': array([-1.62094989,  0.4443787 , -0.08888451]),
#  'убогость': array([-1.61781903,  0.37049502, -0.10361559]),
#  'востановить': array([-1.56801499,  0.45170132, -0.07432897]),
#  'жх': array([-1.23128845, -0.03275374,  0.26570684]),
#  'прибраться': array([-1.36522254,  0.12970937,  0.26803209]),
#  'витрина': array([-0.67281504,  0.05082174,  0.06694872]),
#  'ворота': array([ 0.99836351, -1.79476757,  0.01967989]),
#  'кирпич': array([ 0.47684167, -1.56182103, -0.11329282]),
#  'массовый': array([-1.64987253,  0.4339042 , -0.1087847 ]),
#  'xxxxxxxxxxxxxxxx': array([-1.52424978,  0.50700385, -0.08448192]),
#  'геометрический': array([-1.61819823,  0.41172725, -0.10649752]),
#  'гангутский': array([-0.67938909, -0.54152253,  0.51327985]),
#  'поперечный': array([-1.61038336,  0.42093791, -0.09497753]),
#  'увеличиваться': array([-1.25614889,  0.34017938, -0.20793894]),
#  'обилие': array([-1.01184145, -0.50597787, -0.11431389]),
#  'подвальный': array([ 1.19169272, -0.27616678, -0.18220754]),
#  'шлиссельбургский': array([ 0.2129521 , -2.11565069,  0.05889008]),
#  'впрямую': array([-1.62652762,  0.45790848, -0.11249961]),
#  'разводный': array([-1.45571611,  0.2481904 , -0.13762524]),
#  'торчать': array([ 2.34006914,  0.13307668, -0.63557495]),
#  'песок': array([ 24.15535633, -24.65263987,  -0.66447371]),
#  'протечка': array([ 5.26666258,  0.73027434, -1.28602146]),
#  'издаваться': array([-1.47275833,  0.58932899, -0.02666532]),
#  'кт': array([-1.27147063,  0.00819107,  0.18698194]),
#  'измалевать': array([-1.33032737,  0.71531476, -0.04732718]),
#  'грозить': array([-1.65229714,  0.43471737, -0.10497334]),
#  'запуск': array([-1.51431942,  0.5606786 , -0.12443615]),
#  'кондиционный': array([-1.59116179,  0.40305452, -0.11750515]),
#  'дрезденский': array([-1.36082232,  0.10959393, -0.14398158]),
#  'капремонт': array([-1.284399  ,  0.10388122,  0.27465203]),
#  'нагнуться': array([-1.51590536,  0.42965651, -0.1099732 ]),
#  'посыпка': array([-0.71693827, -0.77435634, -0.065143  ]),
#  'собственность': array([-0.89808488, -0.25885782, -0.14242052]),
#  'справляться': array([-0.78602644,  0.07534448,  0.13185743]),
#  'выгодный': array([-1.59217655,  0.43454411, -0.10240501]),
#  'соединить': array([-1.24787771,  0.76736377,  0.47007372]),
#  'наблюдение': array([-1.37721186,  0.56976705, -0.03978744]),
#  'превышение': array([-1.51336681,  0.28268923, -0.13693048]),
#  ...}

# %%
np.savetxt("matrix_context_pca.tsv", matrix_context_pca)

# %% [markdown]
# ### 5. С помощью PyTorch реализовать один из алгоритмов Word2Vec: CBoW или SkipGram. Получить векторные представления текстов с помощью собственной реализации одного из этих алгоритмов.

# %%
X = []
y = []
max_id = len(id_word)
max_content = window_size * 2

for doc in data:
    doc_len = len(doc)
    for i, word in enumerate(doc):
        if doc_len == 1: word_context = [word]
        else: word_context = doc[max(0, i - window_size):i] + doc[i + 1: i + window_size + 1]

        X.append([word_id[w] for w in word_context])
        y.append(word_id[word])
        
        if (max_content - len(word_context)) % max_content > 0:
            X[-1] += [max_id] * ((max_content - len(word_context)) % max_content)

# %%
torch.tensor(X).size(), torch.tensor(y).size()
# Out:
# (torch.Size([100224, 4]), torch.Size([100224]))

# %%
class CBoW(nn.Module):
    def __init__(self, num_embeddings, embendding_dim):
        super(CBoW, self).__init__()
        self.embedding = nn.Embedding(
            num_embeddings=num_embeddings, embedding_dim=embendding_dim
        )
        self.linear = nn.Linear(embendding_dim, num_embeddings)

    def forward(self, x):
        y = self.embedding(x).mean(1)
        y = self.linear(y)
        return y

# %%
model = CBoW(vocab_len + 1, 35)
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
X_tensor = torch.LongTensor(X)
y_tensor = torch.LongTensor(y)

train_ds = TensorDataset(X_tensor, y_tensor)
train_dl = DataLoader(train_ds, batch_size=1024,shuffle=True)

# %%
epochs = 50
for epoch in range(epochs):
    for x, y in train_dl:
        outputs = model(x)
        loss_value = loss(outputs, y)
        loss_value.backward()
        optimizer.step()
        optimizer.zero_grad()

    print(f"Эпоха {epoch + 1}, Значение функции потерь: {loss_value.item()}")
# Out:
# Эпоха 1, Значение функции потерь: 8.97099494934082
# Эпоха 2, Значение функции потерь: 8.925679206848145
# Эпоха 3, Значение функции потерь: 8.866296768188477
# Эпоха 4, Значение функции потерь: 8.817401885986328
# Эпоха 5, Значение функции потерь: 8.764063835144043
# Эпоха 6, Значение функции потерь: 8.692663192749023
# Эпоха 7, Значение функции потерь: 8.684788703918457
# Эпоха 8, Значение функции потерь: 8.60008430480957
# Эпоха 9, Значение функции потерь: 8.564786911010742
# Эпоха 10, Значение функции потерь: 8.479599952697754
# Эпоха 11, Значение функции потерь: 8.394320487976074
# Эпоха 12, Значение функции потерь: 8.32935619354248
# Эпоха 13, Значение функции потерь: 8.336527824401855
# Эпоха 14, Значение функции потерь: 8.25261116027832
# Эпоха 15, Значение функции потерь: 8.194457054138184
# Эпоха 16, Значение функции потерь: 8.107675552368164
# Эпоха 17, Значение функции потерь: 7.993314266204834
# Эпоха 18, Значение функции потерь: 7.978990077972412
# Эпоха 19, Значение функции потерь: 7.910995960235596
# Эпоха 20, Значение функции потерь: 7.807991027832031
# Эпоха 21, Значение функции потерь: 7.741427898406982
# Эпоха 22, Значение функции потерь: 7.674529552459717
# Эпоха 23, Значение функции потерь: 7.69281005859375
# Эпоха 24, Значение функции потерь: 7.565539836883545
# Эпоха 25, Значение функции потерь: 7.547824382781982
# Эпоха 26, Значение функции потерь: 7.579819202423096
# Эпоха 27, Значение функции потерь: 7.381410121917725
# Эпоха 28, Значение функции потерь: 7.459636211395264
# Эпоха 29, Значение функции потерь: 7.433585166931152
# Эпоха 30, Значение функции потерь: 7.342976093292236
# Эпоха 31, Значение функции потерь: 7.344376564025879
# Эпоха 32, Значение функции потерь: 7.279524803161621
# Эпоха 33, Значение функции потерь: 7.17144250869751
# Эпоха 34, Значение функции потерь: 7.1472930908203125
# Эпоха 35, Значение функции потерь: 7.261728763580322
# Эпоха 36, Значение функции потерь: 7.118912696838379
# Эпоха 37, Значение функции потерь: 6.990591526031494
# Эпоха 38, Значение функции потерь: 7.011826038360596
# Эпоха 39, Значение функции потерь: 7.0886101722717285
# Эпоха 40, Значение функции потерь: 6.971654415130615
# Эпоха 41, Значение функции потерь: 7.019100189208984
# Эпоха 42, Значение функции потерь: 6.92608642578125
# Эпоха 43, Значение функции потерь: 6.8847527503967285
# Эпоха 44, Значение функции потерь: 6.84935998916626
# Эпоха 45, Значение функции потерь: 6.8415398597717285
# Эпоха 46, Значение функции потерь: 6.774787425994873
# Эпоха 47, Значение функции потерь: 6.730483055114746
# Эпоха 48, Значение функции потерь: 6.7824320793151855
# Эпоха 49, Значение функции потерь: 6.770443916320801
# Эпоха 50, Значение функции потерь: 6.749879360198975

# %%
weight = model.linear.weight.detach().numpy()

# %%
weight.shape
# Out:
# (7772, 35)

# %%
len(weight)
# Out:
# 7772

# %%
id_word[7300], weight[7300]
# Out:
# ('осадка',
#  array([-0.12710916,  0.20813441,  0.18532494, -0.07366374,  0.02282931,
#         -0.12198538, -0.05412217, -0.13222803,  0.09234834,  0.17150405,
#          0.05122293,  0.21620837,  0.20281482,  0.13229434,  0.02995811,
#         -0.302809  ,  0.12605064,  0.10542149, -0.12809323, -0.27906603,
#         -0.14581719, -0.12399022,  0.02439718,  0.15829265, -0.01993027,
#          0.02203304,  0.16325116,  0.15210249, -0.1269648 , -0.18010657,
#          0.13687168, -0.20311813,  0.2225621 , -0.05465198,  0.1223396 ],
#        dtype=float32))

# %%
np.savetxt("cbow_emb_pca.tsv", PCA(10).fit_transform(weight))
